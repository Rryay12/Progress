# %%
import numpy as np
import pandas as pd
import pygame 
import math
import matplotlib.pyplot as plt
import json
import random

import torch
import torch.nn as nn
import torch.nn.functional as F

from collections import namedtuple, deque
import torch.optim as optim

import tensorflow as tf

# %%
class Car:
    def __init__(self,initial_x,initial_y,initial_angle,time_elapsed):
        self.x = initial_x
        self.y = initial_y
        self.time_elapsed = time_elapsed
        
        self.speed = 1
        self.vector_angle = initial_angle
        
        self.car_angle = initial_angle
        
        self.steering_angle = 0
        self.accel = 0

        self.grip = 3
        self.steering_grip = 1.5 
        
        self.CAR_WIDTH = 20
        self.CAR_HEIGHT = 10
        self.CAR_COLOR = (0, 255, 0)
        
        self.max_angle = 80
        self.max_speed = 8
        
        self.friction_coef = 0.01
        
        self.accel_const = 0.1 
        self.brake_const = 0.1
        self.steering_const = 10
        
    def calculate_all(self):
        self.car_angle = self.car_angle * (1-self.steering_grip*self.time_elapsed) + (self.steering_angle+self.car_angle) * self.steering_grip*self.time_elapsed
        self.vector_angle = self.vector_angle * (1-self.grip*self.time_elapsed) + self.car_angle * self.grip*self.time_elapsed
        
        potential_speed = self.speed+self.accel*self.time_elapsed
        
        if((potential_speed < self.max_speed)&(potential_speed > 0)):
            self.speed = self.speed+self.accel*self.time_elapsed
        
    def update_position(self):
        self.x = self.x + self.speed*np.cos(np.radians(self.vector_angle))
        self.y = self.y + self.speed*np.sin(np.radians(self.vector_angle))
        
    def speed_up(self):
        self.accel += self.accel_const
        
    def brake(self):
        self.accel -= self.speed*self.brake_const
        
    def nothing(self):
        self.accel = 0

    def friction(self):
        self.speed -= self.speed*self.friction_coef
        
    def turn_right(self):
        if(self.steering_angle < self.max_angle):
            self.steering_angle += self.steering_const
        else:
            self.steering_angle = self.max_angle
            
    def reset_turn(self):
        if(np.abs(self.steering_angle)  < 1):
            self.steering_angle =0
        elif(self.steering_angle<0):
            self.steering_angle +=self.steering_const
        elif(self.steering_angle>0):
            self.steering_angle -=self.steering_const

    def turn_left(self):
        if(self.steering_angle > -self.max_angle):
            self.steering_angle -= self.steering_const
        else:
            self.steering_angle = -self.max_angle

    def draw(self, screen):
        car_surf = pygame.Surface((self.CAR_WIDTH, self.CAR_HEIGHT), pygame.SRCALPHA)
        car_surf.fill(self.CAR_COLOR)
        rotated_car = pygame.transform.rotate(car_surf, -self.car_angle)
        screen.blit(rotated_car, (self.x - rotated_car.get_width() / 2, self.y - rotated_car.get_height() / 2))
        
    def reset_all(self):
        self.x = 0
        self.y = 0
        
        self.speed = 0
        self.vector_angle = 0
        
        self.car_angle = 0
        
        self.steering_angle = 0
        self.accel = 0
        
    def get_vals(self):
        return self.x,self.y,self.car_angle
    
    def get_pos(self):
        return (self.x,self.y)

    def get_speed(self):
        return self.speed

# %%
class extention_line:
    
    def __init__(self,angle,car:Car,outside_line,inside_line,screen):
      self.angle_from_car = angle
      self.car = car
      self.outside_line = outside_line
      self.inside_line = inside_line
      self.shortest_point = (0,0)
      self.screen = screen
      self.smallest = (0,(0,0))
    
    def get_distance(self):
        return self.smallest[0]
    
    def update(self):
        self.x,self.y,self.angle = self.car.get_vals()
        self.point1,self.point2= self.generate_long_segment_from_point((self.x,self.y),self.angle+self.angle_from_car)
        self.shortest_point = self.shortest_intersection()
    
    def plot(self):
        pygame.draw.line(self.screen,(255,255,255),self.point1,self.point2)
        pygame.draw.circle(self.screen,(255,0,0),self.shortest_point,10)
        
    def find_dist(self,x,y):

        return np.sqrt((x-self.car.x)**2+(y-self.car.y)**2)
    
    def shortest_intersection(self):
        point_list = []
        for i in range(len(self.outside_line)):
            p1 = self.outside_line[i-1]
            p2 = self.outside_line[i]
            
            intersection = line_segments_intersection(p1,p2,self.point1,self.point2)
            if (intersection is not None):
                point_list.append((self.find_dist(intersection[0],intersection[1]),intersection))
                
        for i in range(len(self.inside_line)):
            p1 = self.inside_line[i-1]
            p2 = self.inside_line[i]
            
            intersection = line_segments_intersection(p1,p2,self.point1,self.point2)
            if (intersection is not None):
                point_list.append((self.find_dist(intersection[0],intersection[1]),intersection))
                
        if len(point_list) > 0:
            self.smallest = min(point_list, key=lambda i: i[0])

            return self.smallest[1]
        else:
            return self.smallest[1]           
    
    def generate_long_segment_from_point(self,point, angle_degrees, length=10000):
        x, y = point
        angle_radians = math.radians(angle_degrees)

        dx = math.cos(angle_radians) * length
        dy = math.sin(angle_radians) * length

        end_point = (x + dx, y + dy)
        return point, end_point

def line_segments_intersection(p1, p2, p3, p4):
        x1, y1 = p1
        x2, y2 = p2
        x3, y3 = p3
        x4, y4 = p4

        denom = (y4 - y3)*(x2 - x1) - (x4 - x3)*(y2 - y1)

        if denom == 0:
            return None

        t = ((x4 - x3)*(y1 - y3) - (y4 - y3)*(x1 - x3)) / denom
        u = ((x2 - x1)*(y1 - y3) - (y2 - y1)*(x1 - x3)) / denom

        if 0 <= t <= 1 and 0 <= u <= 1:
            intersect_x = x1 + t * (x2 - x1)
            intersect_y = y1 + t * (y2 - y1)
            return (intersect_x, intersect_y)

        return None

# %%
class RaceTrack:
    def __init__(self,inner_points,outer_points):
        self.inner_points = inner_points
        self.outer_points = outer_points
        
        self.track_color = (50,50,50)
        self.border_color = (255,90,90)
        self.inner_color = (255,255,255)
    
    def plot_track(self,surface):
        pygame.draw.polygon(surface,self.track_color,self.outer_points,0)
        pygame.draw.polygon(surface,self.inner_color,self.inner_points,0)
        pygame.draw.lines(surface,self.border_color,True,self.inner_points,5)
        pygame.draw.lines(surface,self.border_color,True,self.outer_points,5)

# %%
def generate_track(centerline, width=100):
    inner = []
    outer = []
    n = len(centerline)
    for i in range(n):
        p1 = centerline[i - 1]
        p2 = centerline[i]
        p3 = centerline[(i + 1) % n]

        # Calculate the direction between p1 and p3 (smoothed)
        dx = p3[0] - p1[0]
        dy = p3[1] - p1[1]
        length = math.hypot(dx, dy)
        if length == 0:
            perp_dx, perp_dy = 0, 0
        else:
            perp_dx = -dy / length
            perp_dy = dx / length

        offset_x = perp_dx * width / 2
        offset_y = perp_dy * width / 2

        inner.append((p2[0] - offset_x, p2[1] - offset_y))
        outer.append((p2[0] + offset_x, p2[1] + offset_y))
    
    return inner, outer

# %%
centerline = [(671.6, 115.5),
(541.7, 120.3),
(402.0, 114.6),
(248.2, 124.1),
(193.1, 177.1),
(184.7, 262.3),
(172.0, 351.3),
(119.8, 441.3),
(111.3, 527.5),
(111.3, 602.3),
(124.0, 694.1),
(183.3, 757.6),
(320.2, 784.1),
(442.9, 792.6),
(579.8, 787.9),
(721.0, 785.0),
(846.6, 784.1),
(962.3, 782.2),
(1104.8, 780.3),
(1257.3, 782.2),
(1367.3, 772.7),
(1457.7, 720.6),
(1450.6, 643.0),
(1404.0, 598.5),
(1267.1, 562.5),
(1119.0, 556.8),
(969.4, 563.4),
(859.3, 583.3),
(705.4, 616.5),
(541.7, 647.7),
(410.5, 607.0),
(366.7, 525.6),
(378.0, 449.8),
(465.5, 398.7),
(582.7, 385.4),
(665.9, 402.5),
(737.9, 426.1),
(785.9, 435.6),
(840.9, 425.2),
(874.8, 401.5),
(900.2, 367.4),
(949.6, 344.7),
(1021.6, 348.5),
(1082.3, 370.3),
(1134.5, 404.4),
(1176.8, 430.9),
(1250.2, 455.5),
(1320.8, 435.6),
(1346.2, 378.8),
(1337.7, 310.6),
(1302.4, 269.9),
(1248.8, 224.4),
(1117.5, 181.8),
(996.2, 151.5),
(736.5, 119.3),]

# %%
class game:
    def __init__(self,inner_points,outer_points,angle_list,start_point,draw_keys=True,checkpoint_pos = 0,starting_angle=180):
        self.draw_keys = draw_keys
        
        self.my_font = pygame.font.SysFont('Comic Sans MS', 30)

        self.checkpoint_score = 3
        self.speed_score_mult = 0.03
        
        self.start_point = start_point
        
        self.car = Car(self.start_point[0],self.start_point[1],starting_angle,1/60)
        self.inner_points = inner_points
        self.outer_points = outer_points
        
        self.action = (0,0)
        
        self.last_pos = (0,0)
        self.current_pos = (0,0)
        
        self.p3 = (0,0)
        self.p4 = (0,0)
        
        self.checkpoint_position = checkpoint_pos
        
        self.log = []
        
        self.current_point = 0
        self.total_score = 0
        
        SCREEN_WIDTH = 1600
        SCREEN_HEIGHT = 900
        
        self.track = RaceTrack(inner_points,outer_points)
        self.screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
        pygame.display.set_caption('Racing Car Simulation')
        
        self.line_list = []
        for angle in angle_list:
            self.line_list.append(extention_line(angle,self.car,self.outer_points,self.inner_points,self.screen))
            
        self.state = self.get_state()
            
        self.safe_update((0,0))
        
    def get_state(self):
        distances = [i.get_distance() for i in self.line_list]
        MAX_DISTANCE = 1835
        return_action = [
            dist / MAX_DISTANCE for dist in distances      
        ] + [
            self.car.speed / self.car.max_speed,                              
            math.sin(np.radians(self.car.vector_angle-self.car.car_angle)), math.cos(np.radians(self.car.vector_angle-self.car.car_angle)),
            math.sin(np.radians(self.car.steering_angle)), math.cos(np.radians(self.car.steering_angle)),
            self.car.accel                                          
        ]
        
        return return_action
        
            
    def get_score(self):
        self.current_point = 0

        # Reward for reaching checkpoints
        self.p3 = self.inner_points[self.checkpoint_position % len(self.inner_points)]
        self.p4 = self.outer_points[self.checkpoint_position % len(self.outer_points)]
        if line_segments_intersection(self.last_pos, self.current_pos, self.p3, self.p4):
            self.current_point += self.checkpoint_score  # +100
            self.checkpoint_position += 1

        # Bonus for staying alive (time alive reward)
        self.current_point += 0.01  # +1 for every frame survived

        # Penalty for standing still
        if self.car.get_speed() < 0.5:
            self.current_point -= 0.02  # discourage inactivity or stalling

        self.total_score += self.current_point
        
    def is_collided_with_track(self):
        for i in range(len(self.outer_points)):
            p1 = self.outer_points[i-1]
            p2 = self.outer_points[i]
            
            intersection = line_segments_intersection(p1,p2,self.current_pos,self.last_pos)
            if (intersection is not None):
                return True
                
        for i in range(len(self.inner_points)):
            p1 = self.inner_points[i-1]
            p2 = self.inner_points[i]
            
            intersection = line_segments_intersection(p1,p2,self.current_pos,self.last_pos)
            if (intersection is not None):
                return True
            
        return False
    
    def plot_checkpoint(self):
        pygame.draw.line(self.screen,(0,255,0),self.p3,self.p4)
    
    def log_score(self):
        score = self.current_point
        self.log.append([score,(self.action),self.get_state()])
    
    def take_action(self,action):
        if self.draw_keys:
            up = (1500,700)
            down = (1500,750)
            left = (1450,750)
            right = (1550,750)
            
            self.draw_key(False,up,25)
            self.draw_key(False,down,25)
            self.draw_key(False,left,25)
            self.draw_key(False,right,25)
        
        if action[0] == 1:
            self.car.speed_up()
            if self.draw_keys:
                self.draw_key(True,up,25)
            
        elif action[0] == -1:
            self.car.brake()
            if self.draw_keys:
                self.draw_key(True,down,25)
        else:
            self.car.nothing()
            
        if action[1] == 1:
            self.car.turn_left()
            if self.draw_keys:
                self.draw_key(True,left,25)
        elif action[1] == -1:
            self.car.turn_right()
            if self.draw_keys:
                self.draw_key(True,right,25)
        else:
            self.car.reset_turn()
            
        self.action = action

    
    def draw_key(self,filled,coor,side):
        if filled:
            pygame.draw.rect(self.screen,(255,255,255), pygame.Rect(coor[0],coor[1],side,side),width=0)
        else:
            pygame.draw.rect(self.screen,(255,255,255), pygame.Rect(coor[0],coor[1],side,side),width=1)
    
    def update(self, action_):
        self.last_pos = self.current_pos
        self.current_pos = self.car.get_pos()

        if self.draw_keys:
            self.screen.fill((0, 0, 0))  
            self.track.plot_track(self.screen)
            self.car.draw(self.screen)

        for line in self.line_list:
            line.update()
            if self.draw_keys:
                line.plot()

        self.take_action(action_)

        self.car.friction()
        self.car.calculate_all()
        self.car.update_position()

        self.plot_checkpoint() if self.draw_keys else None

        if self.is_collided_with_track():
            self.current_point = -10
            self.total_score += self.current_point
            return False

        self.get_score()
        self.log_score()

        if self.draw_keys:
            text_surface = self.my_font.render(str(self.total_score), True, (255, 255, 0))
            self.screen.blit(text_surface, (50, 50))
            pygame.display.update()
            pygame.time.Clock().tick(60)

        return True
    
    def safe_update(self, action_):
        self.last_pos = self.current_pos
        self.current_pos = self.car.get_pos()

        for line in self.line_list:
            line.update()

        self.take_action(action_)
        self.car.friction()
        self.car.calculate_all()
        self.car.update_position()
        self.get_score()
        self.log_score()

            
    def return_log(self):
        return self.log
    
    def return_total_score(self):
        return self.total_score
    
    def return_score(self):
        return self.current_point

# %%
inner_points,outer_points = generate_track(centerline,100)

# %%
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.out(x)
    
    
Transition = namedtuple('Transition',('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
angle_list = [10,30,60,90,160,200,270,300,330,350]

# %%
count = 0
version = 0

# %%
loss_list = []
loss_mean_list = []
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
import numpy as np
import random

def calculate_angle(in_point, out_point):
    dx = out_point[0] - in_point[0]
    dy = out_point[1] - in_point[1]
    
    # atan2 gives angle in radians, handling direction properly
    angle_rad = np.arctan2(dy, dx)
    angle_deg = np.degrees(angle_rad)-90
    
    return angle_deg  # angle relative to x-axis (0 degrees is to the right)

def calculate_position(p1, p2):
    return (p1[0] + p2[0]) / 2, (p1[1] + p2[1]) / 2

def calculate_start():
    checkpoint_start = random.randint(0, len(inner_points) - 1)
    inner = inner_points[checkpoint_start]
    outer = outer_points[checkpoint_start]
    
    pos_x, pos_y = calculate_position(inner, outer)
    angle = calculate_angle(inner, outer)
    
    return pos_x, pos_y, angle, checkpoint_start

# %%
import pygame
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import namedtuple, deque

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

GAMMA = 0.999
LR = 0.0001
BATCH_SIZE = 256
MEMORY_SIZE = 500_000

EPS_START = 1.0
EPS_END = 0.03
EPS_DECAY = 0.99

TARGET_UPDATE = 100  
EPISODES = 5000
TIME = 1000

# Actions
actions = [(-1, -1), (-1, 0), (-1, 1),
           (0, -1), (0, 0), (0, 1),
           (1, -1), (1, 0), (1, 1)]

# Transition tuple
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward', 'done'))

# Replay memory class
class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# DQN model
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 64)
        self.out = nn.Linear(64, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        return self.out(x)

# Initialize

path_name = "/Users/ard/Desktop/Coding_2/F1_laptime_project/policies_9/policy_no_"

while True:
    TIME += 100
    memory = ReplayMemory(MEMORY_SIZE)
    policy_dqn = DQN(16, 9).to(device)
    target_dqn = DQN(16, 9).to(device)
    
    try:
        policy_dqn.load_state_dict(torch.load(path_name+str(count)+"-"+str(version)+".pth"))
    except:
        pass
    count+=1
    target_dqn.load_state_dict(policy_dqn.state_dict())
    target_dqn.eval()

    optimizer = optim.Adam(policy_dqn.parameters(), lr=LR)
    criterion = nn.SmoothL1Loss()

    epsilon = EPS_START
    EPS_START = max([EPS_START*0.9,EPS_END])

    def select_action(state, epsilon):
        if random.random() < epsilon:
            return random.randint(0, 8)
        with torch.no_grad():
            state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            return policy_dqn(state).argmax(dim=1).item()
        
    scorelist = []
    version = 0
    for episode in range(EPISODES):
        test = (episode % 100 == 0)
        x,y,angle,check = calculate_start()
        newgame = game(inner_points, outer_points, angle_list,(x, y), test,check,angle)
        state = newgame.get_state()
        
        episode_loss = []

        for t in range(TIME):
            action = select_action(state, 0.0 if test else epsilon)
            done = not newgame.update(actions[action])
            reward = newgame.return_score()
            next_state = newgame.get_state()

            memory.push(torch.tensor(state, dtype=torch.float32),
                        action,
                        torch.tensor(next_state, dtype=torch.float32),
                        reward,
                        done)

            state = next_state

            if len(memory) >= BATCH_SIZE:
                transitions = memory.sample(BATCH_SIZE)
                batch = Transition(*zip(*transitions))

                states = torch.stack(batch.state).to(device)
                actions_batch = torch.tensor(batch.action, dtype=torch.long).to(device)
                rewards = torch.tensor(batch.reward, dtype=torch.float32).to(device)
                next_states = torch.stack(batch.next_state).to(device)
                dones = torch.tensor(batch.done, dtype=torch.float32).to(device)

                q_values = policy_dqn(states).gather(1, actions_batch.unsqueeze(1)).squeeze(1)
                next_q_values = target_dqn(next_states).max(1)[0]
                expected_q_values = rewards + GAMMA * next_q_values * (1 - dones)

                loss = criterion(q_values, expected_q_values.detach())
                episode_loss.append(loss.detach().numpy())
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            if done:
                break

        epsilon = max(EPS_END, epsilon * EPS_DECAY)
        loss_mean_list.append(np.mean(episode_loss))
        
        if episode % TARGET_UPDATE == TARGET_UPDATE-1:
            target_dqn.load_state_dict(policy_dqn.state_dict())
            torch.save(policy_dqn.state_dict(), path_name+str(count)+"-"+str(version)+".pth")
            version += 1
            scorelist.append(newgame.return_total_score())
            np.savetxt("GFG.csv",loss_mean_list,delimiter =", ",fmt ='% s')
        loss_list.append(episode_loss)
        

        print(f"Episode {episode + 1}, Score: {newgame.return_total_score()}, Epsilon: {epsilon:.3f}, loss: {np.mean(episode_loss)} count: {count} version: {version}")
# Out:
# Episode 1, Score: -6.649999999999883, Epsilon: 0.990, loss: 3.794127906076028e-06 count: 1 version: 0
# Episode 2, Score: -8.27999999999998, Epsilon: 0.980, loss: 1.9204107957193628e-05 count: 1 version: 0
# Episode 3, Score: -3.5499999999999043, Epsilon: 0.970, loss: 0.005599780008196831 count: 1 version: 0
# Episode 4, Score: -5.219999999999974, Epsilon: 0.961, loss: 0.00445322971791029 count: 1 version: 0
# Episode 5, Score: 2.710000000000198, Epsilon: 0.951, loss: 0.007790072821080685 count: 1 version: 0
# Episode 6, Score: -12.179999999999978, Epsilon: 0.941, loss: 0.00839700922369957 count: 1 version: 0
# Episode 7, Score: -8.599999999999982, Epsilon: 0.932, loss: 0.009124627336859703 count: 1 version: 0
# Episode 8, Score: -7.199999999999996, Epsilon: 0.923, loss: 0.008914648555219173 count: 1 version: 0
# Episode 9, Score: -12.029999999999983, Epsilon: 0.914, loss: 0.011202584952116013 count: 1 version: 0
# Episode 10, Score: -7.769999999999984, Epsilon: 0.904, loss: 0.011755093932151794 count: 1 version: 0
# Episode 11, Score: -3.6899999999999045, Epsilon: 0.895, loss: 0.012985573150217533 count: 1 version: 0
# Episode 12, Score: -0.6499999999998741, Epsilon: 0.886, loss: 0.011311652138829231 count: 1 version: 0
# Episode 13, Score: -6.719999999999942, Epsilon: 0.878, loss: 0.011955738998949528 count: 1 version: 0
# Episode 14, Score: 2.5700000000002, Epsilon: 0.869, loss: 0.011145897209644318 count: 1 version: 0
# Episode 15, Score: -8.029999999999914, Epsilon: 0.860, loss: 0.010547416284680367 count: 1 version: 0
# Episode 16, Score: -10.32, Epsilon: 0.851, loss: 0.009692642837762833 count: 1 version: 0
# Episode 17, Score: -10.18999999999998, Epsilon: 0.843, loss: 0.0123298279941082 count: 1 version: 0
# Episode 18, Score: -12.13999999999998, Epsilon: 0.835, loss: 0.013659077696502209 count: 1 version: 0
# Episode 19, Score: -14.079999999999938, Epsilon: 0.826, loss: 0.012407676316797733 count: 1 version: 0
# Episode 20, Score: -5.0099999999999785, Epsilon: 0.818, loss: 0.012370338663458824 count: 1 version: 0
# Episode 21, Score: -16.22999999999989, Epsilon: 0.810, loss: 0.013392950408160686 count: 1 version: 0
# Episode 22, Score: -5.359999999999971, Epsilon: 0.802, loss: 0.012678292579948902 count: 1 version: 0
# Episode 23, Score: -3.960000000000001, Epsilon: 0.794, loss: 0.016642140224575996 count: 1 version: 0
# Episode 24, Score: -7.029999999999999, Epsilon: 0.786, loss: 0.013700135052204132 count: 1 version: 0
# Episode 25, Score: -6.680000000000007, Epsilon: 0.778, loss: 0.011785237118601799 count: 1 version: 0
# Episode 26, Score: -8.25999999999987, Epsilon: 0.770, loss: 0.014485078863799572 count: 1 version: 0
# Episode 27, Score: -5.769999999999962, Epsilon: 0.762, loss: 0.015546814538538456 count: 1 version: 0
# Episode 28, Score: -7.199999999999996, Epsilon: 0.755, loss: 0.018089966848492622 count: 1 version: 0
# Episode 29, Score: -5.85999999999996, Epsilon: 0.747, loss: 0.018980182707309723 count: 1 version: 0
# Episode 30, Score: -7.049999999999999, Epsilon: 0.740, loss: 0.016361115500330925 count: 1 version: 0
# Episode 31, Score: -7.329999999999993, Epsilon: 0.732, loss: 0.01778627559542656 count: 1 version: 0
# Episode 32, Score: -7.829999999999982, Epsilon: 0.725, loss: 0.019779978320002556 count: 1 version: 0
# Episode 33, Score: -6.129999999999955, Epsilon: 0.718, loss: 0.018096372485160828 count: 1 version: 0
# Episode 34, Score: -8.249999999999979, Epsilon: 0.711, loss: 0.017662420868873596 count: 1 version: 0
# Episode 35, Score: -9.58999999999998, Epsilon: 0.703, loss: 0.018106969073414803 count: 1 version: 0
# Episode 36, Score: -7.229999999999995, Epsilon: 0.696, loss: 0.017594560980796814 count: 1 version: 0
# Episode 37, Score: -9.179999999999852, Epsilon: 0.689, loss: 0.017176445573568344 count: 1 version: 0
# Episode 38, Score: -5.119999999999976, Epsilon: 0.683, loss: 0.017071232199668884 count: 1 version: 0
# Episode 39, Score: -8.159999999999979, Epsilon: 0.676, loss: 0.022810373455286026 count: 1 version: 0
# Episode 40, Score: -3.5299999999998852, Epsilon: 0.669, loss: 0.018191969022154808 count: 1 version: 0
# Episode 41, Score: -7.279999999999994, Epsilon: 0.662, loss: 0.017467902973294258 count: 1 version: 0
# Episode 42, Score: -3.80999999999994, Epsilon: 0.656, loss: 0.01857573539018631 count: 1 version: 0
# Episode 43, Score: -3.3299999999998895, Epsilon: 0.649, loss: 0.0182598065584898 count: 1 version: 0
# Episode 44, Score: -6.709999999999882, Epsilon: 0.643, loss: 0.016918424516916275 count: 1 version: 0
# Episode 45, Score: -8.509999999999978, Epsilon: 0.636, loss: 0.01916641555726528 count: 1 version: 0
# Episode 46, Score: -7.829999999999982, Epsilon: 0.630, loss: 0.015436836518347263 count: 1 version: 0
# Episode 47, Score: -7.219999999999995, Epsilon: 0.624, loss: 0.01722482219338417 count: 1 version: 0
# Episode 48, Score: -0.5699999999999049, Epsilon: 0.617, loss: 0.016990305855870247 count: 1 version: 0
# Episode 49, Score: -3.6099999999998835, Epsilon: 0.611, loss: 0.017449501901865005 count: 1 version: 0
# Episode 50, Score: -6.709999999999882, Epsilon: 0.605, loss: 0.016659535467624664 count: 1 version: 0
# Episode 51, Score: -6.569999999999885, Epsilon: 0.599, loss: 0.016419431194663048 count: 1 version: 0
# Episode 52, Score: -3.5299999999998852, Epsilon: 0.593, loss: 0.016706891357898712 count: 1 version: 0
# Episode 53, Score: -3.4299999999998874, Epsilon: 0.587, loss: 0.015984395518898964 count: 1 version: 0
# Episode 54, Score: -9.0, Epsilon: 0.581, loss: 0.014598170295357704 count: 1 version: 0
# Episode 55, Score: -7.629999999999987, Epsilon: 0.575, loss: 0.015910135582089424 count: 1 version: 0
# Episode 56, Score: 0.23000000000014764, Epsilon: 0.570, loss: 0.01471432764083147 count: 1 version: 0
# Episode 57, Score: -3.6699999999998822, Epsilon: 0.564, loss: 0.014551086351275444 count: 1 version: 0
# Episode 58, Score: -9.489999999999917, Epsilon: 0.558, loss: 0.015251507982611656 count: 1 version: 0
# Episode 59, Score: -4.769999999999984, Epsilon: 0.553, loss: 0.01614254340529442 count: 1 version: 0
# Episode 60, Score: -6.609999999999884, Epsilon: 0.547, loss: 0.014023574069142342 count: 1 version: 0
# Episode 61, Score: -3.349999999999889, Epsilon: 0.542, loss: 0.014802856370806694 count: 1 version: 0
# Episode 62, Score: -3.4299999999998874, Epsilon: 0.536, loss: 0.01394510269165039 count: 1 version: 0
# Episode 63, Score: -8.159999999999979, Epsilon: 0.531, loss: 0.013858567923307419 count: 1 version: 0
# Episode 64, Score: -3.7000000000000064, Epsilon: 0.526, loss: 0.01501051802188158 count: 1 version: 0
# Episode 65, Score: -5.279999999999973, Epsilon: 0.520, loss: 0.014242698438465595 count: 1 version: 0
# Episode 66, Score: -3.6099999999998835, Epsilon: 0.515, loss: 0.013830686919391155 count: 1 version: 0
# Episode 67, Score: -15.109999999999916, Epsilon: 0.510, loss: 0.01379133015871048 count: 1 version: 0
# Episode 68, Score: -3.349999999999889, Epsilon: 0.505, loss: 0.014370514079928398 count: 1 version: 0
# Episode 69, Score: -7.759999999999984, Epsilon: 0.500, loss: 0.013103757053613663 count: 1 version: 0
# Episode 70, Score: -7.779999999999919, Epsilon: 0.495, loss: 0.012760891579091549 count: 1 version: 0
# Episode 71, Score: -8.569999999999979, Epsilon: 0.490, loss: 0.013833300210535526 count: 1 version: 0
# Episode 72, Score: -3.589999999999884, Epsilon: 0.485, loss: 0.013667808845639229 count: 1 version: 0
# Episode 73, Score: -6.509999999999886, Epsilon: 0.480, loss: 0.01264902949333191 count: 1 version: 0
# Episode 74, Score: -3.0099999999998963, Epsilon: 0.475, loss: 0.013057445175945759 count: 1 version: 0
# Episode 75, Score: -9.309999999999846, Epsilon: 0.471, loss: 0.012974129989743233 count: 1 version: 0
# Episode 76, Score: -7.189999999999996, Epsilon: 0.466, loss: 0.014514892362058163 count: 1 version: 0
# Episode 77, Score: -8.519999999999978, Epsilon: 0.461, loss: 0.012863239273428917 count: 1 version: 0
# Episode 78, Score: -13.48999999999995, Epsilon: 0.457, loss: 0.01294571254402399 count: 1 version: 0
# Episode 79, Score: -8.249999999999979, Epsilon: 0.452, loss: 0.014141117222607136 count: 1 version: 0
# Episode 80, Score: -7.419999999999991, Epsilon: 0.448, loss: 0.014426454901695251 count: 1 version: 0
# Episode 81, Score: -7.749999999999984, Epsilon: 0.443, loss: 0.013674168847501278 count: 1 version: 0
# Episode 82, Score: -8.069999999999979, Epsilon: 0.439, loss: 0.014137201011180878 count: 1 version: 0
# Episode 83, Score: -5.39999999999997, Epsilon: 0.434, loss: 0.01598348654806614 count: 1 version: 0
# Episode 84, Score: -8.30999999999998, Epsilon: 0.430, loss: 0.015205689705908298 count: 1 version: 0
# Episode 85, Score: -8.509999999999978, Epsilon: 0.426, loss: 0.01489422470331192 count: 1 version: 0
# Episode 86, Score: -7.8199999999999825, Epsilon: 0.421, loss: 0.014797463081777096 count: 1 version: 0
# Episode 87, Score: -7.859999999999982, Epsilon: 0.417, loss: 0.012965349480509758 count: 1 version: 0
# Episode 88, Score: -3.489999999999886, Epsilon: 0.413, loss: 0.013832486234605312 count: 1 version: 0
# Episode 89, Score: -8.05999999999998, Epsilon: 0.409, loss: 0.012465143576264381 count: 1 version: 0
# Episode 90, Score: -7.569999999999988, Epsilon: 0.405, loss: 0.013555887155234814 count: 1 version: 0
# Episode 91, Score: -5.659999999999965, Epsilon: 0.401, loss: 0.013973716646432877 count: 1 version: 0
# Episode 92, Score: -5.469999999999969, Epsilon: 0.397, loss: 0.01329884398728609 count: 1 version: 0
# Episode 93, Score: -7.91999999999998, Epsilon: 0.393, loss: 0.015118126757442951 count: 1 version: 0
# Episode 94, Score: -7.989999999999979, Epsilon: 0.389, loss: 0.016486743465065956 count: 1 version: 0
# Episode 95, Score: -3.549999999999885, Epsilon: 0.385, loss: 0.014416462741792202 count: 1 version: 0
# Episode 96, Score: -6.900000000000002, Epsilon: 0.381, loss: 0.011058835312724113 count: 1 version: 0
# Episode 97, Score: -7.059999999999999, Epsilon: 0.377, loss: 0.013637589290738106 count: 1 version: 0
# Episode 98, Score: -5.749999999999963, Epsilon: 0.373, loss: 0.014667822048068047 count: 1 version: 0
# Episode 99, Score: -7.47999999999999, Epsilon: 0.370, loss: 0.015053722076117992 count: 1 version: 0
# Episode 100, Score: -4.189999999999996, Epsilon: 0.366, loss: 0.013372087851166725 count: 1 version: 1
# Episode 101, Score: -5.980000000000022, Epsilon: 0.362, loss: 0.018701260909438133 count: 1 version: 1
# Episode 102, Score: -7.91999999999998, Epsilon: 0.359, loss: 0.016816895455121994 count: 1 version: 1
# Episode 103, Score: -8.61999999999998, Epsilon: 0.355, loss: 0.0165505763143301 count: 1 version: 1
# Episode 104, Score: -7.439999999999991, Epsilon: 0.352, loss: 0.015120179392397404 count: 1 version: 1
# Episode 105, Score: -7.2599999999999945, Epsilon: 0.348, loss: 0.01661413349211216 count: 1 version: 1
# Episode 106, Score: -8.86999999999998, Epsilon: 0.345, loss: 0.015092304907739162 count: 1 version: 1
# Episode 107, Score: -8.49999999999985, Epsilon: 0.341, loss: 0.016994919627904892 count: 1 version: 1
# Episode 108, Score: -2.8100000000000254, Epsilon: 0.338, loss: 0.017211318016052246 count: 1 version: 1
# Episode 109, Score: -8.019999999999978, Epsilon: 0.334, loss: 0.018014781177043915 count: 1 version: 1
# Episode 110, Score: -4.709999999999985, Epsilon: 0.331, loss: 0.015135142020881176 count: 1 version: 1
# Episode 111, Score: -4.789999999999919, Epsilon: 0.328, loss: 0.01829741708934307 count: 1 version: 1
# Episode 112, Score: -9.50999999999998, Epsilon: 0.324, loss: 0.014780363999307156 count: 1 version: 1
# Episode 113, Score: -8.729999999999915, Epsilon: 0.321, loss: 0.015573844313621521 count: 1 version: 1
# Episode 114, Score: -6.499999999999973, Epsilon: 0.318, loss: 0.017588498070836067 count: 1 version: 1
# Episode 115, Score: -5.319999999999972, Epsilon: 0.315, loss: 0.017702963203191757 count: 1 version: 1
# Episode 116, Score: -6.07000000000002, Epsilon: 0.312, loss: 0.015570016577839851 count: 1 version: 1
# Episode 117, Score: -13.639999999999947, Epsilon: 0.309, loss: 0.01725340634584427 count: 1 version: 1
# Episode 118, Score: -4.419999999999991, Epsilon: 0.305, loss: 0.016430294141173363 count: 1 version: 1
# Episode 119, Score: -9.90999999999998, Epsilon: 0.302, loss: 0.01795148104429245 count: 1 version: 1
# Episode 120, Score: -6.749999999999941, Epsilon: 0.299, loss: 0.017796551808714867 count: 1 version: 1
# Episode 121, Score: -10.18999999999992, Epsilon: 0.296, loss: 0.016573799774050713 count: 1 version: 1
# Episode 122, Score: -7.069999999999935, Epsilon: 0.293, loss: 0.016581954434514046 count: 1 version: 1
# Episode 123, Score: -8.52999999999998, Epsilon: 0.290, loss: 0.01706882007420063 count: 1 version: 1
# Episode 124, Score: -8.20999999999998, Epsilon: 0.288, loss: 0.020627472549676895 count: 1 version: 1
# Episode 125, Score: -8.229999999999979, Epsilon: 0.285, loss: 0.018079442903399467 count: 1 version: 1
# Episode 126, Score: -9.99999999999998, Epsilon: 0.282, loss: 0.02036120556294918 count: 1 version: 1
# Episode 127, Score: -0.6499999999998528, Epsilon: 0.279, loss: 0.018453802913427353 count: 1 version: 1
# Episode 128, Score: -9.959999999999916, Epsilon: 0.276, loss: 0.018911922350525856 count: 1 version: 1
# Episode 129, Score: -6.52000000000001, Epsilon: 0.273, loss: 0.017070205882191658 count: 1 version: 1
# Episode 130, Score: -12.8399999999999, Epsilon: 0.271, loss: 0.017151983454823494 count: 1 version: 1
# Episode 131, Score: -7.419999999999967, Epsilon: 0.268, loss: 0.017340272665023804 count: 1 version: 1
# Episode 132, Score: -11.55999999999993, Epsilon: 0.265, loss: 0.017674928531050682 count: 1 version: 1
# Episode 133, Score: -9.499999999999917, Epsilon: 0.263, loss: 0.017230438068509102 count: 1 version: 1
# Episode 134, Score: -3.249999999999891, Epsilon: 0.260, loss: 0.016515111550688744 count: 1 version: 1
# Episode 135, Score: -14.359999999999951, Epsilon: 0.257, loss: 0.01770027168095112 count: 1 version: 1
# Episode 136, Score: -8.189999999999914, Epsilon: 0.255, loss: 0.01734977960586548 count: 1 version: 1
# Episode 137, Score: -8.179999999999978, Epsilon: 0.252, loss: 0.01673007570207119 count: 1 version: 1
# Episode 138, Score: -4.499999999999925, Epsilon: 0.250, loss: 0.016734978184103966 count: 1 version: 1
# Episode 139, Score: -0.5499999999998527, Epsilon: 0.247, loss: 0.017705347388982773 count: 1 version: 1
# Episode 140, Score: -4.729999999999984, Epsilon: 0.245, loss: 0.016409268602728844 count: 1 version: 1
# Episode 141, Score: -8.069999999999979, Epsilon: 0.242, loss: 0.017518917098641396 count: 1 version: 1
# Episode 142, Score: -6.480000000000011, Epsilon: 0.240, loss: 0.016884762793779373 count: 1 version: 1
# Episode 143, Score: -7.299999999999994, Epsilon: 0.238, loss: 0.017871929332613945 count: 1 version: 1
# Episode 144, Score: -8.20999999999998, Epsilon: 0.235, loss: 0.018108239397406578 count: 1 version: 1
# Episode 145, Score: -5.999999999999957, Epsilon: 0.233, loss: 0.01877274177968502 count: 1 version: 1
# Episode 146, Score: -7.829999999999982, Epsilon: 0.231, loss: 0.017783818766474724 count: 1 version: 1
# Episode 147, Score: -7.669999999999986, Epsilon: 0.228, loss: 0.01938355714082718 count: 1 version: 1
# Episode 148, Score: -4.709999999999985, Epsilon: 0.226, loss: 0.015559256076812744 count: 1 version: 1
# Episode 149, Score: -4.699999999999985, Epsilon: 0.224, loss: 0.016465255990624428 count: 1 version: 1
# Episode 150, Score: -7.689999999999985, Epsilon: 0.221, loss: 0.018679991364479065 count: 1 version: 1
# Episode 151, Score: -3.189999999999938, Epsilon: 0.219, loss: 0.018155593425035477 count: 1 version: 1
# Episode 152, Score: -6.409999999999888, Epsilon: 0.217, loss: 0.016998765990138054 count: 1 version: 1
# Episode 153, Score: -5.519999999999968, Epsilon: 0.215, loss: 0.01932748779654503 count: 1 version: 1
# Episode 154, Score: -7.02, Epsilon: 0.213, loss: 0.023024674504995346 count: 1 version: 1
# Episode 155, Score: 5.670000000000199, Epsilon: 0.211, loss: 0.017631569877266884 count: 1 version: 1
# Episode 156, Score: -8.929999999999922, Epsilon: 0.208, loss: 0.01628127321600914 count: 1 version: 1
# Episode 157, Score: -7.589999999999987, Epsilon: 0.206, loss: 0.019805926829576492 count: 1 version: 1
# Episode 158, Score: -7.75999999999992, Epsilon: 0.204, loss: 0.016866834834218025 count: 1 version: 1
# Episode 159, Score: -7.309999999999875, Epsilon: 0.202, loss: 0.016946665942668915 count: 1 version: 1
# Episode 160, Score: -8.96999999999998, Epsilon: 0.200, loss: 0.018239200115203857 count: 1 version: 1
# Episode 161, Score: -6.099999999999955, Epsilon: 0.198, loss: 0.017953399568796158 count: 1 version: 1
# Episode 162, Score: -6.810000000000004, Epsilon: 0.196, loss: 0.01821499690413475 count: 1 version: 1
# Episode 163, Score: -10.859999999999918, Epsilon: 0.194, loss: 0.018282735720276833 count: 1 version: 1
# Episode 164, Score: -3.3499999999999557, Epsilon: 0.192, loss: 0.01688835583627224 count: 1 version: 1
# Episode 165, Score: -6.470000000000011, Epsilon: 0.190, loss: 0.017025193199515343 count: 1 version: 1
# Episode 166, Score: -6.389999999999949, Epsilon: 0.189, loss: 0.016787834465503693 count: 1 version: 1
# Episode 167, Score: -10.559999999999983, Epsilon: 0.187, loss: 0.01847115345299244 count: 1 version: 1
# Episode 168, Score: -7.819999999999979, Epsilon: 0.185, loss: 0.018586453050374985 count: 1 version: 1
# Episode 169, Score: -12.199999999999978, Epsilon: 0.183, loss: 0.01955365389585495 count: 1 version: 1
# Episode 170, Score: -3.4699999999998865, Epsilon: 0.181, loss: 0.01788371056318283 count: 1 version: 1
# Episode 171, Score: -3.169999999999893, Epsilon: 0.179, loss: 0.017769288271665573 count: 1 version: 1
# Episode 172, Score: -6.32999999999989, Epsilon: 0.178, loss: 0.01714511588215828 count: 1 version: 1
# Episode 173, Score: -13.559999999999949, Epsilon: 0.176, loss: 0.016011063009500504 count: 1 version: 1
# Episode 174, Score: -10.08999999999998, Epsilon: 0.174, loss: 0.015610294416546822 count: 1 version: 1
# Episode 175, Score: -8.599999999999916, Epsilon: 0.172, loss: 0.016083400696516037 count: 1 version: 1
# Episode 176, Score: -8.319999999999979, Epsilon: 0.171, loss: 0.017658691853284836 count: 1 version: 1
# Episode 177, Score: -3.409999999999888, Epsilon: 0.169, loss: 0.016858885064721107 count: 1 version: 1
# Episode 178, Score: -0.8499999999999089, Epsilon: 0.167, loss: 0.018129633739590645 count: 1 version: 1
# Episode 179, Score: -6.309999999999951, Epsilon: 0.165, loss: 0.01666930317878723 count: 1 version: 1
# Episode 180, Score: -6.389999999999949, Epsilon: 0.164, loss: 0.01709546521306038 count: 1 version: 1
# Episode 181, Score: -3.5299999999998852, Epsilon: 0.162, loss: 0.01672488823533058 count: 1 version: 1
# Episode 182, Score: -5.9900000000000215, Epsilon: 0.161, loss: 0.01784389466047287 count: 1 version: 1
# Episode 183, Score: -6.269999999999891, Epsilon: 0.159, loss: 0.017353227362036705 count: 1 version: 1
# Episode 184, Score: -10.31999999999998, Epsilon: 0.157, loss: 0.01746574603021145 count: 1 version: 1
# Episode 185, Score: -14.089999999999938, Epsilon: 0.156, loss: 0.016404325142502785 count: 1 version: 1
# Episode 186, Score: -5.089999999999977, Epsilon: 0.154, loss: 0.012319897301495075 count: 1 version: 1
# Episode 187, Score: -7.159999999999933, Epsilon: 0.153, loss: 0.016730472445487976 count: 1 version: 1
# Episode 188, Score: -6.370000000000013, Epsilon: 0.151, loss: 0.01817023940384388 count: 1 version: 1
# Episode 189, Score: -3.1899999999998925, Epsilon: 0.150, loss: 0.017306413501501083 count: 1 version: 1
# Episode 190, Score: -5.579999999999966, Epsilon: 0.148, loss: 0.019016874954104424 count: 1 version: 1
# Episode 191, Score: -7.1199999999999335, Epsilon: 0.147, loss: 0.01615198329091072 count: 1 version: 1
# Episode 192, Score: -6.3499999999998895, Epsilon: 0.145, loss: 0.017218131572008133 count: 1 version: 1
# Episode 193, Score: -10.769999999999927, Epsilon: 0.144, loss: 0.017399931326508522 count: 1 version: 1
# Episode 194, Score: -11.059999999999981, Epsilon: 0.142, loss: 0.017226599156856537 count: 1 version: 1
# Episode 195, Score: -8.089999999999915, Epsilon: 0.141, loss: 0.016904477030038834 count: 1 version: 1
# Episode 196, Score: -7.049999999999871, Epsilon: 0.139, loss: 0.017715593799948692 count: 1 version: 1
# Episode 197, Score: -7.249999999999995, Epsilon: 0.138, loss: 0.017478832975029945 count: 1 version: 1
# Episode 198, Score: -12.389999999999974, Epsilon: 0.137, loss: 0.016657929867506027 count: 1 version: 1
# Episode 199, Score: -3.4499999999999185, Epsilon: 0.135, loss: 0.016884172335267067 count: 1 version: 1
# Episode 200, Score: -9.24, Epsilon: 0.134, loss: 0.013348371721804142 count: 1 version: 2
# Episode 201, Score: -6.08000000000002, Epsilon: 0.133, loss: 0.015386270359158516 count: 1 version: 2
# Episode 202, Score: -3.5699999999998844, Epsilon: 0.131, loss: 0.01818310096859932 count: 1 version: 2
# Episode 203, Score: -6.30999999999989, Epsilon: 0.130, loss: 0.016640188172459602 count: 1 version: 2
# Episode 204, Score: -3.429999999999925, Epsilon: 0.129, loss: 0.01568218320608139 count: 1 version: 2
# Episode 205, Score: -4.609999999999987, Epsilon: 0.127, loss: 0.013566927053034306 count: 1 version: 2
# Episode 206, Score: -7.799999999999983, Epsilon: 0.126, loss: 0.017069809138774872 count: 1 version: 2
# Episode 207, Score: -5.659999999999965, Epsilon: 0.125, loss: 0.015932288020849228 count: 1 version: 2
# Episode 208, Score: -9.559999999999981, Epsilon: 0.124, loss: 0.01778082735836506 count: 1 version: 2
# Episode 209, Score: -10.849999999999916, Epsilon: 0.122, loss: 0.01761183887720108 count: 1 version: 2
# Episode 210, Score: -9.37999999999998, Epsilon: 0.121, loss: 0.016204915940761566 count: 1 version: 2
# Episode 211, Score: -9.56999999999998, Epsilon: 0.120, loss: 0.015400219708681107 count: 1 version: 2
# Episode 212, Score: -4.199999999999996, Epsilon: 0.119, loss: 0.014804767444729805 count: 1 version: 2
# Episode 213, Score: -11.109999999999982, Epsilon: 0.118, loss: 0.016893543303012848 count: 1 version: 2
# Episode 214, Score: -6.7900000000000045, Epsilon: 0.116, loss: 0.016550783067941666 count: 1 version: 2
# Episode 215, Score: -4.4899999999999896, Epsilon: 0.115, loss: 0.016931233927607536 count: 1 version: 2
# Episode 216, Score: -3.2200000000000166, Epsilon: 0.114, loss: 0.017901146784424782 count: 1 version: 2
# Episode 217, Score: -11.68999999999992, Epsilon: 0.113, loss: 0.016213130205869675 count: 1 version: 2
# Episode 218, Score: -7.4899999999999896, Epsilon: 0.112, loss: 0.017495950683951378 count: 1 version: 2
# Episode 219, Score: -2.960000000000022, Epsilon: 0.111, loss: 0.015979040414094925 count: 1 version: 2
# Episode 220, Score: -12.869999999999964, Epsilon: 0.110, loss: 0.016767095774412155 count: 1 version: 2
# Episode 221, Score: -9.409999999999917, Epsilon: 0.108, loss: 0.01770644262433052 count: 1 version: 2
# Episode 222, Score: -7.969999999999979, Epsilon: 0.107, loss: 0.019656997174024582 count: 1 version: 2
# Episode 223, Score: -9.069999999999915, Epsilon: 0.106, loss: 0.016740793362259865 count: 1 version: 2
# Episode 224, Score: -5.069999999999913, Epsilon: 0.105, loss: 0.017500199377536774 count: 1 version: 2
# Episode 225, Score: -1.9999999999999787, Epsilon: 0.104, loss: 0.01984207145869732 count: 1 version: 2
# Episode 226, Score: -9.30999999999998, Epsilon: 0.103, loss: 0.015793200582265854 count: 1 version: 2
# Episode 227, Score: -5.069999999999977, Epsilon: 0.102, loss: 0.01612309366464615 count: 1 version: 2
# Episode 228, Score: -1.7899999999999832, Epsilon: 0.101, loss: 0.018597079440951347 count: 1 version: 2
# Episode 229, Score: -6.679999999999943, Epsilon: 0.100, loss: 0.015851683914661407 count: 1 version: 2
# Episode 230, Score: -5.0099999999999785, Epsilon: 0.099, loss: 0.017193688079714775 count: 1 version: 2
# Episode 231, Score: -6.590000000000009, Epsilon: 0.098, loss: 0.017631208524107933 count: 1 version: 2
# Episode 232, Score: 0.1499999999999755, Epsilon: 0.097, loss: 0.016137385740876198 count: 1 version: 2
# Episode 233, Score: -7.389999999999992, Epsilon: 0.096, loss: 0.02057710476219654 count: 1 version: 2
# Episode 234, Score: -5.349999999999971, Epsilon: 0.095, loss: 0.0138539494946599 count: 1 version: 2
# Episode 235, Score: -12.309999999999976, Epsilon: 0.094, loss: 0.01677270419895649 count: 1 version: 2
# Episode 236, Score: -5.269999999999973, Epsilon: 0.093, loss: 0.016267379745841026 count: 1 version: 2
# Episode 237, Score: -8.29999999999998, Epsilon: 0.092, loss: 0.016095031052827835 count: 1 version: 2
# Episode 238, Score: -1.8099999999999827, Epsilon: 0.091, loss: 0.01765541359782219 count: 1 version: 2
# Episode 239, Score: -4.419999999999991, Epsilon: 0.091, loss: 0.01859789900481701 count: 1 version: 2
# Episode 240, Score: -6.54000000000001, Epsilon: 0.090, loss: 0.021362287923693657 count: 1 version: 2
# Episode 241, Score: -7.0699999999999985, Epsilon: 0.089, loss: 0.019173244014382362 count: 1 version: 2
# Episode 242, Score: -4.479999999999926, Epsilon: 0.088, loss: 0.01886812411248684 count: 1 version: 2
# Episode 243, Score: -3.8900000000000023, Epsilon: 0.087, loss: 0.017781319096684456 count: 1 version: 2
# Episode 244, Score: -7.079999999999998, Epsilon: 0.086, loss: 0.01752559281885624 count: 1 version: 2
# Episode 245, Score: -3.9800000000000004, Epsilon: 0.085, loss: 0.01831328682601452 count: 1 version: 2
# Episode 246, Score: -3.350000000000014, Epsilon: 0.084, loss: 0.017581477761268616 count: 1 version: 2
# Episode 247, Score: -5.379999999999971, Epsilon: 0.084, loss: 0.01790359430015087 count: 1 version: 2
# Episode 248, Score: -6.579999999999945, Epsilon: 0.083, loss: 0.017951300367712975 count: 1 version: 2
# Episode 249, Score: -6.189999999999953, Epsilon: 0.082, loss: 0.020347654819488525 count: 1 version: 2
# Episode 250, Score: -2.5300000000000313, Epsilon: 0.081, loss: 0.017361527308821678 count: 1 version: 2
# Episode 251, Score: -2.8900000000000237, Epsilon: 0.080, loss: 0.017539119347929955 count: 1 version: 2
# Episode 252, Score: -7.409999999999991, Epsilon: 0.079, loss: 0.019088035449385643 count: 1 version: 2
# Episode 253, Score: -1.9700000000000433, Epsilon: 0.079, loss: 0.0198696106672287 count: 1 version: 2
# Episode 254, Score: -4.029999999999999, Epsilon: 0.078, loss: 0.021719519048929214 count: 1 version: 2
# Episode 255, Score: 14.660000000000046, Epsilon: 0.077, loss: 0.018453938886523247 count: 1 version: 2
# Episode 256, Score: -6.830000000000004, Epsilon: 0.076, loss: 0.017567208036780357 count: 1 version: 2
# Episode 257, Score: -8.45999999999992, Epsilon: 0.076, loss: 0.01978299766778946 count: 1 version: 2
# Episode 258, Score: -12.449999999999973, Epsilon: 0.075, loss: 0.0193969514220953 count: 1 version: 2
# Episode 259, Score: -8.149999999999979, Epsilon: 0.074, loss: 0.014750249683856964 count: 1 version: 2
# Episode 260, Score: -9.069999999999979, Epsilon: 0.073, loss: 0.019252967089414597 count: 1 version: 2
# Episode 261, Score: -2.959999999999958, Epsilon: 0.073, loss: 0.01812715455889702 count: 1 version: 2
# Episode 262, Score: -3.5100000000000104, Epsilon: 0.072, loss: 0.02018403261899948 count: 1 version: 2
# Episode 263, Score: -6.960000000000001, Epsilon: 0.071, loss: 0.018996339291334152 count: 1 version: 2
# Episode 264, Score: -12.469999999999908, Epsilon: 0.070, loss: 0.019077114760875702 count: 1 version: 2
# Episode 265, Score: -9.04999999999998, Epsilon: 0.070, loss: 0.02032654918730259 count: 1 version: 2
# Episode 266, Score: -8.089999999999979, Epsilon: 0.069, loss: 0.021610185503959656 count: 1 version: 2
# Episode 267, Score: -5.849999999999961, Epsilon: 0.068, loss: 0.02068283222615719 count: 1 version: 2
# Episode 268, Score: -6.480000000000011, Epsilon: 0.068, loss: 0.017300277948379517 count: 1 version: 2
# Episode 269, Score: -6.3699999999999495, Epsilon: 0.067, loss: 0.01895606517791748 count: 1 version: 2
# Episode 270, Score: -1.8799999999999812, Epsilon: 0.066, loss: 0.02057044394314289 count: 1 version: 2
# Episode 271, Score: -5.609999999999966, Epsilon: 0.066, loss: 0.019817780703306198 count: 1 version: 2
# Episode 272, Score: -6.469999999999947, Epsilon: 0.065, loss: 0.020804306492209435 count: 1 version: 2
# Episode 273, Score: -1.9500000000000437, Epsilon: 0.064, loss: 0.019335897639393806 count: 1 version: 2
# Episode 274, Score: -6.920000000000002, Epsilon: 0.064, loss: 0.021195072680711746 count: 1 version: 2
# Episode 275, Score: -7.599999999999987, Epsilon: 0.063, loss: 0.019365647807717323 count: 1 version: 2
# Episode 276, Score: -2.870000000000024, Epsilon: 0.062, loss: 0.01728123240172863 count: 1 version: 2
# Episode 277, Score: -8.079999999999979, Epsilon: 0.062, loss: 0.020247183740139008 count: 1 version: 2
# Episode 278, Score: -5.609999999999973, Epsilon: 0.061, loss: 0.02004799246788025 count: 1 version: 2
# Episode 279, Score: -4.639999999999986, Epsilon: 0.061, loss: 0.019149120897054672 count: 1 version: 2
# Episode 280, Score: 1.6000000000000085, Epsilon: 0.060, loss: 0.018298152834177017 count: 1 version: 2
# Episode 281, Score: 0.7100000000000275, Epsilon: 0.059, loss: 0.019989002496004105 count: 1 version: 2
# Episode 282, Score: -3.5500000000000096, Epsilon: 0.059, loss: 0.021781567484140396 count: 1 version: 2
# Episode 283, Score: -4.269999999999994, Epsilon: 0.058, loss: 0.019015328958630562 count: 1 version: 2
# Episode 284, Score: -0.7500000000000053, Epsilon: 0.058, loss: 0.02102021686732769 count: 1 version: 2
# Episode 285, Score: -6.370000000000013, Epsilon: 0.057, loss: 0.019174600020051003 count: 1 version: 2
# Episode 286, Score: -0.7799999999999407, Epsilon: 0.056, loss: 0.021104846149683 count: 1 version: 2
# Episode 287, Score: -8.29999999999998, Epsilon: 0.056, loss: 0.0197810810059309 count: 1 version: 2
# Episode 288, Score: 4.659999999999943, Epsilon: 0.055, loss: 0.018957968801259995 count: 1 version: 2
# Episode 289, Score: -2.129999999999976, Epsilon: 0.055, loss: 0.019888238981366158 count: 1 version: 2
# Episode 290, Score: -6.54000000000001, Epsilon: 0.054, loss: 0.021218089386820793 count: 1 version: 2
# Episode 291, Score: -12.10999999999998, Epsilon: 0.054, loss: 0.020808737725019455 count: 1 version: 2
# Episode 292, Score: 3.6699999999999644, Epsilon: 0.053, loss: 0.019852785393595695 count: 1 version: 2
# Episode 293, Score: -6.500000000000011, Epsilon: 0.053, loss: 0.021106164902448654 count: 1 version: 2
# Episode 294, Score: -3.4200000000000124, Epsilon: 0.052, loss: 0.022365419194102287 count: 1 version: 2
# Episode 295, Score: -7.039999999999999, Epsilon: 0.052, loss: 0.02251342125236988 count: 1 version: 2
# Episode 296, Score: -2.8600000000000243, Epsilon: 0.051, loss: 0.0207791980355978 count: 1 version: 2
# Episode 297, Score: -2.9800000000000217, Epsilon: 0.051, loss: 0.017698438838124275 count: 1 version: 2
# Episode 298, Score: -4.279999999999994, Epsilon: 0.050, loss: 0.02226063795387745 count: 1 version: 2
# Episode 299, Score: -6.780000000000005, Epsilon: 0.050, loss: 0.020131094381213188 count: 1 version: 2
# Episode 300, Score: -1.4499999999999904, Epsilon: 0.049, loss: 0.022189680486917496 count: 1 version: 3
# Episode 301, Score: 6.339999999999986, Epsilon: 0.049, loss: 0.020128553733229637 count: 1 version: 3
# Episode 302, Score: -9.85999999999998, Epsilon: 0.048, loss: 0.021169809624552727 count: 1 version: 3
# Episode 303, Score: -4.199999999999996, Epsilon: 0.048, loss: 0.01989213563501835 count: 1 version: 3
# Episode 304, Score: -4.199999999999996, Epsilon: 0.047, loss: 0.019305594265460968 count: 1 version: 3
# Episode 305, Score: -3.07000000000002, Epsilon: 0.047, loss: 0.01997242495417595 count: 1 version: 3
# Episode 306, Score: -6.98, Epsilon: 0.046, loss: 0.019293107092380524 count: 1 version: 3
# Episode 307, Score: -0.44000000000001194, Epsilon: 0.046, loss: 0.021546337753534317 count: 1 version: 3
# Episode 308, Score: -0.53000000000001, Epsilon: 0.045, loss: 0.020790454000234604 count: 1 version: 3
# Episode 309, Score: -6.960000000000001, Epsilon: 0.045, loss: 0.020907338708639145 count: 1 version: 3
# Episode 310, Score: -2.3300000000000356, Epsilon: 0.044, loss: 0.02070453390479088 count: 1 version: 3
# Episode 311, Score: -3.6400000000000077, Epsilon: 0.044, loss: 0.02066623419523239 count: 1 version: 3
# Episode 312, Score: -7.099999999999934, Epsilon: 0.043, loss: 0.021441718563437462 count: 1 version: 3
# Episode 313, Score: -3.1800000000000175, Epsilon: 0.043, loss: 0.018043581396341324 count: 1 version: 3
# Episode 314, Score: -3.5900000000000087, Epsilon: 0.043, loss: 0.020484942942857742 count: 1 version: 3
# Episode 315, Score: -4.409999999999991, Epsilon: 0.042, loss: 0.0230637826025486 count: 1 version: 3
# Episode 316, Score: -4.8199999999999825, Epsilon: 0.042, loss: 0.0196143239736557 count: 1 version: 3
# Episode 317, Score: -0.10000000000001918, Epsilon: 0.041, loss: 0.020991509780287743 count: 1 version: 3
# Episode 318, Score: -6.830000000000004, Epsilon: 0.041, loss: 0.02038874663412571 count: 1 version: 3
# Episode 319, Score: -0.06000000000002004, Epsilon: 0.041, loss: 0.02354987896978855 count: 1 version: 3
# Episode 320, Score: -4.129999999999997, Epsilon: 0.040, loss: 0.021828532218933105 count: 1 version: 3
# Episode 321, Score: -4.119999999999997, Epsilon: 0.040, loss: 0.021562471985816956 count: 1 version: 3
# Episode 322, Score: -2.8100000000000254, Epsilon: 0.039, loss: 0.019587935879826546 count: 1 version: 3
# Episode 323, Score: -6.1300000000000185, Epsilon: 0.039, loss: 0.017508307471871376 count: 1 version: 3
# Episode 324, Score: -3.680000000000007, Epsilon: 0.039, loss: 0.023977741599082947 count: 1 version: 3
# Episode 325, Score: -7.369999999999992, Epsilon: 0.038, loss: 0.0214343573898077 count: 1 version: 3
# Episode 326, Score: -7.059999999999999, Epsilon: 0.038, loss: 0.02255159802734852 count: 1 version: 3
# Episode 327, Score: -2.740000000000027, Epsilon: 0.037, loss: 0.02135463058948517 count: 1 version: 3
# Episode 328, Score: -12.699999999999967, Epsilon: 0.037, loss: 0.02092154510319233 count: 1 version: 3
# Episode 329, Score: -8.16999999999998, Epsilon: 0.037, loss: 0.021863332018256187 count: 1 version: 3
# Episode 330, Score: -6.700000000000006, Epsilon: 0.036, loss: 0.021847600117325783 count: 1 version: 3
# Episode 331, Score: 0.6699999999999644, Epsilon: 0.036, loss: 0.02173733338713646 count: 1 version: 3
# Episode 332, Score: -7.299999999999994, Epsilon: 0.036, loss: 0.0226286593824625 count: 1 version: 3
# Episode 333, Score: -6.840000000000003, Epsilon: 0.035, loss: 0.023984001949429512 count: 1 version: 3
# Episode 334, Score: -4.47999999999999, Epsilon: 0.035, loss: 0.020237473770976067 count: 1 version: 3
# Episode 335, Score: -4.809999999999986, Epsilon: 0.034, loss: 0.02168942429125309 count: 1 version: 3
# Episode 336, Score: -6.160000000000018, Epsilon: 0.034, loss: 0.023488424718379974 count: 1 version: 3
# Episode 337, Score: -6.810000000000004, Epsilon: 0.034, loss: 0.025631694123148918 count: 1 version: 3
# Episode 338, Score: -2.2900000000000365, Epsilon: 0.033, loss: 0.026438478380441666 count: 1 version: 3
# Episode 339, Score: -2.3799999999999706, Epsilon: 0.033, loss: 0.01963743567466736 count: 1 version: 3
# Episode 340, Score: -3.960000000000001, Epsilon: 0.033, loss: 0.0231923870742321 count: 1 version: 3
# Episode 341, Score: -3.400000000000013, Epsilon: 0.032, loss: 0.022286606952548027 count: 1 version: 3
# Episode 342, Score: -1.279999999999994, Epsilon: 0.032, loss: 0.022424422204494476 count: 1 version: 3
# Episode 343, Score: -2.4700000000000326, Epsilon: 0.032, loss: 0.021957015618681908 count: 1 version: 3
# Episode 344, Score: -3.2700000000000156, Epsilon: 0.032, loss: 0.01904672011733055 count: 1 version: 3
# Episode 345, Score: -4.279999999999994, Epsilon: 0.031, loss: 0.025133473798632622 count: 1 version: 3
# Episode 346, Score: 1.9800000000000004, Epsilon: 0.031, loss: 0.024440735578536987 count: 1 version: 3
# Episode 347, Score: -6.079999999999956, Epsilon: 0.031, loss: 0.022211268544197083 count: 1 version: 3
# Episode 348, Score: 3.7599999999999625, Epsilon: 0.030, loss: 0.024366943165659904 count: 1 version: 3
# Episode 349, Score: -4.039999999999999, Epsilon: 0.030, loss: 0.022214772179722786 count: 1 version: 3
# Episode 350, Score: -7.729999999999984, Epsilon: 0.030, loss: 0.025810154154896736 count: 1 version: 3
# Episode 351, Score: -2.740000000000027, Epsilon: 0.030, loss: 0.02127266675233841 count: 1 version: 3
# Episode 352, Score: -7.499999999999989, Epsilon: 0.030, loss: 0.02261378988623619 count: 1 version: 3
# Episode 353, Score: -3.5600000000000094, Epsilon: 0.030, loss: 0.022117910906672478 count: 1 version: 3
# Episode 354, Score: -3.200000000000017, Epsilon: 0.030, loss: 0.02372477389872074 count: 1 version: 3
# Episode 355, Score: -3.1700000000000177, Epsilon: 0.030, loss: 0.02523818053305149 count: 1 version: 3
# Episode 356, Score: -4.839999999999984, Epsilon: 0.030, loss: 0.021504206582903862 count: 1 version: 3
# Episode 357, Score: -4.249999999999995, Epsilon: 0.030, loss: 0.02312992513179779 count: 1 version: 3
# Episode 358, Score: -6.390000000000013, Epsilon: 0.030, loss: 0.02472482994198799 count: 1 version: 3
# Episode 359, Score: -0.9100000000000019, Epsilon: 0.030, loss: 0.023262951523065567 count: 1 version: 3
# Episode 360, Score: -3.910000000000002, Epsilon: 0.030, loss: 0.025563456118106842 count: 1 version: 3
# Episode 361, Score: -7.639999999999986, Epsilon: 0.030, loss: 0.023008301854133606 count: 1 version: 3
# Episode 362, Score: -3.1300000000000185, Epsilon: 0.030, loss: 0.02487371861934662 count: 1 version: 3
# Episode 363, Score: -3.960000000000001, Epsilon: 0.030, loss: 0.025053275749087334 count: 1 version: 3
# Episode 364, Score: -3.440000000000012, Epsilon: 0.030, loss: 0.022114349529147148 count: 1 version: 3
# Episode 365, Score: -5.750000000000027, Epsilon: 0.030, loss: 0.029043808579444885 count: 1 version: 3
# Episode 366, Score: -1.279999999999994, Epsilon: 0.030, loss: 0.022549718618392944 count: 1 version: 3
# Episode 367, Score: -0.5200000000000102, Epsilon: 0.030, loss: 0.021893655881285667 count: 1 version: 3
# Episode 368, Score: -7.93999999999998, Epsilon: 0.030, loss: 0.026018060743808746 count: 1 version: 3
# Episode 369, Score: -10.72999999999998, Epsilon: 0.030, loss: 0.02282564342021942 count: 1 version: 3
# Episode 370, Score: -6.539999999999946, Epsilon: 0.030, loss: 0.0239427387714386 count: 1 version: 3
# Episode 371, Score: -3.8000000000000043, Epsilon: 0.030, loss: 0.023998169228434563 count: 1 version: 3
# Episode 372, Score: -3.9400000000000013, Epsilon: 0.030, loss: 0.028171883895993233 count: 1 version: 3
# Episode 373, Score: -8.95999999999998, Epsilon: 0.030, loss: 0.026389431208372116 count: 1 version: 3
# Episode 374, Score: -2.0600000000000414, Epsilon: 0.030, loss: 0.023274920880794525 count: 1 version: 3
# Episode 375, Score: -0.4500000000000117, Epsilon: 0.030, loss: 0.02281031385064125 count: 1 version: 3
# Episode 376, Score: -5.8500000000000245, Epsilon: 0.030, loss: 0.024534866213798523 count: 1 version: 3
# Episode 377, Score: -7.699999999999985, Epsilon: 0.030, loss: 0.02397901378571987 count: 1 version: 3
# Episode 378, Score: -8.659999999999979, Epsilon: 0.030, loss: 0.022595513612031937 count: 1 version: 3
# Episode 379, Score: -8.399999999999979, Epsilon: 0.030, loss: 0.025041837245225906 count: 1 version: 3
# Episode 380, Score: -7.629999999999987, Epsilon: 0.030, loss: 0.023670485243201256 count: 1 version: 3
# Episode 381, Score: 0.2999999999999723, Epsilon: 0.030, loss: 0.022727780044078827 count: 1 version: 3
# Episode 382, Score: 5.079999999999995, Epsilon: 0.030, loss: 0.027015939354896545 count: 1 version: 3
# Episode 383, Score: -1.8299999999999823, Epsilon: 0.030, loss: 0.02337990514934063 count: 1 version: 3
# Episode 384, Score: -6.260000000000016, Epsilon: 0.030, loss: 0.024811506271362305 count: 1 version: 3
# Episode 385, Score: -5.8999999999999595, Epsilon: 0.030, loss: 0.025292037054896355 count: 1 version: 3
# Episode 386, Score: -4.999999999999979, Epsilon: 0.030, loss: 0.027706967666745186 count: 1 version: 3
# Episode 387, Score: -2.60000000000003, Epsilon: 0.030, loss: 0.024462124332785606 count: 1 version: 3
# Episode 388, Score: -6.310000000000015, Epsilon: 0.030, loss: 0.02169005386531353 count: 1 version: 3
# Episode 389, Score: -8.05999999999998, Epsilon: 0.030, loss: 0.02132950723171234 count: 1 version: 3
# Episode 390, Score: -0.9300000000000015, Epsilon: 0.030, loss: 0.026733117178082466 count: 1 version: 3
# Episode 391, Score: -8.77, Epsilon: 0.030, loss: 0.026142502203583717 count: 1 version: 3
# Episode 392, Score: -8.04999999999998, Epsilon: 0.030, loss: 0.02213302068412304 count: 1 version: 3
# Episode 393, Score: -6.710000000000006, Epsilon: 0.030, loss: 0.019905507564544678 count: 1 version: 3
# Episode 394, Score: 0.31999999999997186, Epsilon: 0.030, loss: 0.024927526712417603 count: 1 version: 3
# Episode 395, Score: -3.210000000000017, Epsilon: 0.030, loss: 0.02600676566362381 count: 1 version: 3
# Episode 396, Score: -4.0699999999999985, Epsilon: 0.030, loss: 0.024880578741431236 count: 1 version: 3
# Episode 397, Score: -7.359999999999992, Epsilon: 0.030, loss: 0.025201136246323586 count: 1 version: 3
# Episode 398, Score: -7.419999999999991, Epsilon: 0.030, loss: 0.0233748909085989 count: 1 version: 3
# Episode 399, Score: -8.249999999999979, Epsilon: 0.030, loss: 0.026143154129385948 count: 1 version: 3
# Episode 400, Score: -8.12999999999998, Epsilon: 0.030, loss: 0.025471793487668037 count: 1 version: 4
# Episode 401, Score: -6.250000000000016, Epsilon: 0.030, loss: 0.02457146719098091 count: 1 version: 4
# Episode 402, Score: -4.849999999999982, Epsilon: 0.030, loss: 0.026477398350834846 count: 1 version: 4
# Episode 403, Score: -4.559999999999988, Epsilon: 0.030, loss: 0.02403946779668331 count: 1 version: 4
# Episode 404, Score: -8.43999999999998, Epsilon: 0.030, loss: 0.022936882451176643 count: 1 version: 4
# Episode 405, Score: -6.890000000000002, Epsilon: 0.030, loss: 0.024753671139478683 count: 1 version: 4
# Episode 406, Score: -6.720000000000006, Epsilon: 0.030, loss: 0.023120611906051636 count: 1 version: 4
# Episode 407, Score: -3.2300000000000164, Epsilon: 0.030, loss: 0.027968738228082657 count: 1 version: 4
# Episode 408, Score: -7.759999999999984, Epsilon: 0.030, loss: 0.02432326227426529 count: 1 version: 4
# Episode 409, Score: -5.209999999999974, Epsilon: 0.030, loss: 0.024960404261946678 count: 1 version: 4
# Episode 410, Score: -6.120000000000019, Epsilon: 0.030, loss: 0.025929778814315796 count: 1 version: 4
# Episode 411, Score: -7.44999999999999, Epsilon: 0.030, loss: 0.023383013904094696 count: 1 version: 4
# Episode 412, Score: -6.680000000000007, Epsilon: 0.030, loss: 0.02802993170917034 count: 1 version: 4
# Episode 413, Score: -7.429999999999991, Epsilon: 0.030, loss: 0.02430749125778675 count: 1 version: 4
# Episode 414, Score: -8.06999999999996, Epsilon: 0.030, loss: 0.02510732412338257 count: 1 version: 4
# Episode 415, Score: 3.259999999999973, Epsilon: 0.030, loss: 0.02507960982620716 count: 1 version: 4
# Episode 416, Score: -8.11999999999998, Epsilon: 0.030, loss: 0.02557661198079586 count: 1 version: 4
# Episode 417, Score: -7.279999999999994, Epsilon: 0.030, loss: 0.024502594023942947 count: 1 version: 4
# Episode 418, Score: -8.099999999999978, Epsilon: 0.030, loss: 0.024448568001389503 count: 1 version: 4
# Episode 419, Score: -5.359999999999982, Epsilon: 0.030, loss: 0.027529118582606316 count: 1 version: 4
# Episode 420, Score: -6.940000000000001, Epsilon: 0.030, loss: 0.0234348326921463 count: 1 version: 4
# Episode 421, Score: -8.099999999999978, Epsilon: 0.030, loss: 0.025428198277950287 count: 1 version: 4
# Episode 422, Score: -7.549999999999988, Epsilon: 0.030, loss: 0.026356561109423637 count: 1 version: 4
# Episode 423, Score: -4.269999999999994, Epsilon: 0.030, loss: 0.023137466982007027 count: 1 version: 4
# Episode 424, Score: -2.9800000000000217, Epsilon: 0.030, loss: 0.027895741164684296 count: 1 version: 4
# Episode 425, Score: -11.89999999999998, Epsilon: 0.030, loss: 0.025593632832169533 count: 1 version: 4
# Episode 426, Score: -5.159999999999975, Epsilon: 0.030, loss: 0.02482040971517563 count: 1 version: 4
# Episode 427, Score: -7.519999999999989, Epsilon: 0.030, loss: 0.023922612890601158 count: 1 version: 4
# Episode 428, Score: -1.2899999999999938, Epsilon: 0.030, loss: 0.027794232591986656 count: 1 version: 4
# Episode 429, Score: -9.829999999999917, Epsilon: 0.030, loss: 0.023409312590956688 count: 1 version: 4
# Episode 430, Score: -9.86999999999998, Epsilon: 0.030, loss: 0.02474198117852211 count: 1 version: 4
# Episode 431, Score: -7.02, Epsilon: 0.030, loss: 0.024573341012001038 count: 1 version: 4
# Episode 432, Score: -16.31999999999989, Epsilon: 0.030, loss: 0.024972613900899887 count: 1 version: 4
# Episode 433, Score: -7.2599999999999945, Epsilon: 0.030, loss: 0.025779251009225845 count: 1 version: 4
# Episode 434, Score: -6.54000000000001, Epsilon: 0.030, loss: 0.023381801322102547 count: 1 version: 4
# Episode 435, Score: -2.9400000000000226, Epsilon: 0.030, loss: 0.022918613627552986 count: 1 version: 4
# Episode 436, Score: -6.610000000000008, Epsilon: 0.030, loss: 0.026797307655215263 count: 1 version: 4
# Episode 437, Score: -3.900000000000002, Epsilon: 0.030, loss: 0.02375359833240509 count: 1 version: 4
# Episode 438, Score: -5.349999999999981, Epsilon: 0.030, loss: 0.02594172954559326 count: 1 version: 4
# Episode 439, Score: -8.169999999999979, Epsilon: 0.030, loss: 0.02449699304997921 count: 1 version: 4
# Episode 440, Score: -5.739999999999986, Epsilon: 0.030, loss: 0.027234937995672226 count: 1 version: 4
# Episode 441, Score: -7.309999999999993, Epsilon: 0.030, loss: 0.025655124336481094 count: 1 version: 4
# Episode 442, Score: -6.940000000000001, Epsilon: 0.030, loss: 0.027597421780228615 count: 1 version: 4
# Episode 443, Score: -5.9000000000000234, Epsilon: 0.030, loss: 0.02909477986395359 count: 1 version: 4
# Episode 444, Score: -4.219999999999995, Epsilon: 0.030, loss: 0.02533343806862831 count: 1 version: 4
# Episode 445, Score: -3.720000000000006, Epsilon: 0.030, loss: 0.02427135966718197 count: 1 version: 4
# Episode 446, Score: -11.13, Epsilon: 0.030, loss: 0.025449607521295547 count: 1 version: 4
# Episode 447, Score: -7.519999999999989, Epsilon: 0.030, loss: 0.028356192633509636 count: 1 version: 4
# Episode 448, Score: 2.3099999999999934, Epsilon: 0.030, loss: 0.02505459450185299 count: 1 version: 4
# Episode 449, Score: -2.9299999999999926, Epsilon: 0.030, loss: 0.02589563839137554 count: 1 version: 4
# Episode 450, Score: -7.409999999999991, Epsilon: 0.030, loss: 0.02645806409418583 count: 1 version: 4
# Episode 451, Score: -6.340000000000014, Epsilon: 0.030, loss: 0.02486284449696541 count: 1 version: 4
# Episode 452, Score: -7.289999999999994, Epsilon: 0.030, loss: 0.023323142901062965 count: 1 version: 4
# Episode 453, Score: -7.739999999999984, Epsilon: 0.030, loss: 0.026993809267878532 count: 1 version: 4
# Episode 454, Score: 9.070000000000025, Epsilon: 0.030, loss: 0.029614076018333435 count: 1 version: 4
# Episode 455, Score: -7.749999999999984, Epsilon: 0.030, loss: 0.024626191705465317 count: 1 version: 4
# Episode 456, Score: -4.44999999999999, Epsilon: 0.030, loss: 0.02410467527806759 count: 1 version: 4
# Episode 457, Score: -6.750000000000005, Epsilon: 0.030, loss: 0.026665939018130302 count: 1 version: 4
# Episode 458, Score: -7.659999999999986, Epsilon: 0.030, loss: 0.027005579322576523 count: 1 version: 4
# Episode 459, Score: -7.419999999999991, Epsilon: 0.030, loss: 0.02728196792304516 count: 1 version: 4
# Episode 460, Score: -6.920000000000002, Epsilon: 0.030, loss: 0.026399798691272736 count: 1 version: 4
# Episode 461, Score: -8.169999999999979, Epsilon: 0.030, loss: 0.025020357221364975 count: 1 version: 4
# Episode 462, Score: -8.819999999999979, Epsilon: 0.030, loss: 0.026400955393910408 count: 1 version: 4
# Episode 463, Score: -0.6300000000000079, Epsilon: 0.030, loss: 0.027821026742458344 count: 1 version: 4
# Episode 464, Score: -3.8700000000000028, Epsilon: 0.030, loss: 0.026798168197274208 count: 1 version: 4
# Episode 465, Score: -4.8199999999999825, Epsilon: 0.030, loss: 0.02673988975584507 count: 1 version: 4
# Episode 466, Score: -7.909999999999981, Epsilon: 0.030, loss: 0.024372991174459457 count: 1 version: 4
# Episode 467, Score: -7.46999999999999, Epsilon: 0.030, loss: 0.02586127631366253 count: 1 version: 4
# Episode 468, Score: -3.7000000000000064, Epsilon: 0.030, loss: 0.02716994658112526 count: 1 version: 4
# Episode 469, Score: -4.859999999999989, Epsilon: 0.030, loss: 0.025884397327899933 count: 1 version: 4
# ...
# Episode 553, Score: 20.550000000000107, Epsilon: 0.030, loss: 0.02868981845676899 count: 1 version: 5
# Episode 554, Score: -7.739999999999984, Epsilon: 0.030, loss: 0.0274270698428154 count: 1 version: 5
# Episode 555, Score: -7.969999999999979, Epsilon: 0.030, loss: 0.031307902187108994 count: 1 version: 5
# Episode 556, Score: -6.98, Epsilon: 0.030, loss: 0.0257845651358366 count: 1 version: 5
# Episode 557, Score: -1.5799999999999876, Epsilon: 0.030, loss: 0.026014043018221855 count: 1 version: 5
# Episode 558, Score: -8.68999999999998, Epsilon: 0.030, loss: 0.028160391375422478 count: 1 version: 5
# Episode 559, Score: 3.4699999999999687, Epsilon: 0.030, loss: 0.02531411498785019 count: 1 version: 5
# Episode 560, Score: -7.159999999999997, Epsilon: 0.030, loss: 0.02803722396492958 count: 1 version: 5
# Episode 561, Score: -7.44999999999999, Epsilon: 0.030, loss: 0.03101476840674877 count: 1 version: 5
# Episode 562, Score: -7.519999999999989, Epsilon: 0.030, loss: 0.0236945990473032 count: 1 version: 5
# Episode 563, Score: -7.0699999999999985, Epsilon: 0.030, loss: 0.023738792166113853 count: 1 version: 5
# Episode 564, Score: -8.53999999999998, Epsilon: 0.030, loss: 0.027422133833169937 count: 1 version: 5
# Episode 565, Score: -7.93999999999998, Epsilon: 0.030, loss: 0.024303846061229706 count: 1 version: 5
# Episode 566, Score: -3.480000000000011, Epsilon: 0.030, loss: 0.027294917032122612 count: 1 version: 5
# Episode 567, Score: 6.589999999999989, Epsilon: 0.030, loss: 0.02957242727279663 count: 1 version: 5
# Episode 568, Score: -3.07000000000002, Epsilon: 0.030, loss: 0.02503172867000103 count: 1 version: 5
# Episode 569, Score: -6.579999999999945, Epsilon: 0.030, loss: 0.027368757873773575 count: 1 version: 5
# Episode 570, Score: -2.9500000000000224, Epsilon: 0.030, loss: 0.026883790269494057 count: 1 version: 5
# Episode 571, Score: -7.359999999999992, Epsilon: 0.030, loss: 0.0288921557366848 count: 1 version: 5
# Episode 572, Score: -3.390000000000013, Epsilon: 0.030, loss: 0.03200879693031311 count: 1 version: 5
# Episode 573, Score: -3.680000000000007, Epsilon: 0.030, loss: 0.02673419378697872 count: 1 version: 5
# Episode 574, Score: -8.329999999999979, Epsilon: 0.030, loss: 0.02755611203610897 count: 1 version: 5
# Episode 575, Score: -4.159999999999997, Epsilon: 0.030, loss: 0.027310015633702278 count: 1 version: 5
# Episode 576, Score: -7.2599999999999945, Epsilon: 0.030, loss: 0.02681136690080166 count: 1 version: 5
# Episode 577, Score: -0.6200000000000081, Epsilon: 0.030, loss: 0.0299516711384058 count: 1 version: 5
# Episode 578, Score: -7.46999999999999, Epsilon: 0.030, loss: 0.03182873874902725 count: 1 version: 5
# Episode 579, Score: -8.54999999999998, Epsilon: 0.030, loss: 0.02734154835343361 count: 1 version: 5
# Episode 580, Score: 0.7499999999999627, Epsilon: 0.030, loss: 0.029099002480506897 count: 1 version: 5
# Episode 581, Score: -6.340000000000014, Epsilon: 0.030, loss: 0.02166852355003357 count: 1 version: 5
# Episode 582, Score: -9.75999999999998, Epsilon: 0.030, loss: 0.026398861780762672 count: 1 version: 5
# Episode 583, Score: -7.6799999999999855, Epsilon: 0.030, loss: 0.028362583369016647 count: 1 version: 5
# Episode 584, Score: -9.78999999999998, Epsilon: 0.030, loss: 0.029624314978718758 count: 1 version: 5
# Episode 585, Score: -6.260000000000016, Epsilon: 0.030, loss: 0.02685876376926899 count: 1 version: 5
# Episode 586, Score: 0.4399999999999693, Epsilon: 0.030, loss: 0.023329734802246094 count: 1 version: 5
# Episode 587, Score: -6.210000000000017, Epsilon: 0.030, loss: 0.029952537268400192 count: 1 version: 5
# Episode 588, Score: -7.369999999999992, Epsilon: 0.030, loss: 0.02597970701754093 count: 1 version: 5
# Episode 589, Score: -5.9900000000000215, Epsilon: 0.030, loss: 0.026313738897442818 count: 1 version: 5
# Episode 590, Score: 7.9000000000000306, Epsilon: 0.030, loss: 0.029168028384447098 count: 1 version: 5
# Episode 591, Score: -6.08000000000002, Epsilon: 0.030, loss: 0.0280087199062109 count: 1 version: 5
# Episode 592, Score: -5.780000000000026, Epsilon: 0.030, loss: 0.027937155216932297 count: 1 version: 5
# Episode 593, Score: -4.429999999999991, Epsilon: 0.030, loss: 0.024996478110551834 count: 1 version: 5
# Episode 594, Score: -8.28999999999998, Epsilon: 0.030, loss: 0.024532411247491837 count: 1 version: 5
# Episode 595, Score: -6.560000000000009, Epsilon: 0.030, loss: 0.027636120095849037 count: 1 version: 5
# Episode 596, Score: -6.890000000000002, Epsilon: 0.030, loss: 0.03062346577644348 count: 1 version: 5
# Episode 597, Score: -6.310000000000015, Epsilon: 0.030, loss: 0.02252713404595852 count: 1 version: 5
# Episode 598, Score: -3.1800000000000175, Epsilon: 0.030, loss: 0.029561443254351616 count: 1 version: 5
# Episode 599, Score: -7.979999999999979, Epsilon: 0.030, loss: 0.030233165249228477 count: 1 version: 5
# Episode 600, Score: -8.61999999999998, Epsilon: 0.030, loss: 0.029212968423962593 count: 1 version: 6
# Episode 601, Score: -3.909999999999986, Epsilon: 0.030, loss: 0.026998769491910934 count: 1 version: 6
# Episode 602, Score: -10.48, Epsilon: 0.030, loss: 0.027648840099573135 count: 1 version: 6
# Episode 603, Score: -0.11000000000001897, Epsilon: 0.030, loss: 0.029736854135990143 count: 1 version: 6
# Episode 604, Score: -3.3200000000000145, Epsilon: 0.030, loss: 0.02822236716747284 count: 1 version: 6
# Episode 605, Score: -6.400000000000013, Epsilon: 0.030, loss: 0.03194365277886391 count: 1 version: 6
# Episode 606, Score: -3.240000000000016, Epsilon: 0.030, loss: 0.02844139188528061 count: 1 version: 6
# Episode 607, Score: -6.420000000000012, Epsilon: 0.030, loss: 0.02641483023762703 count: 1 version: 6
# Episode 608, Score: -8.84999999999998, Epsilon: 0.030, loss: 0.02609541267156601 count: 1 version: 6
# Episode 609, Score: -7.709999999999985, Epsilon: 0.030, loss: 0.02725488319993019 count: 1 version: 6
# Episode 610, Score: -2.8000000000000256, Epsilon: 0.030, loss: 0.03155386075377464 count: 1 version: 6
# Episode 611, Score: -6.270000000000016, Epsilon: 0.030, loss: 0.02792827971279621 count: 1 version: 6
# Episode 612, Score: -5.840000000000025, Epsilon: 0.030, loss: 0.030206460505723953 count: 1 version: 6
# Episode 613, Score: -3.2300000000000164, Epsilon: 0.030, loss: 0.0250238087028265 count: 1 version: 6
# Episode 614, Score: -6.160000000000018, Epsilon: 0.030, loss: 0.027420392259955406 count: 1 version: 6
# Episode 615, Score: -3.240000000000016, Epsilon: 0.030, loss: 0.028228718787431717 count: 1 version: 6
# Episode 616, Score: -6.99, Epsilon: 0.030, loss: 0.026797961443662643 count: 1 version: 6
# Episode 617, Score: -9.72, Epsilon: 0.030, loss: 0.027021020650863647 count: 1 version: 6
# Episode 618, Score: -6.289999999999951, Epsilon: 0.030, loss: 0.02562389336526394 count: 1 version: 6
# Episode 619, Score: -8.039999999999978, Epsilon: 0.030, loss: 0.03065343387424946 count: 1 version: 6
# Episode 620, Score: 3.3399999999999714, Epsilon: 0.030, loss: 0.029864760115742683 count: 1 version: 6
# Episode 621, Score: -7.44999999999999, Epsilon: 0.030, loss: 0.028012622147798538 count: 1 version: 6
# Episode 622, Score: -7.249999999999995, Epsilon: 0.030, loss: 0.0264090858399868 count: 1 version: 6
# Episode 623, Score: -5.9000000000000234, Epsilon: 0.030, loss: 0.029221635311841965 count: 1 version: 6
# Episode 624, Score: 1.0499999999999563, Epsilon: 0.030, loss: 0.027063699439167976 count: 1 version: 6
# Episode 625, Score: -3.2700000000000156, Epsilon: 0.030, loss: 0.020747128874063492 count: 1 version: 6
# Episode 626, Score: -2.6600000000000286, Epsilon: 0.030, loss: 0.02595786191523075 count: 1 version: 6
# Episode 627, Score: -6.290000000000015, Epsilon: 0.030, loss: 0.026966484263539314 count: 1 version: 6
# Episode 628, Score: -3.580000000000009, Epsilon: 0.030, loss: 0.02920340746641159 count: 1 version: 6
# Episode 629, Score: -9.16999999999998, Epsilon: 0.030, loss: 0.028948377817869186 count: 1 version: 6
# Episode 630, Score: -7.279999999999994, Epsilon: 0.030, loss: 0.024286935105919838 count: 1 version: 6
# Episode 631, Score: -2.7600000000000264, Epsilon: 0.030, loss: 0.025908034294843674 count: 1 version: 6
# Episode 632, Score: -8.199999999999978, Epsilon: 0.030, loss: 0.029219355434179306 count: 1 version: 6
# Episode 633, Score: -6.06000000000002, Epsilon: 0.030, loss: 0.02761918120086193 count: 1 version: 6
# Episode 634, Score: -6.120000000000019, Epsilon: 0.030, loss: 0.026127897202968597 count: 1 version: 6
# Episode 635, Score: -6.170000000000018, Epsilon: 0.030, loss: 0.02716097980737686 count: 1 version: 6
# Episode 636, Score: -3.020000000000021, Epsilon: 0.030, loss: 0.022373931482434273 count: 1 version: 6
# Episode 637, Score: -3.2300000000000164, Epsilon: 0.030, loss: 0.03114997036755085 count: 1 version: 6
# Episode 638, Score: -8.86999999999998, Epsilon: 0.030, loss: 0.028997022658586502 count: 1 version: 6
# Episode 639, Score: -7.179999999999996, Epsilon: 0.030, loss: 0.02903933823108673 count: 1 version: 6
# Episode 640, Score: -10.41999999999998, Epsilon: 0.030, loss: 0.02874869666993618 count: 1 version: 6
# Episode 641, Score: -6.260000000000016, Epsilon: 0.030, loss: 0.025349026545882225 count: 1 version: 6
# Episode 642, Score: -6.170000000000018, Epsilon: 0.030, loss: 0.028466416522860527 count: 1 version: 6
# Episode 643, Score: -4.099999999999998, Epsilon: 0.030, loss: 0.02870418317615986 count: 1 version: 6
# Episode 644, Score: -6.140000000000018, Epsilon: 0.030, loss: 0.02355719357728958 count: 1 version: 6
# Episode 645, Score: -7.669999999999986, Epsilon: 0.030, loss: 0.025050088763237 count: 1 version: 6
# Episode 646, Score: -7.609999999999987, Epsilon: 0.030, loss: 0.026898007839918137 count: 1 version: 6
# Episode 647, Score: -7.01, Epsilon: 0.030, loss: 0.029392967000603676 count: 1 version: 6
# Episode 648, Score: -6.100000000000019, Epsilon: 0.030, loss: 0.02349175699055195 count: 1 version: 6
# Episode 649, Score: -7.639999999999986, Epsilon: 0.030, loss: 0.02931636944413185 count: 1 version: 6
# Episode 650, Score: -4.219999999999995, Epsilon: 0.030, loss: 0.027217233553528786 count: 1 version: 6
# Episode 651, Score: -3.810000000000004, Epsilon: 0.030, loss: 0.027898788452148438 count: 1 version: 6
# Episode 652, Score: -3.3200000000000145, Epsilon: 0.030, loss: 0.026676837354898453 count: 1 version: 6
# Episode 653, Score: -5.699999999999964, Epsilon: 0.030, loss: 0.027691742405295372 count: 1 version: 6
# Episode 654, Score: 3.87999999999996, Epsilon: 0.030, loss: 0.025741292163729668 count: 1 version: 6
# Episode 655, Score: -5.880000000000024, Epsilon: 0.030, loss: 0.023823002353310585 count: 1 version: 6
# Episode 656, Score: -9.83, Epsilon: 0.030, loss: 0.025801092386245728 count: 1 version: 6
# Episode 657, Score: -7.309999999999993, Epsilon: 0.030, loss: 0.026612211018800735 count: 1 version: 6
# Episode 658, Score: -6.500000000000011, Epsilon: 0.030, loss: 0.0258743017911911 count: 1 version: 6
# Episode 659, Score: -8.029999999999978, Epsilon: 0.030, loss: 0.029083311557769775 count: 1 version: 6
# Episode 660, Score: -4.199999999999996, Epsilon: 0.030, loss: 0.027268873527646065 count: 1 version: 6
# Episode 661, Score: -3.1300000000000185, Epsilon: 0.030, loss: 0.02914290316402912 count: 1 version: 6
# Episode 662, Score: -5.940000000000023, Epsilon: 0.030, loss: 0.024931130930781364 count: 1 version: 6
# Episode 663, Score: 0.06999999999997719, Epsilon: 0.030, loss: 0.029874075204133987 count: 1 version: 6
# Episode 664, Score: -6.07000000000002, Epsilon: 0.030, loss: 0.027348680421710014 count: 1 version: 6
# Episode 665, Score: -3.290000000000015, Epsilon: 0.030, loss: 0.026537185534834862 count: 1 version: 6
# Episode 666, Score: -3.3700000000000134, Epsilon: 0.030, loss: 0.03410864248871803 count: 1 version: 6
# Episode 667, Score: -7.709999999999985, Epsilon: 0.030, loss: 0.029130877926945686 count: 1 version: 6
# Episode 668, Score: 6.239999999999906, Epsilon: 0.030, loss: 0.025791073217988014 count: 1 version: 6
# Episode 669, Score: -7.029999999999999, Epsilon: 0.030, loss: 0.027627671137452126 count: 1 version: 6
# Episode 670, Score: -9.95999999999998, Epsilon: 0.030, loss: 0.028665587306022644 count: 1 version: 6
# Episode 671, Score: -5.379999999999971, Epsilon: 0.030, loss: 0.029298480600118637 count: 1 version: 6
# Episode 672, Score: -3.7000000000000064, Epsilon: 0.030, loss: 0.031114839017391205 count: 1 version: 6
# Episode 673, Score: -6.100000000000019, Epsilon: 0.030, loss: 0.024826839566230774 count: 1 version: 6
# Episode 674, Score: -6.890000000000002, Epsilon: 0.030, loss: 0.026215801015496254 count: 1 version: 6
# Episode 675, Score: -5.560000000000031, Epsilon: 0.030, loss: 0.02974874898791313 count: 1 version: 6
# Episode 676, Score: -8.28999999999998, Epsilon: 0.030, loss: 0.030029861256480217 count: 1 version: 6
# Episode 677, Score: -3.6000000000000085, Epsilon: 0.030, loss: 0.02618229389190674 count: 1 version: 6
# Episode 678, Score: -6.1800000000000175, Epsilon: 0.030, loss: 0.02650933712720871 count: 1 version: 6
# Episode 679, Score: -8.109999999999978, Epsilon: 0.030, loss: 0.02751823328435421 count: 1 version: 6
# Episode 680, Score: -6.860000000000003, Epsilon: 0.030, loss: 0.035614483058452606 count: 1 version: 6
# Episode 681, Score: -5.860000000000024, Epsilon: 0.030, loss: 0.025504162535071373 count: 1 version: 6
# Episode 682, Score: -6.870000000000003, Epsilon: 0.030, loss: 0.029668129980564117 count: 1 version: 6
# Episode 683, Score: -3.010000000000021, Epsilon: 0.030, loss: 0.0310008954256773 count: 1 version: 6
# Episode 684, Score: -5.38999999999997, Epsilon: 0.030, loss: 0.027566304430365562 count: 1 version: 6
# Episode 685, Score: -2.780000000000026, Epsilon: 0.030, loss: 0.02588910609483719 count: 1 version: 6
# Episode 686, Score: -7.529999999999989, Epsilon: 0.030, loss: 0.028331147506833076 count: 1 version: 6
# Episode 687, Score: -7.109999999999998, Epsilon: 0.030, loss: 0.02582002989947796 count: 1 version: 6
# Episode 688, Score: -9.45999999999998, Epsilon: 0.030, loss: 0.027951925992965698 count: 1 version: 6
# Episode 689, Score: -7.589999999999987, Epsilon: 0.030, loss: 0.031222589313983917 count: 1 version: 6
# Episode 690, Score: -3.0300000000000207, Epsilon: 0.030, loss: 0.03095374070107937 count: 1 version: 6
# Episode 691, Score: 0.11999999999997613, Epsilon: 0.030, loss: 0.03180893510580063 count: 1 version: 6
# Episode 692, Score: -6.55000000000001, Epsilon: 0.030, loss: 0.028804095461964607 count: 1 version: 6
# Episode 693, Score: -7.359999999999992, Epsilon: 0.030, loss: 0.029215233400464058 count: 1 version: 6
# Episode 694, Score: -3.3700000000000134, Epsilon: 0.030, loss: 0.02939506433904171 count: 1 version: 6
# Episode 695, Score: -7.0699999999999985, Epsilon: 0.030, loss: 0.02790224179625511 count: 1 version: 6
# Episode 696, Score: -6.0400000000000205, Epsilon: 0.030, loss: 0.03040548972785473 count: 1 version: 6
# Episode 697, Score: -6.370000000000013, Epsilon: 0.030, loss: 0.02711488865315914 count: 1 version: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[321], line 117
#     114 state = next_state
#     116 if len(memory) >= BATCH_SIZE:
# --> 117     transitions = memory.sample(BATCH_SIZE)
#     118     batch = Transition(*zip(*transitions))
#     120     states = torch.stack(batch.state).to(device)
#
# Cell In[321], line 41, in ReplayMemory.sample(self, batch_size)
#      40 def sample(self, batch_size):
# ---> 41     return random.sample(self.memory, batch_size)
#
# File /opt/anaconda3/lib/python3.12/random.py:451, in Random.sample(self, population, k, counts)
#     449             j = randbelow(n)
#     450         selected_add(j)
# --> 451         result[i] = population[j]
#     452 return result
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
class game:
    def __init__(self,inner_points,outer_points,angle_list,start_point,draw_keys=True):
        self.draw_keys = draw_keys
        
        self.my_font = pygame.font.SysFont('Comic Sans MS', 30)

        self.checkpoint_score = 100
        self.speed_score_mult = 3
        
        self.start_point = start_point
        
        self.car = Car(self.start_point[0],self.start_point[1],180,1/60)
        self.inner_points = inner_points
        self.outer_points = outer_points
        
        self.action = (0,0)
        
        self.last_pos = (0,0)
        self.current_pos = (0,0)
        
        self.p3 = (0,0)
        self.p4 = (0,0)
        
        self.checkpoint_position = 0
        
        self.log = []
        
        self.current_point = 0
        self.total_score = 0
        
        SCREEN_WIDTH = 1600
        SCREEN_HEIGHT = 900
        
        self.track = RaceTrack(inner_points,outer_points)
        self.screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
        pygame.display.set_caption('Racing Car Simulation')
        
        self.line_list = []
        for angle in angle_list:
            self.line_list.append(extention_line(angle,self.car,self.outer_points,self.inner_points,self.screen))
            
        self.state = self.get_state()
            
        self.safe_update((0,0))
        
    def get_state(self):
        return [i.get_distance() for i in self.line_list] + [self.car.speed,self.car.car_angle,self.car.vector_angle,self.car.steering_angle,self.car.accel]
        
            
    def get_score(self):
        self.current_point = 0

        # Reward for reaching checkpoints
        self.p3 = self.inner_points[self.checkpoint_position % len(self.inner_points)]
        self.p4 = self.outer_points[self.checkpoint_position % len(self.outer_points)]
        if line_segments_intersection(self.last_pos, self.current_pos, self.p3, self.p4):
            self.current_point += self.checkpoint_score  # +100
            self.checkpoint_position += 1

        # Small reward for moving fast, encourage momentum
        self.current_point += self.speed_score_mult * self.car.get_speed()  # up to ~+3 per step

        # Bonus for staying alive (time alive reward)
        self.current_point += 1  # +1 for every frame survived

        # Penalty for standing still
        if self.car.get_speed() < 0.5:
            self.current_point -= 2  # discourage inactivity or stalling

        self.total_score += self.current_point
        
    def is_collided_with_track(self):
        for i in range(len(self.outer_points)):
            p1 = self.outer_points[i-1]
            p2 = self.outer_points[i]
            
            intersection = line_segments_intersection(p1,p2,self.current_pos,self.last_pos)
            if (intersection is not None):
                return True
                
        for i in range(len(self.inner_points)):
            p1 = self.inner_points[i-1]
            p2 = self.inner_points[i]
            
            intersection = line_segments_intersection(p1,p2,self.current_pos,self.last_pos)
            if (intersection is not None):
                return True
            
        return False
    
    def plot_checkpoint(self):
        pygame.draw.line(self.screen,(0,255,0),self.p3,self.p4)
    
    def log_score(self):
        score = self.current_point
        self.log.append([score,(self.action),self.get_state()])
    
    def take_action(self,action):
        if self.draw_keys:
            up = (1500,700)
            down = (1500,750)
            left = (1450,750)
            right = (1550,750)
            
            self.draw_key(False,up,25)
            self.draw_key(False,down,25)
            self.draw_key(False,left,25)
            self.draw_key(False,right,25)
        
        if action[0] == 1:
            self.car.speed_up()
            if self.draw_keys:
                self.draw_key(True,up,25)
            
        elif action[0] == -1:
            self.car.brake()
            if self.draw_keys:
                self.draw_key(True,down,25)
        else:
            self.car.nothing()
            
        if action[1] == 1:
            self.car.turn_left()
            if self.draw_keys:
                self.draw_key(True,left,25)
        elif action[1] == -1:
            self.car.turn_right()
            if self.draw_keys:
                self.draw_key(True,right,25)
        else:
            self.car.reset_turn()
            
        self.action = action

    
    def draw_key(self,filled,coor,side):
        if filled:
            pygame.draw.rect(self.screen,(255,255,255), pygame.Rect(coor[0],coor[1],side,side),width=0)
        else:
            pygame.draw.rect(self.screen,(255,255,255), pygame.Rect(coor[0],coor[1],side,side),width=1)
    
    def update(self, action_):
        self.last_pos = self.current_pos
        self.current_pos = self.car.get_pos()

        if self.draw_keys:
            self.screen.fill((0, 0, 0))  
            self.track.plot_track(self.screen)
            self.car.draw(self.screen)

        for line in self.line_list:
            line.update()
            if self.draw_keys:
                line.plot()

        self.take_action(action_)

        self.car.friction()
        self.car.calculate_all()
        self.car.update_position()

        self.plot_checkpoint() if self.draw_keys else None

        if self.is_collided_with_track():
            self.current_point = -5
            self.total_score += self.current_point
            return False

        self.get_score()
        self.log_score()

        if self.draw_keys:
            text_surface = self.my_font.render(str(self.total_score), True, (255, 255, 0))
            self.screen.blit(text_surface, (50, 50))
            pygame.display.update()
            pygame.time.Clock().tick(60)

        return True
    
    def safe_update(self, action_):
        self.last_pos = self.current_pos
        self.current_pos = self.car.get_pos()

        for line in self.line_list:
            line.update()

        self.take_action(action_)
        self.car.friction()
        self.car.calculate_all()
        self.car.update_position()
        self.get_score()
        self.log_score()

            
    def return_log(self):
        return self.log
    
    def return_total_score(self):
        return self.total_score
    
    def return_score(self):
        return self.current_point

# %%
pygame.init()
pygame.font.init()

my_font = pygame.font.SysFont('Comic Sans MS', 30)

policy_dqn = DQN(20, 9).to(device)
policy_dqn.load_state_dict(torch.load("/Users/ard/Desktop/Coding_2/F1_laptime_project/policies_5/policy_no_5-49.pth"))

angle_list = [angle*30 for angle in range(12)]

x,y,angle,check = calculate_start()
newgame = game(inner_points, outer_points, angle_list,(x, y), test,check,angle)

state = newgame.get_state()
done = False

while not done:
    state =  newgame.get_state()
    action = select_action(state, 0.1)
    done = not newgame.update(actions[action])
