# %%
import numpy as np
import pandas as pd
import pygame 
import math
import matplotlib.pyplot as plt
import json
import random

import torch
import torch.nn as nn
import torch.nn.functional as F

from collections import namedtuple, deque
import torch.optim as optim

import tensorflow as tf

# %%
class Car:
    def __init__(self,initial_x,initial_y,initial_angle,time_elapsed):
        self.x = initial_x
        self.y = initial_y
        self.time_elapsed = time_elapsed
        
        self.speed = 1
        self.vector_angle = initial_angle
        
        self.car_angle = initial_angle
        
        self.steering_angle = 0
        self.accel = 0

        self.grip = 3
        self.steering_grip = 1.5 
        
        self.CAR_WIDTH = 20
        self.CAR_HEIGHT = 10
        self.CAR_COLOR = (0, 255, 0)
        
        self.max_angle = 80
        self.max_speed = 8
        
        self.friction_coef = 0.01
        
        self.accel_const = 0.1 
        self.brake_const = 0.1
        self.steering_const = 10
        
    def calculate_all(self):
        self.car_angle = self.car_angle * (1-self.steering_grip*self.time_elapsed) + (self.steering_angle+self.car_angle) * self.steering_grip*self.time_elapsed
        self.vector_angle = self.vector_angle * (1-self.grip*self.time_elapsed) + self.car_angle * self.grip*self.time_elapsed
        
        potential_speed = self.speed+self.accel*self.time_elapsed
        
        if((potential_speed < self.max_speed)&(potential_speed > 0)):
            self.speed = self.speed+self.accel*self.time_elapsed
        
    def update_position(self):
        self.x = self.x + self.speed*np.cos(np.radians(self.vector_angle))
        self.y = self.y + self.speed*np.sin(np.radians(self.vector_angle))
        
    def speed_up(self):
        self.accel += self.accel_const
        
    def brake(self):
        self.accel -= self.speed*self.brake_const
        
    def nothing(self):
        self.accel = 0

    def friction(self):
        self.speed -= self.speed*self.friction_coef
        
    def turn_right(self):
        if(self.steering_angle < self.max_angle):
            self.steering_angle += self.steering_const
        else:
            self.steering_angle = self.max_angle
            
    def reset_turn(self):
        if(np.abs(self.steering_angle)  < 1):
            self.steering_angle =0
        elif(self.steering_angle<0):
            self.steering_angle +=self.steering_const
        elif(self.steering_angle>0):
            self.steering_angle -=self.steering_const

    def turn_left(self):
        if(self.steering_angle > -self.max_angle):
            self.steering_angle -= self.steering_const
        else:
            self.steering_angle = -self.max_angle

    def draw(self, screen):
        car_surf = pygame.Surface((self.CAR_WIDTH, self.CAR_HEIGHT), pygame.SRCALPHA)
        car_surf.fill(self.CAR_COLOR)
        rotated_car = pygame.transform.rotate(car_surf, -self.car_angle)
        screen.blit(rotated_car, (self.x - rotated_car.get_width() / 2, self.y - rotated_car.get_height() / 2))
        
    def reset_all(self):
        self.x = 0
        self.y = 0
        
        self.speed = 0
        self.vector_angle = 0
        
        self.car_angle = 0
        
        self.steering_angle = 0
        self.accel = 0
        
    def get_vals(self):
        return self.x,self.y,self.car_angle
    
    def get_pos(self):
        return (self.x,self.y)

    def get_speed(self):
        return self.speed

# %%
class extention_line:
    
    def __init__(self,angle,car:Car,outside_line,inside_line,screen):
      self.angle_from_car = angle
      self.car = car
      self.outside_line = outside_line
      self.inside_line = inside_line
      self.shortest_point = (0,0)
      self.screen = screen
      self.smallest = (0,(0,0))
    
    def get_distance(self):
        return self.smallest[0]
    
    def update(self):
        self.x,self.y,self.angle = self.car.get_vals()
        self.point1,self.point2= self.generate_long_segment_from_point((self.x,self.y),self.angle+self.angle_from_car)
        self.shortest_point = self.shortest_intersection()
    
    def plot(self):
        pygame.draw.line(self.screen,(255,255,255),self.point1,self.point2)
        pygame.draw.circle(self.screen,(255,0,0),self.shortest_point,10)
        
    def find_dist(self,x,y):

        return np.sqrt((x-self.car.x)**2+(y-self.car.y)**2)
    
    def shortest_intersection(self):
        point_list = []
        for i in range(len(self.outside_line)):
            p1 = self.outside_line[i-1]
            p2 = self.outside_line[i]
            
            intersection = line_segments_intersection(p1,p2,self.point1,self.point2)
            if (intersection is not None):
                point_list.append((self.find_dist(intersection[0],intersection[1]),intersection))
                
        for i in range(len(self.inside_line)):
            p1 = self.inside_line[i-1]
            p2 = self.inside_line[i]
            
            intersection = line_segments_intersection(p1,p2,self.point1,self.point2)
            if (intersection is not None):
                point_list.append((self.find_dist(intersection[0],intersection[1]),intersection))
                
        if len(point_list) > 0:
            self.smallest = min(point_list, key=lambda i: i[0])

            return self.smallest[1]
        else:
            return self.smallest[1]           
    
    def generate_long_segment_from_point(self,point, angle_degrees, length=10000):
        x, y = point
        angle_radians = math.radians(angle_degrees)

        dx = math.cos(angle_radians) * length
        dy = math.sin(angle_radians) * length

        end_point = (x + dx, y + dy)
        return point, end_point

def line_segments_intersection(p1, p2, p3, p4):
        x1, y1 = p1
        x2, y2 = p2
        x3, y3 = p3
        x4, y4 = p4

        denom = (y4 - y3)*(x2 - x1) - (x4 - x3)*(y2 - y1)

        if denom == 0:
            return None

        t = ((x4 - x3)*(y1 - y3) - (y4 - y3)*(x1 - x3)) / denom
        u = ((x2 - x1)*(y1 - y3) - (y2 - y1)*(x1 - x3)) / denom

        if 0 <= t <= 1 and 0 <= u <= 1:
            intersect_x = x1 + t * (x2 - x1)
            intersect_y = y1 + t * (y2 - y1)
            return (intersect_x, intersect_y)

        return None

# %%
class RaceTrack:
    def __init__(self,inner_points,outer_points):
        self.inner_points = inner_points
        self.outer_points = outer_points
        
        self.track_color = (50,50,50)
        self.border_color = (255,90,90)
        self.inner_color = (255,255,255)
    
    def plot_track(self,surface):
        pygame.draw.polygon(surface,self.track_color,self.outer_points,0)
        pygame.draw.polygon(surface,self.inner_color,self.inner_points,0)
        pygame.draw.lines(surface,self.border_color,True,self.inner_points,5)
        pygame.draw.lines(surface,self.border_color,True,self.outer_points,5)

# %%
def generate_track(centerline, width=100):
    inner = []
    outer = []
    n = len(centerline)
    for i in range(n):
        p1 = centerline[i - 1]
        p2 = centerline[i]
        p3 = centerline[(i + 1) % n]

        # Calculate the direction between p1 and p3 (smoothed)
        dx = p3[0] - p1[0]
        dy = p3[1] - p1[1]
        length = math.hypot(dx, dy)
        if length == 0:
            perp_dx, perp_dy = 0, 0
        else:
            perp_dx = -dy / length
            perp_dy = dx / length

        offset_x = perp_dx * width / 2
        offset_y = perp_dy * width / 2

        inner.append((p2[0] - offset_x, p2[1] - offset_y))
        outer.append((p2[0] + offset_x, p2[1] + offset_y))
    
    return inner, outer

# %%
centerline = [(671.6, 115.5),
(541.7, 120.3),
(402.0, 114.6),
(248.2, 124.1),
(193.1, 177.1),
(184.7, 262.3),
(172.0, 351.3),
(119.8, 441.3),
(111.3, 527.5),
(111.3, 602.3),
(124.0, 694.1),
(183.3, 757.6),
(320.2, 784.1),
(442.9, 792.6),
(579.8, 787.9),
(721.0, 785.0),
(846.6, 784.1),
(962.3, 782.2),
(1104.8, 780.3),
(1257.3, 782.2),
(1367.3, 772.7),
(1457.7, 720.6),
(1450.6, 643.0),
(1404.0, 598.5),
(1267.1, 562.5),
(1119.0, 556.8),
(969.4, 563.4),
(859.3, 583.3),
(705.4, 616.5),
(541.7, 647.7),
(410.5, 607.0),
(366.7, 525.6),
(378.0, 449.8),
(465.5, 398.7),
(582.7, 385.4),
(665.9, 402.5),
(737.9, 426.1),
(785.9, 435.6),
(840.9, 425.2),
(874.8, 401.5),
(900.2, 367.4),
(949.6, 344.7),
(1021.6, 348.5),
(1082.3, 370.3),
(1134.5, 404.4),
(1176.8, 430.9),
(1250.2, 455.5),
(1320.8, 435.6),
(1346.2, 378.8),
(1337.7, 310.6),
(1302.4, 269.9),
(1248.8, 224.4),
(1117.5, 181.8),
(996.2, 151.5),
(736.5, 119.3),]

# %%
class game:
    def __init__(self,inner_points,outer_points,angle_list,start_point,draw_keys=True):
        self.draw_keys = draw_keys
        
        self.my_font = pygame.font.SysFont('Comic Sans MS', 30)

        self.checkpoint_score = 1
        self.speed_score_mult = 0.03
        
        self.start_point = start_point
        
        self.car = Car(self.start_point[0],self.start_point[1],180,1/60)
        self.inner_points = inner_points
        self.outer_points = outer_points
        
        self.action = (0,0)
        
        self.last_pos = (0,0)
        self.current_pos = (0,0)
        
        self.p3 = (0,0)
        self.p4 = (0,0)
        
        self.checkpoint_position = 0
        
        self.log = []
        
        self.current_point = 0
        self.total_score = 0
        
        SCREEN_WIDTH = 1600
        SCREEN_HEIGHT = 900
        
        self.track = RaceTrack(inner_points,outer_points)
        self.screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
        pygame.display.set_caption('Racing Car Simulation')
        
        self.line_list = []
        for angle in angle_list:
            self.line_list.append(extention_line(angle,self.car,self.outer_points,self.inner_points,self.screen))
            
        self.state = self.get_state()
            
        self.safe_update((0,0))
        
    def get_state(self):
        distances = [i.get_distance() for i in self.line_list]
        MAX_DISTANCE = 1835
        [
            dist / MAX_DISTANCE for dist in distances      # scale distances
        ] + [
            self.car.speed / self.car.max_speed,                             # scale speed
            math.sin(self.car.car_angle), math.cos(self.car.car_angle),      # encode angles
            math.sin(self.car.vector_angle), math.cos(self.car.vector_angle),
            math.sin(self.car.steering_angle), math.cos(self.car.steering_angle),
            self.car.accel                                          # usually small, like -1 to +1
        ]
            
    def get_score(self):
        self.current_point = 0

        # Reward for reaching checkpoints
        self.p3 = self.inner_points[self.checkpoint_position % len(self.inner_points)]
        self.p4 = self.outer_points[self.checkpoint_position % len(self.outer_points)]
        if line_segments_intersection(self.last_pos, self.current_pos, self.p3, self.p4):
            self.current_point += self.checkpoint_score  # +100
            self.checkpoint_position += 1

        # Small reward for moving fast, encourage momentum
        self.current_point += self.speed_score_mult * self.car.get_speed()  # up to ~+3 per step

        # Bonus for staying alive (time alive reward)
        self.current_point += 1  # +1 for every frame survived

        # Penalty for standing still
        if self.car.get_speed() < 0.5:
            self.current_point -= 2  # discourage inactivity or stalling

        self.total_score += self.current_point
        
    def is_collided_with_track(self):
        for i in range(len(self.outer_points)):
            p1 = self.outer_points[i-1]
            p2 = self.outer_points[i]
            
            intersection = line_segments_intersection(p1,p2,self.current_pos,self.last_pos)
            if (intersection is not None):
                return True
                
        for i in range(len(self.inner_points)):
            p1 = self.inner_points[i-1]
            p2 = self.inner_points[i]
            
            intersection = line_segments_intersection(p1,p2,self.current_pos,self.last_pos)
            if (intersection is not None):
                return True
            
        return False
    
    def plot_checkpoint(self):
        pygame.draw.line(self.screen,(0,255,0),self.p3,self.p4)
    
    def log_score(self):
        score = self.current_point
        self.log.append([score,(self.action),self.get_state()])
    
    def take_action(self,action):
        if self.draw_keys:
            up = (1500,700)
            down = (1500,750)
            left = (1450,750)
            right = (1550,750)
            
            self.draw_key(False,up,25)
            self.draw_key(False,down,25)
            self.draw_key(False,left,25)
            self.draw_key(False,right,25)
        
        if action[0] == 1:
            self.car.speed_up()
            if self.draw_keys:
                self.draw_key(True,up,25)
            
        elif action[0] == -1:
            self.car.brake()
            if self.draw_keys:
                self.draw_key(True,down,25)
        else:
            self.car.nothing()
            
        if action[1] == 1:
            self.car.turn_left()
            if self.draw_keys:
                self.draw_key(True,left,25)
        elif action[1] == -1:
            self.car.turn_right()
            if self.draw_keys:
                self.draw_key(True,right,25)
        else:
            self.car.reset_turn()
            
        self.action = action

    
    def draw_key(self,filled,coor,side):
        if filled:
            pygame.draw.rect(self.screen,(255,255,255), pygame.Rect(coor[0],coor[1],side,side),width=0)
        else:
            pygame.draw.rect(self.screen,(255,255,255), pygame.Rect(coor[0],coor[1],side,side),width=1)
    
    def update(self, action_):
        self.last_pos = self.current_pos
        self.current_pos = self.car.get_pos()

        if self.draw_keys:
            self.screen.fill((0, 0, 0))  
            self.track.plot_track(self.screen)
            self.car.draw(self.screen)

        for line in self.line_list:
            line.update()
            if self.draw_keys:
                line.plot()

        self.take_action(action_)

        self.car.friction()
        self.car.calculate_all()
        self.car.update_position()

        self.plot_checkpoint() if self.draw_keys else None

        if self.is_collided_with_track():
            self.current_point = -5
            self.total_score += self.current_point
            return False

        self.get_score()
        self.log_score()

        if self.draw_keys:
            text_surface = self.my_font.render(str(self.total_score), True, (255, 255, 0))
            self.screen.blit(text_surface, (50, 50))
            pygame.display.update()
            pygame.time.Clock().tick(60)

        return True
    
    def safe_update(self, action_):
        self.last_pos = self.current_pos
        self.current_pos = self.car.get_pos()

        for line in self.line_list:
            line.update()

        self.take_action(action_)
        self.car.friction()
        self.car.calculate_all()
        self.car.update_position()
        self.get_score()
        self.log_score()

            
    def return_log(self):
        return self.log
    
    def return_total_score(self):
        return self.total_score
    
    def return_score(self):
        return self.current_point

# %%
inner_points,outer_points = generate_track(centerline,100)

# %%
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.out(x)
    
    
Transition = namedtuple('Transition',('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
angle_list = [angle*30 for angle in range(0,12)]

# %%
count = 19
version = 46

# %%
import pygame
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import namedtuple, deque

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

GAMMA = 0.999
LR = 0.0001
BATCH_SIZE = 256
MEMORY_SIZE = 500_000

EPS_START = 1.0
EPS_END = 0.05
EPS_DECAY = 0.995   # if per step (else 0.99 if per episode)

TARGET_UPDATE = 500  # or 1000 if per step
EPISODES = 25000
TIME = 1000

# Actions
actions = [(-1, -1), (-1, 0), (-1, 1),
           (0, -1), (0, 0), (0, 1),
           (1, -1), (1, 0), (1, 1)]

# Transition tuple
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward', 'done'))

# Replay memory class
class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# DQN model
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 64)
        self.out = nn.Linear(64, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        return self.out(x)

# Initialize

path_name = "/Users/ard/Desktop/Coding_2/F1_laptime_project/policies/policy_no_"

loss_list = []
while True:
    TIME += 100
    memory = ReplayMemory(MEMORY_SIZE)
    policy_dqn = DQN(17, 9).to(device)
    target_dqn = DQN(17, 9).to(device)
    
    try:
        policy_dqn.load_state_dict(torch.load(path_name+str(count)+"-"+str(version)+".pth"))
    except:
        pass
    count+=1
    target_dqn.load_state_dict(policy_dqn.state_dict())
    target_dqn.eval()

    optimizer = optim.Adam(policy_dqn.parameters(), lr=LR)
    criterion = nn.SmoothL1Loss()

    epsilon = EPS_START
    EPS_START = max([EPS_START*0.9,EPS_END])

    def select_action(state, epsilon):
        if random.random() < epsilon:
            return random.randint(0, 8)
        with torch.no_grad():
            state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            return policy_dqn(state).argmax(dim=1).item()
        
    scorelist = []
    version = 0
    for episode in range(EPISODES):
        test = (episode % 100 == 0)
        newgame = game(inner_points, outer_points, angle_list,(random.randint(780,820), random.randint(100, 150)), test)
        state = newgame.get_state()
        
        episode_loss = []

        for t in range(TIME):
            action = select_action(state, 0.0 if test else epsilon)
            done = not newgame.update(actions[action])
            reward = newgame.return_score()
            next_state = newgame.get_state()

            memory.push(torch.tensor(state, dtype=torch.float32),
                        action,
                        torch.tensor(next_state, dtype=torch.float32),
                        reward,
                        done)

            state = next_state

            if len(memory) >= BATCH_SIZE:
                transitions = memory.sample(BATCH_SIZE)
                batch = Transition(*zip(*transitions))

                states = torch.stack(batch.state).to(device)
                actions_batch = torch.tensor(batch.action, dtype=torch.long).to(device)
                rewards = torch.tensor(batch.reward, dtype=torch.float32).to(device)
                next_states = torch.stack(batch.next_state).to(device)
                dones = torch.tensor(batch.done, dtype=torch.float32).to(device)

                q_values = policy_dqn(states).gather(1, actions_batch.unsqueeze(1)).squeeze(1)
                next_q_values = target_dqn(next_states).max(1)[0]
                expected_q_values = rewards + GAMMA * next_q_values * (1 - dones)

                loss = criterion(q_values, expected_q_values.detach())
                episode_loss.append(loss.detach().numpy())
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            if done:
                break

        epsilon = max(EPS_END, epsilon * EPS_DECAY)

        if episode % TARGET_UPDATE == 0:
            target_dqn.load_state_dict(policy_dqn.state_dict())
            torch.save(policy_dqn.state_dict(), path_name+str(count)+"-"+str(version)+".pth")
            version += 1
            scorelist.append(newgame.return_total_score())
        loss_list.append(episode_loss)

        print(f"Episode {episode + 1}, Score: {newgame.return_total_score()}, Epsilon: {epsilon:.3f}, loss: {np.mean(episode_loss)} count: {count} version: {version}")
# Out:
# Episode 1, Score: -309.1693373513215, Epsilon: 0.995, loss: 1.2757450342178345 count: 20 version: 1
# Episode 2, Score: -152.09184676145173, Epsilon: 0.990, loss: 3.810534715652466 count: 20 version: 1
# Episode 3, Score: -301.55765699784644, Epsilon: 0.985, loss: 4.276900768280029 count: 20 version: 1
# Episode 4, Score: -193.13603134906973, Epsilon: 0.980, loss: 3.7686941623687744 count: 20 version: 1
# Episode 5, Score: -190.19830620047983, Epsilon: 0.975, loss: 3.0303661823272705 count: 20 version: 1
# Episode 6, Score: -249.1838207919445, Epsilon: 0.970, loss: 3.0650341510772705 count: 20 version: 1
# Episode 7, Score: -573.8561457087809, Epsilon: 0.966, loss: 3.091226816177368 count: 20 version: 1
# Episode 8, Score: -253.31038417400083, Epsilon: 0.961, loss: 3.2130260467529297 count: 20 version: 1
# Episode 9, Score: -382.6615941456765, Epsilon: 0.956, loss: 3.382078170776367 count: 20 version: 1
# Episode 10, Score: -315.43778221083744, Epsilon: 0.951, loss: 3.4420108795166016 count: 20 version: 1
# Episode 11, Score: -364.79559884422173, Epsilon: 0.946, loss: 3.57253360748291 count: 20 version: 1
# Episode 12, Score: -364.84969563086236, Epsilon: 0.942, loss: 3.503629207611084 count: 20 version: 1
# Episode 13, Score: -628.8479003950952, Epsilon: 0.937, loss: 3.576848030090332 count: 20 version: 1
# Episode 14, Score: -149.38712213303285, Epsilon: 0.932, loss: 3.5214788913726807 count: 20 version: 1
# Episode 15, Score: -83.05647459628752, Epsilon: 0.928, loss: 3.6407835483551025 count: 20 version: 1
# Episode 16, Score: -120.51417501159835, Epsilon: 0.923, loss: 3.692044496536255 count: 20 version: 1
# Episode 17, Score: -120.22046756357622, Epsilon: 0.918, loss: 3.6078543663024902 count: 20 version: 1
# Episode 18, Score: -73.15282629010584, Epsilon: 0.914, loss: 3.552713394165039 count: 20 version: 1
# Episode 19, Score: -229.09850814805094, Epsilon: 0.909, loss: 3.504265546798706 count: 20 version: 1
# Episode 20, Score: -237.67802260365966, Epsilon: 0.905, loss: 3.6472036838531494 count: 20 version: 1
# Episode 21, Score: -170.07107308093174, Epsilon: 0.900, loss: 3.66313099861145 count: 20 version: 1
# Episode 22, Score: -331.29560365365586, Epsilon: 0.896, loss: 3.7497520446777344 count: 20 version: 1
# Episode 23, Score: -116.40898647372882, Epsilon: 0.891, loss: 3.8668370246887207 count: 20 version: 1
# Episode 24, Score: -146.8076772574446, Epsilon: 0.887, loss: 3.838350296020508 count: 20 version: 1
# Episode 25, Score: -158.41547217309937, Epsilon: 0.882, loss: 3.8556060791015625 count: 20 version: 1
# Episode 26, Score: -197.1581661104496, Epsilon: 0.878, loss: 3.9796242713928223 count: 20 version: 1
# Episode 27, Score: -228.4622582148557, Epsilon: 0.873, loss: 3.9859507083892822 count: 20 version: 1
# Episode 28, Score: -400.99094752594937, Epsilon: 0.869, loss: 4.0264482498168945 count: 20 version: 1
# Episode 29, Score: -161.9783516176443, Epsilon: 0.865, loss: 3.999846935272217 count: 20 version: 1
# Episode 30, Score: -370.0177531347639, Epsilon: 0.860, loss: 4.058085918426514 count: 20 version: 1
# Episode 31, Score: -114.40946815052625, Epsilon: 0.856, loss: 4.246988773345947 count: 20 version: 1
# Episode 32, Score: -87.7389945605558, Epsilon: 0.852, loss: 4.3208537101745605 count: 20 version: 1
# Episode 33, Score: -421.3754792134727, Epsilon: 0.848, loss: 4.20472526550293 count: 20 version: 1
# Episode 34, Score: -125.80023577192583, Epsilon: 0.843, loss: 4.265806674957275 count: 20 version: 1
# Episode 35, Score: -198.5154024648669, Epsilon: 0.839, loss: 4.2926411628723145 count: 20 version: 1
# Episode 36, Score: -240.8406661929481, Epsilon: 0.835, loss: 4.383772850036621 count: 20 version: 1
# Episode 37, Score: -183.099634547022, Epsilon: 0.831, loss: 4.404209136962891 count: 20 version: 1
# Episode 38, Score: -228.59461506617328, Epsilon: 0.827, loss: 4.364354133605957 count: 20 version: 1
# Episode 39, Score: -383.6497717972358, Epsilon: 0.822, loss: 4.366164684295654 count: 20 version: 1
# Episode 40, Score: -49.030033501197046, Epsilon: 0.818, loss: 4.41351318359375 count: 20 version: 1
# Episode 41, Score: -221.82417816336965, Epsilon: 0.814, loss: 4.514891147613525 count: 20 version: 1
# Episode 42, Score: -142.7072871402372, Epsilon: 0.810, loss: 4.474472999572754 count: 20 version: 1
# Episode 43, Score: -209.3050079983563, Epsilon: 0.806, loss: 4.550779819488525 count: 20 version: 1
# Episode 44, Score: -176.2634740608475, Epsilon: 0.802, loss: 4.518130302429199 count: 20 version: 1
# Episode 45, Score: -137.6821800305574, Epsilon: 0.798, loss: 4.50361967086792 count: 20 version: 1
# Episode 46, Score: 32.48069367138522, Epsilon: 0.794, loss: 4.522017955780029 count: 20 version: 1
# Episode 47, Score: -234.20118816255626, Epsilon: 0.790, loss: 4.613589286804199 count: 20 version: 1
# Episode 48, Score: -78.04863011266795, Epsilon: 0.786, loss: 4.499413967132568 count: 20 version: 1
# Episode 49, Score: -78.05899883022727, Epsilon: 0.782, loss: 4.461029052734375 count: 20 version: 1
# Episode 50, Score: -180.93801086782406, Epsilon: 0.778, loss: 4.566839694976807 count: 20 version: 1
# Episode 51, Score: -108.30451356145409, Epsilon: 0.774, loss: 4.502373218536377 count: 20 version: 1
# Episode 52, Score: -141.2835377511011, Epsilon: 0.771, loss: 4.577945709228516 count: 20 version: 1
# Episode 53, Score: -83.76404926769766, Epsilon: 0.767, loss: 4.598721981048584 count: 20 version: 1
# Episode 54, Score: -276.9220156576488, Epsilon: 0.763, loss: 4.500096321105957 count: 20 version: 1
# Episode 55, Score: -168.61228004464942, Epsilon: 0.759, loss: 4.6611738204956055 count: 20 version: 1
# Episode 56, Score: -49.6564463884128, Epsilon: 0.755, loss: 4.605319499969482 count: 20 version: 1
# Episode 57, Score: -128.9510591909853, Epsilon: 0.751, loss: 4.473017692565918 count: 20 version: 1
# Episode 58, Score: 3.8449965868653067, Epsilon: 0.748, loss: 4.701494216918945 count: 20 version: 1
# Episode 59, Score: 16.915229114189742, Epsilon: 0.744, loss: 4.713202476501465 count: 20 version: 1
# Episode 60, Score: -156.66503436906646, Epsilon: 0.740, loss: 4.793332099914551 count: 20 version: 1
# Episode 61, Score: -135.82314117102908, Epsilon: 0.737, loss: 4.690558433532715 count: 20 version: 1
# Episode 62, Score: -279.21555960385865, Epsilon: 0.733, loss: 4.730901718139648 count: 20 version: 1
# Episode 63, Score: -97.99227403165094, Epsilon: 0.729, loss: 4.743418216705322 count: 20 version: 1
# Episode 64, Score: -42.39450401005985, Epsilon: 0.726, loss: 4.765250205993652 count: 20 version: 1
# Episode 65, Score: -148.9290876574966, Epsilon: 0.722, loss: 4.823787212371826 count: 20 version: 1
# Episode 66, Score: -20.743574409427993, Epsilon: 0.718, loss: 4.656589984893799 count: 20 version: 1
# Episode 67, Score: -23.696159119533206, Epsilon: 0.715, loss: 4.771416664123535 count: 20 version: 1
# Episode 68, Score: -168.70605383119482, Epsilon: 0.711, loss: 4.78477668762207 count: 20 version: 1
# Episode 69, Score: 116.56942499088575, Epsilon: 0.708, loss: 4.772494316101074 count: 20 version: 1
# Episode 70, Score: -43.82573259849863, Epsilon: 0.704, loss: 4.747249603271484 count: 20 version: 1
# Episode 71, Score: 61.23020842877679, Epsilon: 0.701, loss: 4.815425872802734 count: 20 version: 1
# Episode 72, Score: -148.89272451789384, Epsilon: 0.697, loss: 4.881605625152588 count: 20 version: 1
# Episode 73, Score: -76.63137476401596, Epsilon: 0.694, loss: 4.823015213012695 count: 20 version: 1
# Episode 74, Score: -63.287228452750924, Epsilon: 0.690, loss: 4.662405967712402 count: 20 version: 1
# Episode 75, Score: -114.1971847439712, Epsilon: 0.687, loss: 4.732154369354248 count: 20 version: 1
# Episode 76, Score: -144.3702024533796, Epsilon: 0.683, loss: 4.7913665771484375 count: 20 version: 1
# Episode 77, Score: -58.15806990606088, Epsilon: 0.680, loss: 4.834866046905518 count: 20 version: 1
# Episode 78, Score: -103.69582546926074, Epsilon: 0.676, loss: 4.9563493728637695 count: 20 version: 1
# Episode 79, Score: -174.69695283784756, Epsilon: 0.673, loss: 4.989683628082275 count: 20 version: 1
# Episode 80, Score: -42.70138692207712, Epsilon: 0.670, loss: 5.099348545074463 count: 20 version: 1
# Episode 81, Score: -67.36876540481148, Epsilon: 0.666, loss: 4.886587619781494 count: 20 version: 1
# Episode 82, Score: -178.26064551316853, Epsilon: 0.663, loss: 4.957146644592285 count: 20 version: 1
# Episode 83, Score: -162.2948411073408, Epsilon: 0.660, loss: 4.9011759757995605 count: 20 version: 1
# Episode 84, Score: -221.91436818476114, Epsilon: 0.656, loss: 4.926303863525391 count: 20 version: 1
# Episode 85, Score: -29.78765313955836, Epsilon: 0.653, loss: 5.011947154998779 count: 20 version: 1
# Episode 86, Score: -78.46402622717443, Epsilon: 0.650, loss: 4.942983627319336 count: 20 version: 1
# Episode 87, Score: -17.53288424947931, Epsilon: 0.647, loss: 5.018037796020508 count: 20 version: 1
# Episode 88, Score: 200.85180227064848, Epsilon: 0.643, loss: 4.853589057922363 count: 20 version: 1
# Episode 89, Score: -77.77836146962915, Epsilon: 0.640, loss: 4.861294269561768 count: 20 version: 1
# Episode 90, Score: -250.01298398419658, Epsilon: 0.637, loss: 4.954664707183838 count: 20 version: 1
# Episode 91, Score: -130.8589521836144, Epsilon: 0.634, loss: 4.996396064758301 count: 20 version: 1
# Episode 92, Score: -61.550476871627154, Epsilon: 0.631, loss: 5.002694606781006 count: 20 version: 1
# Episode 93, Score: 21.46012737674812, Epsilon: 0.627, loss: 5.103222846984863 count: 20 version: 1
# Episode 94, Score: -147.83299781334995, Epsilon: 0.624, loss: 5.015738010406494 count: 20 version: 1
# Episode 95, Score: -23.9451388790834, Epsilon: 0.621, loss: 4.989573955535889 count: 20 version: 1
# Episode 96, Score: -20.270751951694592, Epsilon: 0.618, loss: 5.040339469909668 count: 20 version: 1
# Episode 97, Score: 30.251615512542003, Epsilon: 0.615, loss: 5.020171642303467 count: 20 version: 1
# Episode 98, Score: -86.42908275481642, Epsilon: 0.612, loss: 5.017414093017578 count: 20 version: 1
# Episode 99, Score: -94.70282422315955, Epsilon: 0.609, loss: 5.0974907875061035 count: 20 version: 1
# Episode 100, Score: -108.55968942154624, Epsilon: 0.606, loss: 4.982057094573975 count: 20 version: 1
# Episode 101, Score: 1003.1922206213135, Epsilon: 0.603, loss: 5.103951454162598 count: 20 version: 1
# Episode 102, Score: -57.039843089060014, Epsilon: 0.600, loss: 5.116516590118408 count: 20 version: 1
# Episode 103, Score: -34.13800264048143, Epsilon: 0.597, loss: 5.175352573394775 count: 20 version: 1
# Episode 104, Score: 48.09682850580248, Epsilon: 0.594, loss: 4.983522891998291 count: 20 version: 1
# Episode 105, Score: -151.88653156874676, Epsilon: 0.591, loss: 5.085801601409912 count: 20 version: 1
# Episode 106, Score: -17.88894339723879, Epsilon: 0.588, loss: 5.269468307495117 count: 20 version: 1
# Episode 107, Score: -131.01189276707476, Epsilon: 0.585, loss: 5.114777565002441 count: 20 version: 1
# Episode 108, Score: -67.6929194162517, Epsilon: 0.582, loss: 5.076714992523193 count: 20 version: 1
# Episode 109, Score: -5.821638000839187, Epsilon: 0.579, loss: 5.1716628074646 count: 20 version: 1
# Episode 110, Score: -97.06356908388642, Epsilon: 0.576, loss: 5.175113677978516 count: 20 version: 1
# Episode 111, Score: -87.88994820027608, Epsilon: 0.573, loss: 4.927356719970703 count: 20 version: 1
# Episode 112, Score: 107.72739180772658, Epsilon: 0.570, loss: 5.063930988311768 count: 20 version: 1
# Episode 113, Score: 49.77986969603421, Epsilon: 0.568, loss: 5.0791015625 count: 20 version: 1
# Episode 114, Score: -65.83226598236502, Epsilon: 0.565, loss: 5.033520698547363 count: 20 version: 1
# Episode 115, Score: -112.6254472838661, Epsilon: 0.562, loss: 5.114683628082275 count: 20 version: 1
# Episode 116, Score: -168.1563145729353, Epsilon: 0.559, loss: 4.978107929229736 count: 20 version: 1
# Episode 117, Score: -99.34870840667418, Epsilon: 0.556, loss: 5.079148769378662 count: 20 version: 1
# Episode 118, Score: -97.98256727976292, Epsilon: 0.554, loss: 5.227611541748047 count: 20 version: 1
# Episode 119, Score: -2.807245267269991, Epsilon: 0.551, loss: 4.953400135040283 count: 20 version: 1
# Episode 120, Score: -77.79578333105536, Epsilon: 0.548, loss: 5.161787509918213 count: 20 version: 1
# Episode 121, Score: 75.44202043991095, Epsilon: 0.545, loss: 5.2382025718688965 count: 20 version: 1
# Episode 122, Score: -91.10605087740646, Epsilon: 0.543, loss: 5.096963882446289 count: 20 version: 1
# Episode 123, Score: -26.65840506819876, Epsilon: 0.540, loss: 5.232190132141113 count: 20 version: 1
# Episode 124, Score: 361.2685248373683, Epsilon: 0.537, loss: 5.164403915405273 count: 20 version: 1
# Episode 125, Score: 329.96358586915983, Epsilon: 0.534, loss: 5.136785984039307 count: 20 version: 1
# Episode 126, Score: -425.0535746756779, Epsilon: 0.532, loss: 5.185938358306885 count: 20 version: 1
# Episode 127, Score: 85.98708225245855, Epsilon: 0.529, loss: 5.292472839355469 count: 20 version: 1
# Episode 128, Score: -57.228260575158345, Epsilon: 0.526, loss: 5.159909725189209 count: 20 version: 1
# Episode 129, Score: -28.871985609393903, Epsilon: 0.524, loss: 5.367462158203125 count: 20 version: 1
# Episode 130, Score: 54.81039532781551, Epsilon: 0.521, loss: 5.280368804931641 count: 20 version: 1
# Episode 131, Score: 125.83684663092856, Epsilon: 0.519, loss: 5.224237442016602 count: 20 version: 1
# Episode 132, Score: 81.4000930587456, Epsilon: 0.516, loss: 5.316025257110596 count: 20 version: 1
# Episode 133, Score: -117.60969730969413, Epsilon: 0.513, loss: 5.373744487762451 count: 20 version: 1
# Episode 134, Score: -122.06396935784863, Epsilon: 0.511, loss: 5.241054058074951 count: 20 version: 1
# Episode 135, Score: -72.74167840944511, Epsilon: 0.508, loss: 5.126124382019043 count: 20 version: 1
# Episode 136, Score: -101.44128692182267, Epsilon: 0.506, loss: 5.266918659210205 count: 20 version: 1
# Episode 137, Score: -63.45819509493134, Epsilon: 0.503, loss: 5.217417240142822 count: 20 version: 1
# Episode 138, Score: 157.93720842174673, Epsilon: 0.501, loss: 5.311539173126221 count: 20 version: 1
# Episode 139, Score: 247.85027640240105, Epsilon: 0.498, loss: 5.285544395446777 count: 20 version: 1
# Episode 140, Score: -19.306529440716133, Epsilon: 0.496, loss: 5.247639179229736 count: 20 version: 1
# Episode 141, Score: -65.07109424540641, Epsilon: 0.493, loss: 5.314230918884277 count: 20 version: 1
# Episode 142, Score: 80.56066370119402, Epsilon: 0.491, loss: 5.383332252502441 count: 20 version: 1
# Episode 143, Score: 1.724015849418663, Epsilon: 0.488, loss: 5.282943248748779 count: 20 version: 1
# Episode 144, Score: -90.60711419847644, Epsilon: 0.486, loss: 5.425178050994873 count: 20 version: 1
# Episode 145, Score: -53.55231744500878, Epsilon: 0.483, loss: 5.326117515563965 count: 20 version: 1
# Episode 146, Score: 64.81998760149736, Epsilon: 0.481, loss: 5.478826999664307 count: 20 version: 1
# Episode 147, Score: 234.17436691951968, Epsilon: 0.479, loss: 5.371117115020752 count: 20 version: 1
# Episode 148, Score: -80.31229429275396, Epsilon: 0.476, loss: 5.204291820526123 count: 20 version: 1
# Episode 149, Score: 2.713375271543157, Epsilon: 0.474, loss: 5.233071327209473 count: 20 version: 1
# Episode 150, Score: 93.19184552048398, Epsilon: 0.471, loss: 5.530654430389404 count: 20 version: 1
# Episode 151, Score: 160.9373603155218, Epsilon: 0.469, loss: 5.209235668182373 count: 20 version: 1
# Episode 152, Score: 9.003978384529944, Epsilon: 0.467, loss: 5.256021499633789 count: 20 version: 1
# Episode 153, Score: 136.79073944947663, Epsilon: 0.464, loss: 5.2140374183654785 count: 20 version: 1
# Episode 154, Score: -28.810720291890334, Epsilon: 0.462, loss: 5.143658638000488 count: 20 version: 1
# Episode 155, Score: 42.321207013302114, Epsilon: 0.460, loss: 5.166804313659668 count: 20 version: 1
# Episode 156, Score: 89.95945693963733, Epsilon: 0.458, loss: 5.286859035491943 count: 20 version: 1
# Episode 157, Score: -56.920313050895004, Epsilon: 0.455, loss: 5.5730366706848145 count: 20 version: 1
# Episode 158, Score: -82.99048128759893, Epsilon: 0.453, loss: 5.454851150512695 count: 20 version: 1
# Episode 159, Score: 20.764911833589395, Epsilon: 0.451, loss: 5.4415106773376465 count: 20 version: 1
# Episode 160, Score: -56.253009369203824, Epsilon: 0.448, loss: 5.477921962738037 count: 20 version: 1
# Episode 161, Score: -117.7861899699775, Epsilon: 0.446, loss: 5.332097053527832 count: 20 version: 1
# Episode 162, Score: 42.79741705052652, Epsilon: 0.444, loss: 5.384339809417725 count: 20 version: 1
# Episode 163, Score: -111.7208517504252, Epsilon: 0.442, loss: 5.574747562408447 count: 20 version: 1
# Episode 164, Score: -1.8310639081599334, Epsilon: 0.440, loss: 5.447559833526611 count: 20 version: 1
# Episode 165, Score: 377.4092301006315, Epsilon: 0.437, loss: 5.401182174682617 count: 20 version: 1
# Episode 166, Score: -36.93164556789077, Epsilon: 0.435, loss: 5.3387885093688965 count: 20 version: 1
# Episode 167, Score: 57.19713050820269, Epsilon: 0.433, loss: 5.398305892944336 count: 20 version: 1
# Episode 168, Score: -7.712780560588897, Epsilon: 0.431, loss: 5.284797668457031 count: 20 version: 1
# Episode 169, Score: -55.123860687183026, Epsilon: 0.429, loss: 5.487340450286865 count: 20 version: 1
# Episode 170, Score: -2.193060973867091, Epsilon: 0.427, loss: 5.420093536376953 count: 20 version: 1
# Episode 171, Score: 163.74231638485992, Epsilon: 0.424, loss: 5.289772987365723 count: 20 version: 1
# Episode 172, Score: 70.32141392160224, Epsilon: 0.422, loss: 5.60160493850708 count: 20 version: 1
# Episode 173, Score: 281.2941719212554, Epsilon: 0.420, loss: 5.450014591217041 count: 20 version: 1
# Episode 174, Score: -48.937850247629456, Epsilon: 0.418, loss: 5.493525505065918 count: 20 version: 1
# Episode 175, Score: 54.30246951519155, Epsilon: 0.416, loss: 5.436909198760986 count: 20 version: 1
# Episode 176, Score: 491.075083819983, Epsilon: 0.414, loss: 5.609687328338623 count: 20 version: 1
# Episode 177, Score: -9.666803575519054, Epsilon: 0.412, loss: 5.472092628479004 count: 20 version: 1
# Episode 178, Score: 616.1602009362673, Epsilon: 0.410, loss: 5.544951438903809 count: 20 version: 1
# Episode 179, Score: 71.62236615362156, Epsilon: 0.408, loss: 5.533543586730957 count: 20 version: 1
# Episode 180, Score: 74.17228090144624, Epsilon: 0.406, loss: 5.447963714599609 count: 20 version: 1
# Episode 181, Score: -63.907780969253, Epsilon: 0.404, loss: 5.2787861824035645 count: 20 version: 1
# Episode 182, Score: 218.2024036691355, Epsilon: 0.402, loss: 5.642165660858154 count: 20 version: 1
# Episode 183, Score: 308.785456917464, Epsilon: 0.400, loss: 5.3114752769470215 count: 20 version: 1
# Episode 184, Score: 284.69600415148193, Epsilon: 0.398, loss: 5.306980609893799 count: 20 version: 1
# Episode 185, Score: 258.00958123424857, Epsilon: 0.396, loss: 5.451545238494873 count: 20 version: 1
# Episode 186, Score: 260.3354376973057, Epsilon: 0.394, loss: 5.366451263427734 count: 20 version: 1
# Episode 187, Score: 322.429228602031, Epsilon: 0.392, loss: 5.48549222946167 count: 20 version: 1
# Episode 188, Score: 284.5100370376705, Epsilon: 0.390, loss: 5.479480743408203 count: 20 version: 1
# Episode 189, Score: 466.79698063046226, Epsilon: 0.388, loss: 5.515348434448242 count: 20 version: 1
# Episode 190, Score: 50.72405648344602, Epsilon: 0.386, loss: 5.301056385040283 count: 20 version: 1
# Episode 191, Score: -58.32050617682165, Epsilon: 0.384, loss: 5.305403232574463 count: 20 version: 1
# Episode 192, Score: 172.10099872150272, Epsilon: 0.382, loss: 5.385063648223877 count: 20 version: 1
# Episode 193, Score: 192.54334678357043, Epsilon: 0.380, loss: 5.647330284118652 count: 20 version: 1
# Episode 194, Score: -16.41995861707818, Epsilon: 0.378, loss: 5.207768440246582 count: 20 version: 1
# Episode 195, Score: 67.71565639077426, Epsilon: 0.376, loss: 5.373943328857422 count: 20 version: 1
# Episode 196, Score: 163.40751435271443, Epsilon: 0.374, loss: 5.395806789398193 count: 20 version: 1
# Episode 197, Score: 53.24375626121832, Epsilon: 0.373, loss: 5.335853099822998 count: 20 version: 1
# Episode 198, Score: -61.591548646761794, Epsilon: 0.371, loss: 5.486295223236084 count: 20 version: 1
# Episode 199, Score: 35.20383502514278, Epsilon: 0.369, loss: 5.590150833129883 count: 20 version: 1
# Episode 200, Score: -12.31618359438653, Epsilon: 0.367, loss: 5.516026973724365 count: 20 version: 1
# Episode 201, Score: 54.86469558662918, Epsilon: 0.365, loss: 5.716620922088623 count: 20 version: 1
# Episode 202, Score: -98.84025165491533, Epsilon: 0.363, loss: 5.578826427459717 count: 20 version: 1
# Episode 203, Score: 71.6981492751031, Epsilon: 0.361, loss: 5.55433988571167 count: 20 version: 1
# Episode 204, Score: 22.091554247111162, Epsilon: 0.360, loss: 5.6489691734313965 count: 20 version: 1
# Episode 205, Score: 252.544513636514, Epsilon: 0.358, loss: 5.317286014556885 count: 20 version: 1
# Episode 206, Score: 183.89497974078154, Epsilon: 0.356, loss: 5.536214828491211 count: 20 version: 1
# Episode 207, Score: 204.15086889362874, Epsilon: 0.354, loss: 5.429932594299316 count: 20 version: 1
# Episode 208, Score: -106.53313970469435, Epsilon: 0.353, loss: 5.4184489250183105 count: 20 version: 1
# Episode 209, Score: 105.79541493754562, Epsilon: 0.351, loss: 5.568756580352783 count: 20 version: 1
# Episode 210, Score: -131.7634985596834, Epsilon: 0.349, loss: 5.361937522888184 count: 20 version: 1
# Episode 211, Score: 472.63631340099766, Epsilon: 0.347, loss: 5.476919651031494 count: 20 version: 1
# Episode 212, Score: 198.71127319331947, Epsilon: 0.346, loss: 5.693439483642578 count: 20 version: 1
# Episode 213, Score: -68.51988735239979, Epsilon: 0.344, loss: 5.627274036407471 count: 20 version: 1
# Episode 214, Score: 126.8338516554802, Epsilon: 0.342, loss: 5.4276323318481445 count: 20 version: 1
# Episode 215, Score: 34.30714372077466, Epsilon: 0.340, loss: 5.440981864929199 count: 20 version: 1
# Episode 216, Score: -15.14804325670383, Epsilon: 0.339, loss: 5.4055256843566895 count: 20 version: 1
# Episode 217, Score: 45.758001545035995, Epsilon: 0.337, loss: 5.387959003448486 count: 20 version: 1
# Episode 218, Score: 20.83997596784502, Epsilon: 0.335, loss: 5.587576866149902 count: 20 version: 1
# Episode 219, Score: -61.36363315198605, Epsilon: 0.334, loss: 5.619551658630371 count: 20 version: 1
# Episode 220, Score: 130.6238181917065, Epsilon: 0.332, loss: 5.29465389251709 count: 20 version: 1
# Episode 221, Score: 233.83719255935148, Epsilon: 0.330, loss: 5.194565773010254 count: 20 version: 1
# Episode 222, Score: 379.7974731412809, Epsilon: 0.329, loss: 5.444868087768555 count: 20 version: 1
# Episode 223, Score: 18.262370116836678, Epsilon: 0.327, loss: 5.767796993255615 count: 20 version: 1
# Episode 224, Score: 65.40696858882643, Epsilon: 0.325, loss: 5.4154767990112305 count: 20 version: 1
# Episode 225, Score: 291.7218437393176, Epsilon: 0.324, loss: 5.311129570007324 count: 20 version: 1
# Episode 226, Score: 407.46938063115306, Epsilon: 0.322, loss: 5.450249195098877 count: 20 version: 1
# Episode 227, Score: -29.44312068638311, Epsilon: 0.321, loss: 5.42340612411499 count: 20 version: 1
# Episode 228, Score: 176.10518564314987, Epsilon: 0.319, loss: 5.730462551116943 count: 20 version: 1
# Episode 229, Score: 63.10057237487956, Epsilon: 0.317, loss: 5.659945011138916 count: 20 version: 1
# Episode 230, Score: 636.6217149840877, Epsilon: 0.316, loss: 5.503537654876709 count: 20 version: 1
# Episode 231, Score: 70.50706332622087, Epsilon: 0.314, loss: 5.562004566192627 count: 20 version: 1
# Episode 232, Score: -18.835391421267104, Epsilon: 0.313, loss: 5.700324058532715 count: 20 version: 1
# Episode 233, Score: 135.03948660936692, Epsilon: 0.311, loss: 5.54132604598999 count: 20 version: 1
# Episode 234, Score: 23.530869589475742, Epsilon: 0.309, loss: 5.667004108428955 count: 20 version: 1
# Episode 235, Score: 144.78820406538262, Epsilon: 0.308, loss: 5.471728801727295 count: 20 version: 1
# Episode 236, Score: 285.6564983612425, Epsilon: 0.306, loss: 5.59129524230957 count: 20 version: 1
# Episode 237, Score: 29.60633434094052, Epsilon: 0.305, loss: 5.581056594848633 count: 20 version: 1
# Episode 238, Score: 35.28802356601477, Epsilon: 0.303, loss: 5.400912761688232 count: 20 version: 1
# Episode 239, Score: 456.7888078494377, Epsilon: 0.302, loss: 5.626849174499512 count: 20 version: 1
# Episode 240, Score: 82.32167046123061, Epsilon: 0.300, loss: 5.291013240814209 count: 20 version: 1
# Episode 241, Score: 32.969834067482225, Epsilon: 0.299, loss: 5.405597686767578 count: 20 version: 1
# Episode 242, Score: 68.25303844082373, Epsilon: 0.297, loss: 5.656033039093018 count: 20 version: 1
# Episode 243, Score: -38.47415251846746, Epsilon: 0.296, loss: 5.4409589767456055 count: 20 version: 1
# Episode 244, Score: -96.29237114476314, Epsilon: 0.294, loss: 5.447448253631592 count: 20 version: 1
# Episode 245, Score: -1.7007141078873929, Epsilon: 0.293, loss: 5.330074787139893 count: 20 version: 1
# Episode 246, Score: -4.881190398262731, Epsilon: 0.291, loss: 5.548977375030518 count: 20 version: 1
# Episode 247, Score: 186.59613812645887, Epsilon: 0.290, loss: 5.520549297332764 count: 20 version: 1
# Episode 248, Score: 83.98577892316973, Epsilon: 0.288, loss: 5.6223931312561035 count: 20 version: 1
# Episode 249, Score: 69.55776596646183, Epsilon: 0.287, loss: 5.690325736999512 count: 20 version: 1
# Episode 250, Score: 43.97161277337864, Epsilon: 0.286, loss: 5.713407516479492 count: 20 version: 1
# Episode 251, Score: 85.49639811680038, Epsilon: 0.284, loss: 5.513652801513672 count: 20 version: 1
# Episode 252, Score: 276.641002827281, Epsilon: 0.283, loss: 5.397660255432129 count: 20 version: 1
# Episode 253, Score: -7.59661242128567, Epsilon: 0.281, loss: 5.594994068145752 count: 20 version: 1
# Episode 254, Score: 99.6700631292673, Epsilon: 0.280, loss: 5.524500846862793 count: 20 version: 1
# Episode 255, Score: 83.2853051392841, Epsilon: 0.279, loss: 5.458854675292969 count: 20 version: 1
# Episode 256, Score: -18.01681453738246, Epsilon: 0.277, loss: 5.681612014770508 count: 20 version: 1
# Episode 257, Score: 60.35420767871494, Epsilon: 0.276, loss: 5.76831579208374 count: 20 version: 1
# Episode 258, Score: 84.76335661473615, Epsilon: 0.274, loss: 5.755855083465576 count: 20 version: 1
# Episode 259, Score: 80.61655546565328, Epsilon: 0.273, loss: 5.666718006134033 count: 20 version: 1
# Episode 260, Score: 92.230967836486, Epsilon: 0.272, loss: 5.572274208068848 count: 20 version: 1
# Episode 261, Score: 466.6970533857153, Epsilon: 0.270, loss: 5.639824390411377 count: 20 version: 1
# Episode 262, Score: 31.313637766991064, Epsilon: 0.269, loss: 5.655747890472412 count: 20 version: 1
# Episode 263, Score: 201.83374534372842, Epsilon: 0.268, loss: 5.569711208343506 count: 20 version: 1
# Episode 264, Score: 29.739749905747658, Epsilon: 0.266, loss: 5.722587585449219 count: 20 version: 1
# Episode 265, Score: 323.9919272978534, Epsilon: 0.265, loss: 5.389881134033203 count: 20 version: 1
# Episode 266, Score: -17.499693031021025, Epsilon: 0.264, loss: 5.614543437957764 count: 20 version: 1
# Episode 267, Score: 40.2966205995325, Epsilon: 0.262, loss: 5.740673542022705 count: 20 version: 1
# Episode 268, Score: 15.743852175710003, Epsilon: 0.261, loss: 5.667450428009033 count: 20 version: 1
# Episode 269, Score: 103.91701104700644, Epsilon: 0.260, loss: 5.44651460647583 count: 20 version: 1
# Episode 270, Score: 817.6669275623444, Epsilon: 0.258, loss: 5.602278232574463 count: 20 version: 1
# Episode 271, Score: 99.90326457818173, Epsilon: 0.257, loss: 5.405965328216553 count: 20 version: 1
# Episode 272, Score: 22.48095872848944, Epsilon: 0.256, loss: 5.385066509246826 count: 20 version: 1
# Episode 273, Score: 100.48755629974767, Epsilon: 0.255, loss: 5.525062561035156 count: 20 version: 1
# Episode 274, Score: 36.19310740983144, Epsilon: 0.253, loss: 5.67556095123291 count: 20 version: 1
# Episode 275, Score: 10.445838155755496, Epsilon: 0.252, loss: 5.78313684463501 count: 20 version: 1
# Episode 276, Score: 66.50724478861537, Epsilon: 0.251, loss: 5.622342586517334 count: 20 version: 1
# Episode 277, Score: 10.463340897271905, Epsilon: 0.249, loss: 5.741140365600586 count: 20 version: 1
# Episode 278, Score: 52.085341288381755, Epsilon: 0.248, loss: 5.543909549713135 count: 20 version: 1
# Episode 279, Score: 142.27295797416264, Epsilon: 0.247, loss: 5.5582427978515625 count: 20 version: 1
# Episode 280, Score: 81.84275974118043, Epsilon: 0.246, loss: 5.51816463470459 count: 20 version: 1
# Episode 281, Score: 269.79042255138404, Epsilon: 0.245, loss: 5.517091751098633 count: 20 version: 1
# Episode 282, Score: 24.76864591949402, Epsilon: 0.243, loss: 5.347339630126953 count: 20 version: 1
# Episode 283, Score: -96.84792280988819, Epsilon: 0.242, loss: 5.676684379577637 count: 20 version: 1
# Episode 284, Score: -33.35891615647489, Epsilon: 0.241, loss: 5.5105390548706055 count: 20 version: 1
# Episode 285, Score: 141.38553569018666, Epsilon: 0.240, loss: 5.617559432983398 count: 20 version: 1
# Episode 286, Score: -119.73717621574622, Epsilon: 0.238, loss: 5.518041610717773 count: 20 version: 1
# Episode 287, Score: 190.45248862575022, Epsilon: 0.237, loss: 5.588554859161377 count: 20 version: 1
# Episode 288, Score: -1.4413649027065958, Epsilon: 0.236, loss: 5.6520490646362305 count: 20 version: 1
# Episode 289, Score: 75.66819276961792, Epsilon: 0.235, loss: 5.479408264160156 count: 20 version: 1
# Episode 290, Score: 51.452026675522234, Epsilon: 0.234, loss: 5.586546897888184 count: 20 version: 1
# Episode 291, Score: 2420.29621360723, Epsilon: 0.233, loss: 5.531428813934326 count: 20 version: 1
# Episode 292, Score: 127.94711875699215, Epsilon: 0.231, loss: 5.611581325531006 count: 20 version: 1
# Episode 293, Score: 54.68886432687066, Epsilon: 0.230, loss: 5.515052795410156 count: 20 version: 1
# Episode 294, Score: 804.1870850577702, Epsilon: 0.229, loss: 5.589190483093262 count: 20 version: 1
# Episode 295, Score: 56.17597677773972, Epsilon: 0.228, loss: 5.647557735443115 count: 20 version: 1
# Episode 296, Score: 61.93337718932696, Epsilon: 0.227, loss: 5.627172946929932 count: 20 version: 1
# Episode 297, Score: 117.13738606836012, Epsilon: 0.226, loss: 5.411741256713867 count: 20 version: 1
# Episode 298, Score: 438.87603428008936, Epsilon: 0.225, loss: 5.650918960571289 count: 20 version: 1
# Episode 299, Score: 192.63504601618115, Epsilon: 0.223, loss: 5.5646185874938965 count: 20 version: 1
# Episode 300, Score: 327.2303133078258, Epsilon: 0.222, loss: 5.707203388214111 count: 20 version: 1
# Episode 301, Score: 50.8558309682237, Epsilon: 0.221, loss: 5.428469181060791 count: 20 version: 1
# Episode 302, Score: 38.46939051042011, Epsilon: 0.220, loss: 5.538234233856201 count: 20 version: 1
# Episode 303, Score: 52.368523280050795, Epsilon: 0.219, loss: 5.743502140045166 count: 20 version: 1
# Episode 304, Score: 232.83308141384248, Epsilon: 0.218, loss: 5.654945373535156 count: 20 version: 1
# Episode 305, Score: 34.7094705938631, Epsilon: 0.217, loss: 5.582111358642578 count: 20 version: 1
# Episode 306, Score: 46.71425512938356, Epsilon: 0.216, loss: 5.761936187744141 count: 20 version: 1
# Episode 307, Score: 245.3591001986689, Epsilon: 0.215, loss: 5.770926475524902 count: 20 version: 1
# Episode 308, Score: 392.76307110732307, Epsilon: 0.214, loss: 5.846030235290527 count: 20 version: 1
# Episode 309, Score: 62.732435150494325, Epsilon: 0.212, loss: 5.71641206741333 count: 20 version: 1
# Episode 310, Score: 278.54324373352836, Epsilon: 0.211, loss: 5.668490409851074 count: 20 version: 1
# Episode 311, Score: 34.81095423913507, Epsilon: 0.210, loss: 5.492303371429443 count: 20 version: 1
# Episode 312, Score: 59.22991220162157, Epsilon: 0.209, loss: 5.54595947265625 count: 20 version: 1
# Episode 313, Score: 36.550376058766005, Epsilon: 0.208, loss: 5.538975238800049 count: 20 version: 1
# Episode 314, Score: 23.026501226117148, Epsilon: 0.207, loss: 5.906530857086182 count: 20 version: 1
# Episode 315, Score: 86.20868791757391, Epsilon: 0.206, loss: 5.4402852058410645 count: 20 version: 1
# Episode 316, Score: 65.56250738574352, Epsilon: 0.205, loss: 5.626720905303955 count: 20 version: 1
# Episode 317, Score: 807.9880801837824, Epsilon: 0.204, loss: 5.737852096557617 count: 20 version: 1
# Episode 318, Score: -11.384320371914612, Epsilon: 0.203, loss: 5.699037551879883 count: 20 version: 1
# Episode 319, Score: 40.566560508409566, Epsilon: 0.202, loss: 5.781116485595703 count: 20 version: 1
# Episode 320, Score: 25.283339088698995, Epsilon: 0.201, loss: 5.547013759613037 count: 20 version: 1
# Episode 321, Score: 51.86214967157923, Epsilon: 0.200, loss: 5.710027694702148 count: 20 version: 1
# Episode 322, Score: 866.062952087832, Epsilon: 0.199, loss: 5.723945140838623 count: 20 version: 1
# Episode 323, Score: 26.952845796719316, Epsilon: 0.198, loss: 5.610774993896484 count: 20 version: 1
# Episode 324, Score: 112.49929833771591, Epsilon: 0.197, loss: 5.98717737197876 count: 20 version: 1
# Episode 325, Score: 336.982909098901, Epsilon: 0.196, loss: 5.922648906707764 count: 20 version: 1
# Episode 326, Score: 53.44828111776178, Epsilon: 0.195, loss: 5.763065814971924 count: 20 version: 1
# Episode 327, Score: 550.1918910041804, Epsilon: 0.194, loss: 5.426466941833496 count: 20 version: 1
# Episode 328, Score: 53.78784048429509, Epsilon: 0.193, loss: 5.650787353515625 count: 20 version: 1
# Episode 329, Score: 55.75901787696603, Epsilon: 0.192, loss: 5.8578057289123535 count: 20 version: 1
# Episode 330, Score: 815.7451554401634, Epsilon: 0.191, loss: 5.71253776550293 count: 20 version: 1
# Episode 331, Score: -25.143034741010467, Epsilon: 0.190, loss: 5.547417163848877 count: 20 version: 1
# Episode 332, Score: 156.58616135213015, Epsilon: 0.189, loss: 5.528162479400635 count: 20 version: 1
# Episode 333, Score: 2228.6696087759983, Epsilon: 0.188, loss: 5.720871925354004 count: 20 version: 1
# Episode 334, Score: 56.228996396817706, Epsilon: 0.187, loss: 5.9480390548706055 count: 20 version: 1
# Episode 335, Score: 115.46913628277866, Epsilon: 0.187, loss: 5.572107791900635 count: 20 version: 1
# Episode 336, Score: 164.70478123054068, Epsilon: 0.186, loss: 5.7238640785217285 count: 20 version: 1
# Episode 337, Score: 10.603179159126398, Epsilon: 0.185, loss: 5.65003776550293 count: 20 version: 1
# Episode 338, Score: 42.43676055761978, Epsilon: 0.184, loss: 5.6153035163879395 count: 20 version: 1
# Episode 339, Score: 34.52861438403511, Epsilon: 0.183, loss: 5.986867427825928 count: 20 version: 1
# Episode 340, Score: 136.1265986163288, Epsilon: 0.182, loss: 5.940452575683594 count: 20 version: 1
# Episode 341, Score: 64.17710587498789, Epsilon: 0.181, loss: 5.631024360656738 count: 20 version: 1
# Episode 342, Score: 86.59054935120673, Epsilon: 0.180, loss: 5.798852443695068 count: 20 version: 1
# Episode 343, Score: 417.73548318448707, Epsilon: 0.179, loss: 5.5276265144348145 count: 20 version: 1
# Episode 344, Score: 128.62201539720468, Epsilon: 0.178, loss: 5.742316722869873 count: 20 version: 1
# Episode 345, Score: 79.87101494649755, Epsilon: 0.177, loss: 5.738950252532959 count: 20 version: 1
# Episode 346, Score: 671.0017286904147, Epsilon: 0.177, loss: 5.748694896697998 count: 20 version: 1
# Episode 347, Score: 105.86448361062094, Epsilon: 0.176, loss: 5.937506675720215 count: 20 version: 1
# Episode 348, Score: 591.841534480172, Epsilon: 0.175, loss: 5.643288612365723 count: 20 version: 1
# Episode 349, Score: 678.7596559665408, Epsilon: 0.174, loss: 5.636114597320557 count: 20 version: 1
# Episode 350, Score: 4672.535774212386, Epsilon: 0.173, loss: 5.681804180145264 count: 20 version: 1
# Episode 351, Score: 74.65544688468651, Epsilon: 0.172, loss: 6.1827006340026855 count: 20 version: 1
# Episode 352, Score: 139.0640873525664, Epsilon: 0.171, loss: 5.627060413360596 count: 20 version: 1
# Episode 353, Score: 308.3486494536879, Epsilon: 0.170, loss: 5.770304203033447 count: 20 version: 1
# Episode 354, Score: 90.23713956680751, Epsilon: 0.170, loss: 5.734892845153809 count: 20 version: 1
# Episode 355, Score: -1.9489529342978926, Epsilon: 0.169, loss: 5.7732977867126465 count: 20 version: 1
# Episode 356, Score: 90.18245779418066, Epsilon: 0.168, loss: 5.463741779327393 count: 20 version: 1
# Episode 357, Score: 326.31963318074463, Epsilon: 0.167, loss: 5.855423450469971 count: 20 version: 1
# Episode 358, Score: 111.89193956119277, Epsilon: 0.166, loss: 5.801417350769043 count: 20 version: 1
# Episode 359, Score: 3507.0826654983694, Epsilon: 0.165, loss: 5.875433921813965 count: 20 version: 1
# Episode 360, Score: 115.34932373064953, Epsilon: 0.165, loss: 5.789852142333984 count: 20 version: 1
# Episode 361, Score: 116.48337761640266, Epsilon: 0.164, loss: 6.115235805511475 count: 20 version: 1
# Episode 362, Score: 109.61763089064732, Epsilon: 0.163, loss: 5.695751190185547 count: 20 version: 1
# Episode 363, Score: 282.9939538220964, Epsilon: 0.162, loss: 5.99338436126709 count: 20 version: 1
# Episode 364, Score: 292.27077200659664, Epsilon: 0.161, loss: 6.121871471405029 count: 20 version: 1
# Episode 365, Score: 78.4782922825193, Epsilon: 0.160, loss: 5.718420505523682 count: 20 version: 1
# Episode 366, Score: 94.65793322129025, Epsilon: 0.160, loss: 5.6630859375 count: 20 version: 1
# Episode 367, Score: 2166.354925960631, Epsilon: 0.159, loss: 5.641944885253906 count: 20 version: 1
# Episode 368, Score: 79.78041651973786, Epsilon: 0.158, loss: 5.722725868225098 count: 20 version: 1
# Episode 369, Score: 180.89491835211902, Epsilon: 0.157, loss: 5.813959121704102 count: 20 version: 1
# Episode 370, Score: 104.24981754307726, Epsilon: 0.157, loss: 5.9157233238220215 count: 20 version: 1
# Episode 371, Score: 67.29912951927543, Epsilon: 0.156, loss: 5.947455883026123 count: 20 version: 1
# Episode 372, Score: 758.2333813825778, Epsilon: 0.155, loss: 5.999349594116211 count: 20 version: 1
# Episode 373, Score: 31.44841264068441, Epsilon: 0.154, loss: 5.721395492553711 count: 20 version: 1
# Episode 374, Score: 93.86554455384487, Epsilon: 0.153, loss: 5.863311290740967 count: 20 version: 1
# Episode 375, Score: 130.30429680408702, Epsilon: 0.153, loss: 5.644993782043457 count: 20 version: 1
# Episode 376, Score: 33.995851852925966, Epsilon: 0.152, loss: 5.81530237197876 count: 20 version: 1
# Episode 377, Score: 148.88546216424947, Epsilon: 0.151, loss: 5.626500606536865 count: 20 version: 1
# Episode 378, Score: 149.02617063542243, Epsilon: 0.150, loss: 5.767632484436035 count: 20 version: 1
# Episode 379, Score: 118.6830721006221, Epsilon: 0.150, loss: 5.737573623657227 count: 20 version: 1
# Episode 380, Score: 75.39856371592259, Epsilon: 0.149, loss: 5.712423801422119 count: 20 version: 1
# Episode 381, Score: 122.61948264947705, Epsilon: 0.148, loss: 5.900318145751953 count: 20 version: 1
# Episode 382, Score: 121.08629322543516, Epsilon: 0.147, loss: 5.600177764892578 count: 20 version: 1
# Episode 383, Score: 78.0333071931409, Epsilon: 0.147, loss: 6.0352396965026855 count: 20 version: 1
# Episode 384, Score: 90.15958660663568, Epsilon: 0.146, loss: 5.560516834259033 count: 20 version: 1
# Episode 385, Score: 13.665018033259457, Epsilon: 0.145, loss: 5.584610939025879 count: 20 version: 1
# Episode 386, Score: 109.26147778525512, Epsilon: 0.144, loss: 5.573546886444092 count: 20 version: 1
# Episode 387, Score: 44.269289203861945, Epsilon: 0.144, loss: 5.800529479980469 count: 20 version: 1
# Episode 388, Score: 41.925639261949755, Epsilon: 0.143, loss: 5.860381603240967 count: 20 version: 1
# Episode 389, Score: -156.15737488428118, Epsilon: 0.142, loss: 6.125556468963623 count: 20 version: 1
# Episode 390, Score: 1041.3040501824644, Epsilon: 0.142, loss: 5.775230407714844 count: 20 version: 1
# Episode 391, Score: 3.845070590473938, Epsilon: 0.141, loss: 5.809372901916504 count: 20 version: 1
# Episode 392, Score: 37.43920899590148, Epsilon: 0.140, loss: 5.922336578369141 count: 20 version: 1
# Episode 393, Score: 120.15441510769404, Epsilon: 0.139, loss: 5.8573455810546875 count: 20 version: 1
# Episode 394, Score: 121.6257468324568, Epsilon: 0.139, loss: 5.797725677490234 count: 20 version: 1
# Episode 395, Score: 17.025300032069254, Epsilon: 0.138, loss: 5.902992248535156 count: 20 version: 1
# Episode 396, Score: 75.18329106840417, Epsilon: 0.137, loss: 5.5810723304748535 count: 20 version: 1
# Episode 397, Score: 19.381189336025386, Epsilon: 0.137, loss: 5.7444658279418945 count: 20 version: 1
# Episode 398, Score: 25.02560388167285, Epsilon: 0.136, loss: 5.713132381439209 count: 20 version: 1
# Episode 399, Score: 105.73050654092947, Epsilon: 0.135, loss: 6.007896423339844 count: 20 version: 1
# Episode 400, Score: 132.33999764068278, Epsilon: 0.135, loss: 6.1351823806762695 count: 20 version: 1
# Episode 401, Score: 23.301485992696826, Epsilon: 0.134, loss: 6.1162238121032715 count: 20 version: 1
# Episode 402, Score: 33.02489435339089, Epsilon: 0.133, loss: 5.607959270477295 count: 20 version: 1
# Episode 403, Score: 292.28535509965025, Epsilon: 0.133, loss: 5.521105766296387 count: 20 version: 1
# Episode 404, Score: 74.06872608233391, Epsilon: 0.132, loss: 5.920910835266113 count: 20 version: 1
# Episode 405, Score: 125.53961595647797, Epsilon: 0.131, loss: 5.819615364074707 count: 20 version: 1
# Episode 406, Score: 37.292771371614776, Epsilon: 0.131, loss: 5.642838001251221 count: 20 version: 1
# Episode 407, Score: 109.455705321658, Epsilon: 0.130, loss: 5.72035026550293 count: 20 version: 1
# Episode 408, Score: 96.48580163494785, Epsilon: 0.129, loss: 5.856169700622559 count: 20 version: 1
# Episode 409, Score: 1464.131996108959, Epsilon: 0.129, loss: 5.806957244873047 count: 20 version: 1
# Episode 410, Score: 73.66298289021825, Epsilon: 0.128, loss: 5.841049671173096 count: 20 version: 1
# Episode 411, Score: 84.36127020036531, Epsilon: 0.127, loss: 5.887979984283447 count: 20 version: 1
# Episode 412, Score: 102.4523262018871, Epsilon: 0.127, loss: 6.100090980529785 count: 20 version: 1
# Episode 413, Score: 92.04010525546164, Epsilon: 0.126, loss: 6.1830925941467285 count: 20 version: 1
# Episode 414, Score: 47.84295422171124, Epsilon: 0.126, loss: 5.594976902008057 count: 20 version: 1
# Episode 415, Score: 100.8727972932503, Epsilon: 0.125, loss: 6.002795219421387 count: 20 version: 1
# Episode 416, Score: 2031.3251571767419, Epsilon: 0.124, loss: 5.841614246368408 count: 20 version: 1
# Episode 417, Score: 10.269030001566591, Epsilon: 0.124, loss: 5.86082124710083 count: 20 version: 1
# Episode 418, Score: 103.07680666911995, Epsilon: 0.123, loss: 6.063782691955566 count: 20 version: 1
# Episode 419, Score: 9.64909706673319, Epsilon: 0.122, loss: 5.82659387588501 count: 20 version: 1
# Episode 420, Score: 80.43881328638236, Epsilon: 0.122, loss: 6.101644515991211 count: 20 version: 1
# Episode 421, Score: 9.573515923407228, Epsilon: 0.121, loss: 5.734347820281982 count: 20 version: 1
# Episode 422, Score: 55.04939109458826, Epsilon: 0.121, loss: 5.807960033416748 count: 20 version: 1
# Episode 423, Score: 254.55501829671084, Epsilon: 0.120, loss: 5.645488262176514 count: 20 version: 1
# Episode 424, Score: 466.810530071793, Epsilon: 0.119, loss: 5.991523265838623 count: 20 version: 1
# Episode 425, Score: 77.20664739198321, Epsilon: 0.119, loss: 5.902881145477295 count: 20 version: 1
# Episode 426, Score: 110.00224969835313, Epsilon: 0.118, loss: 5.677768230438232 count: 20 version: 1
# Episode 427, Score: 70.6108185679592, Epsilon: 0.118, loss: 5.951879024505615 count: 20 version: 1
# Episode 428, Score: -3.165365048653314, Epsilon: 0.117, loss: 5.927340507507324 count: 20 version: 1
# Episode 429, Score: 2286.8378430800626, Epsilon: 0.116, loss: 5.906716823577881 count: 20 version: 1
# Episode 430, Score: 169.57351172006724, Epsilon: 0.116, loss: 5.820359706878662 count: 20 version: 1
# Episode 431, Score: 468.7136715797533, Epsilon: 0.115, loss: 5.814340114593506 count: 20 version: 1
# Episode 432, Score: 40.882669100210364, Epsilon: 0.115, loss: 5.544957160949707 count: 20 version: 1
# Episode 433, Score: 93.26578557891264, Epsilon: 0.114, loss: 5.9116644859313965 count: 20 version: 1
# Episode 434, Score: 42.56866040418572, Epsilon: 0.114, loss: 5.743735313415527 count: 20 version: 1
# Episode 435, Score: 90.60412753814796, Epsilon: 0.113, loss: 5.723982810974121 count: 20 version: 1
# Episode 436, Score: 7.091585329191332, Epsilon: 0.112, loss: 5.98548698425293 count: 20 version: 1
# Episode 437, Score: 2488.907378243624, Epsilon: 0.112, loss: 5.941094398498535 count: 20 version: 1
# Episode 438, Score: 57.60840204464478, Epsilon: 0.111, loss: 6.150645732879639 count: 20 version: 1
# Episode 439, Score: 109.84132491146352, Epsilon: 0.111, loss: 5.68550443649292 count: 20 version: 1
# Episode 440, Score: 106.77897070570691, Epsilon: 0.110, loss: 5.862812042236328 count: 20 version: 1
# Episode 441, Score: 69.39275951712773, Epsilon: 0.110, loss: 5.873875617980957 count: 20 version: 1
# Episode 442, Score: 53.73910691642175, Epsilon: 0.109, loss: 6.222070217132568 count: 20 version: 1
# Episode 443, Score: 124.09642021577918, Epsilon: 0.109, loss: 5.705355167388916 count: 20 version: 1
# Episode 444, Score: 162.22628824754406, Epsilon: 0.108, loss: 5.934492588043213 count: 20 version: 1
# Episode 445, Score: 2221.8912219939634, Epsilon: 0.107, loss: 5.835302829742432 count: 20 version: 1
# Episode 446, Score: 56.943525296520875, Epsilon: 0.107, loss: 5.812085151672363 count: 20 version: 1
# Episode 447, Score: 90.3158050960377, Epsilon: 0.106, loss: 5.9814863204956055 count: 20 version: 1
# Episode 448, Score: 58.347799041569374, Epsilon: 0.106, loss: 5.863283157348633 count: 20 version: 1
# Episode 449, Score: 27.67747792277771, Epsilon: 0.105, loss: 5.835413455963135 count: 20 version: 1
# Episode 450, Score: 2286.424532720667, Epsilon: 0.105, loss: 5.802872657775879 count: 20 version: 1
# Episode 451, Score: 23.104291929513806, Epsilon: 0.104, loss: 5.5985107421875 count: 20 version: 1
# Episode 452, Score: 4870.887277170006, Epsilon: 0.104, loss: 6.000651836395264 count: 20 version: 1
# Episode 453, Score: 663.9859722857921, Epsilon: 0.103, loss: 5.982935905456543 count: 20 version: 1
# Episode 454, Score: 86.84017613636081, Epsilon: 0.103, loss: 5.69570779800415 count: 20 version: 1
# Episode 455, Score: 57.139805943765055, Epsilon: 0.102, loss: 6.220749378204346 count: 20 version: 1
# Episode 456, Score: 80.46295048521938, Epsilon: 0.102, loss: 5.9322052001953125 count: 20 version: 1
# Episode 457, Score: 478.86790359462293, Epsilon: 0.101, loss: 5.959109306335449 count: 20 version: 1
# Episode 458, Score: 1031.8347286372596, Epsilon: 0.101, loss: 5.846927165985107 count: 20 version: 1
# Episode 459, Score: 2201.4880389739824, Epsilon: 0.100, loss: 5.904278755187988 count: 20 version: 1
# Episode 460, Score: 41.166308994549354, Epsilon: 0.100, loss: 5.871530055999756 count: 20 version: 1
# Episode 461, Score: 18.30829754546869, Epsilon: 0.099, loss: 6.247478485107422 count: 20 version: 1
# Episode 462, Score: 35.20348217516698, Epsilon: 0.099, loss: 5.889276504516602 count: 20 version: 1
# Episode 463, Score: 56.48795157778886, Epsilon: 0.098, loss: 6.1386637687683105 count: 20 version: 1
# Episode 464, Score: 111.96506771494637, Epsilon: 0.098, loss: 5.9288835525512695 count: 20 version: 1
# Episode 465, Score: 62.471060418907086, Epsilon: 0.097, loss: 5.956180095672607 count: 20 version: 1
# Episode 466, Score: 27.336594757765397, Epsilon: 0.097, loss: 6.111044883728027 count: 20 version: 1
# Episode 467, Score: 31.69681410199405, Epsilon: 0.096, loss: 5.943447113037109 count: 20 version: 1
# Episode 468, Score: 59.353351682315974, Epsilon: 0.096, loss: 5.956290245056152 count: 20 version: 1
# Episode 469, Score: 49.92304107507994, Epsilon: 0.095, loss: 5.971555233001709 count: 20 version: 1
# Episode 470, Score: 124.45673522138691, Epsilon: 0.095, loss: 6.105685234069824 count: 20 version: 1
# Episode 471, Score: 2364.230335826997, Epsilon: 0.094, loss: 6.122946262359619 count: 20 version: 1
# Episode 472, Score: 100.48827825450269, Epsilon: 0.094, loss: 5.833384990692139 count: 20 version: 1
# Episode 473, Score: 105.74571512072623, Epsilon: 0.093, loss: 6.133355617523193 count: 20 version: 1
# Episode 474, Score: 70.27467921444133, Epsilon: 0.093, loss: 5.9296956062316895 count: 20 version: 1
# Episode 475, Score: 324.10222587771057, Epsilon: 0.092, loss: 6.013313293457031 count: 20 version: 1
# Episode 476, Score: 51.243427315100234, Epsilon: 0.092, loss: 5.898574352264404 count: 20 version: 1
# Episode 477, Score: 24.370946723543398, Epsilon: 0.092, loss: 6.050734519958496 count: 20 version: 1
# ...
# Episode 1041, Score: 204.91449438232723, Epsilon: 0.050, loss: 6.6613054275512695 count: 20 version: 3
# Episode 1042, Score: 1397.5639062527175, Epsilon: 0.050, loss: 6.990253925323486 count: 20 version: 3
# Episode 1043, Score: 87.96422286304016, Epsilon: 0.050, loss: 7.259716033935547 count: 20 version: 3
# Episode 1044, Score: -2.711226575951173, Epsilon: 0.050, loss: 7.0344390869140625 count: 20 version: 3
# Episode 1045, Score: 123.5948238035138, Epsilon: 0.050, loss: 7.144956111907959 count: 20 version: 3
# Episode 1046, Score: 132.23100780818868, Epsilon: 0.050, loss: 6.905144691467285 count: 20 version: 3
# Episode 1047, Score: 52.948631233831634, Epsilon: 0.050, loss: 6.9085187911987305 count: 20 version: 3
# Episode 1048, Score: 788.6317700859129, Epsilon: 0.050, loss: 6.913201808929443 count: 20 version: 3
# Episode 1049, Score: 138.37612730773174, Epsilon: 0.050, loss: 7.065951824188232 count: 20 version: 3
# Episode 1050, Score: -4.941380179708858, Epsilon: 0.050, loss: 6.969333648681641 count: 20 version: 3
# Episode 1051, Score: 244.5882283233625, Epsilon: 0.050, loss: 6.901592254638672 count: 20 version: 3
# Episode 1052, Score: 47.295377116682516, Epsilon: 0.050, loss: 6.526994705200195 count: 20 version: 3
# Episode 1053, Score: 136.0911419746186, Epsilon: 0.050, loss: 6.689731121063232 count: 20 version: 3
# Episode 1054, Score: 1549.1545716041323, Epsilon: 0.050, loss: 7.220292091369629 count: 20 version: 3
# Episode 1055, Score: 205.58395149957812, Epsilon: 0.050, loss: 7.2142815589904785 count: 20 version: 3
# Episode 1056, Score: -23.518643500659437, Epsilon: 0.050, loss: 7.244703769683838 count: 20 version: 3
# Episode 1057, Score: 199.6660406876099, Epsilon: 0.050, loss: 6.688189506530762 count: 20 version: 3
# Episode 1058, Score: 867.6265541007338, Epsilon: 0.050, loss: 7.024637222290039 count: 20 version: 3
# Episode 1059, Score: 55.96522391204894, Epsilon: 0.050, loss: 6.952326774597168 count: 20 version: 3
# Episode 1060, Score: 35.27219748681182, Epsilon: 0.050, loss: 7.054245948791504 count: 20 version: 3
# Episode 1061, Score: 126.71010427279168, Epsilon: 0.050, loss: 7.223461151123047 count: 20 version: 3
# Episode 1062, Score: 127.03879657753725, Epsilon: 0.050, loss: 6.40365743637085 count: 20 version: 3
# Episode 1063, Score: 241.57320868095542, Epsilon: 0.050, loss: 7.137918472290039 count: 20 version: 3
# Episode 1064, Score: 137.64066347879543, Epsilon: 0.050, loss: 7.033924102783203 count: 20 version: 3
# Episode 1065, Score: 90.12908211655599, Epsilon: 0.050, loss: 6.874643325805664 count: 20 version: 3
# Episode 1066, Score: 2311.838383284887, Epsilon: 0.050, loss: 7.345913410186768 count: 20 version: 3
# Episode 1067, Score: 174.06939045682168, Epsilon: 0.050, loss: 6.930222988128662 count: 20 version: 3
# Episode 1068, Score: 29.8076282813106, Epsilon: 0.050, loss: 6.344512939453125 count: 20 version: 3
# Episode 1069, Score: 184.1269670518019, Epsilon: 0.050, loss: 6.821900367736816 count: 20 version: 3
# Episode 1070, Score: -51.053546863690485, Epsilon: 0.050, loss: 6.703158855438232 count: 20 version: 3
# Episode 1071, Score: 149.58768818923443, Epsilon: 0.050, loss: 6.839899063110352 count: 20 version: 3
# Episode 1072, Score: 228.9138528236116, Epsilon: 0.050, loss: 7.082615375518799 count: 20 version: 3
# Episode 1073, Score: 173.5800027974965, Epsilon: 0.050, loss: 6.536531448364258 count: 20 version: 3
# Episode 1074, Score: 115.83752563287601, Epsilon: 0.050, loss: 6.691935062408447 count: 20 version: 3
# Episode 1075, Score: 130.32465172967625, Epsilon: 0.050, loss: 7.108537197113037 count: 20 version: 3
# Episode 1076, Score: 150.83468908719306, Epsilon: 0.050, loss: 6.893321990966797 count: 20 version: 3
# Episode 1077, Score: -20.912100800678445, Epsilon: 0.050, loss: 6.585923671722412 count: 20 version: 3
# Episode 1078, Score: -31.052748534570412, Epsilon: 0.050, loss: 6.965095043182373 count: 20 version: 3
# Episode 1079, Score: 109.11359955590615, Epsilon: 0.050, loss: 7.0028395652771 count: 20 version: 3
# Episode 1080, Score: 102.03279330701207, Epsilon: 0.050, loss: 7.0628156661987305 count: 20 version: 3
# Episode 1081, Score: 16.590585503319517, Epsilon: 0.050, loss: 6.9273810386657715 count: 20 version: 3
# Episode 1082, Score: 520.2986375517908, Epsilon: 0.050, loss: 6.594466209411621 count: 20 version: 3
# Episode 1083, Score: 126.03660747244021, Epsilon: 0.050, loss: 6.849745273590088 count: 20 version: 3
# Episode 1084, Score: 2409.439981226501, Epsilon: 0.050, loss: 6.8792195320129395 count: 20 version: 3
# Episode 1085, Score: 24.693055587501476, Epsilon: 0.050, loss: 7.049755096435547 count: 20 version: 3
# Episode 1086, Score: 312.79978616288645, Epsilon: 0.050, loss: 7.227004051208496 count: 20 version: 3
# Episode 1087, Score: 1493.5908782236497, Epsilon: 0.050, loss: 7.156612873077393 count: 20 version: 3
# Episode 1088, Score: 79.8105028166292, Epsilon: 0.050, loss: 6.960916042327881 count: 20 version: 3
# Episode 1089, Score: 147.37422415319122, Epsilon: 0.050, loss: 6.8716840744018555 count: 20 version: 3
# Episode 1090, Score: 15.346445639989952, Epsilon: 0.050, loss: 6.855220317840576 count: 20 version: 3
# Episode 1091, Score: 98.33674897543574, Epsilon: 0.050, loss: 7.132043838500977 count: 20 version: 3
# Episode 1092, Score: 1514.4799550838945, Epsilon: 0.050, loss: 7.17246675491333 count: 20 version: 3
# Episode 1093, Score: 157.97413615724088, Epsilon: 0.050, loss: 6.400705814361572 count: 20 version: 3
# Episode 1094, Score: 2502.0796574846286, Epsilon: 0.050, loss: 6.88922119140625 count: 20 version: 3
# Episode 1095, Score: 274.6880453454992, Epsilon: 0.050, loss: 7.310766696929932 count: 20 version: 3
# Episode 1096, Score: 143.36059859991087, Epsilon: 0.050, loss: 7.117814540863037 count: 20 version: 3
# Episode 1097, Score: 209.1893733102612, Epsilon: 0.050, loss: 6.681764125823975 count: 20 version: 3
# Episode 1098, Score: 172.5876699933948, Epsilon: 0.050, loss: 6.566085338592529 count: 20 version: 3
# Episode 1099, Score: 125.3820854096374, Epsilon: 0.050, loss: 7.014741897583008 count: 20 version: 3
# Episode 1100, Score: 199.43703662401526, Epsilon: 0.050, loss: 7.2451581954956055 count: 20 version: 3
# Episode 1101, Score: 190.25765776192623, Epsilon: 0.050, loss: 6.788023471832275 count: 20 version: 3
# Episode 1102, Score: 534.9057803208841, Epsilon: 0.050, loss: 6.817143440246582 count: 20 version: 3
# Episode 1103, Score: 105.44444681463278, Epsilon: 0.050, loss: 6.672269344329834 count: 20 version: 3
# Episode 1104, Score: 596.2482709671328, Epsilon: 0.050, loss: 6.839382171630859 count: 20 version: 3
# Episode 1105, Score: -30.19168405803356, Epsilon: 0.050, loss: 6.694814205169678 count: 20 version: 3
# Episode 1106, Score: 712.3831982254248, Epsilon: 0.050, loss: 7.346585273742676 count: 20 version: 3
# Episode 1107, Score: 183.25560154902576, Epsilon: 0.050, loss: 6.51640510559082 count: 20 version: 3
# Episode 1108, Score: 1806.490523409505, Epsilon: 0.050, loss: 6.900649070739746 count: 20 version: 3
# Episode 1109, Score: 148.269695849728, Epsilon: 0.050, loss: 6.62136173248291 count: 20 version: 3
# Episode 1110, Score: 159.86576949692653, Epsilon: 0.050, loss: 6.822373390197754 count: 20 version: 3
# Episode 1111, Score: 50.80008057461225, Epsilon: 0.050, loss: 6.851276874542236 count: 20 version: 3
# Episode 1112, Score: 16.333172522753102, Epsilon: 0.050, loss: 6.600770950317383 count: 20 version: 3
# Episode 1113, Score: 1508.1300251632715, Epsilon: 0.050, loss: 7.2331156730651855 count: 20 version: 3
# Episode 1114, Score: 124.20313325886752, Epsilon: 0.050, loss: 7.170892715454102 count: 20 version: 3
# Episode 1115, Score: 3119.95027694457, Epsilon: 0.050, loss: 6.450094223022461 count: 20 version: 3
# Episode 1116, Score: 106.28035665417667, Epsilon: 0.050, loss: 6.615583419799805 count: 20 version: 3
# Episode 1117, Score: 40.02149378317654, Epsilon: 0.050, loss: 6.627843856811523 count: 20 version: 3
# Episode 1118, Score: 735.053798481518, Epsilon: 0.050, loss: 7.019434928894043 count: 20 version: 3
# Episode 1119, Score: 1471.1029352211863, Epsilon: 0.050, loss: 6.612670421600342 count: 20 version: 3
# Episode 1120, Score: 11.497300212337791, Epsilon: 0.050, loss: 7.059171199798584 count: 20 version: 3
# Episode 1121, Score: 397.72408259865654, Epsilon: 0.050, loss: 6.415606498718262 count: 20 version: 3
# Episode 1122, Score: 16.72244911872565, Epsilon: 0.050, loss: 6.5337233543396 count: 20 version: 3
# Episode 1123, Score: 156.2909109686401, Epsilon: 0.050, loss: 6.955239772796631 count: 20 version: 3
# Episode 1124, Score: 798.3066153002164, Epsilon: 0.050, loss: 6.813364505767822 count: 20 version: 3
# Episode 1125, Score: -34.992788272903, Epsilon: 0.050, loss: 6.6794633865356445 count: 20 version: 3
# Episode 1126, Score: -34.30724202799104, Epsilon: 0.050, loss: 6.970823764801025 count: 20 version: 3
# Episode 1127, Score: 223.09154299236639, Epsilon: 0.050, loss: 6.788316249847412 count: 20 version: 3
# Episode 1128, Score: 442.76560033987903, Epsilon: 0.050, loss: 6.905517101287842 count: 20 version: 3
# Episode 1129, Score: 251.1793739983898, Epsilon: 0.050, loss: 7.2250823974609375 count: 20 version: 3
# Episode 1130, Score: -14.183456349615597, Epsilon: 0.050, loss: 6.824584007263184 count: 20 version: 3
# Episode 1131, Score: 8.790363265437236, Epsilon: 0.050, loss: 6.973136901855469 count: 20 version: 3
# Episode 1132, Score: 8.543825742229785, Epsilon: 0.050, loss: 6.961092948913574 count: 20 version: 3
# Episode 1133, Score: 100.5400875296333, Epsilon: 0.050, loss: 7.568270683288574 count: 20 version: 3
# Episode 1134, Score: 468.2680590541959, Epsilon: 0.050, loss: 7.130997657775879 count: 20 version: 3
# Episode 1135, Score: 186.40685510802643, Epsilon: 0.050, loss: 7.32643461227417 count: 20 version: 3
# Episode 1136, Score: 167.57974256242846, Epsilon: 0.050, loss: 6.829255104064941 count: 20 version: 3
# Episode 1137, Score: 30.489532304844033, Epsilon: 0.050, loss: 6.818614959716797 count: 20 version: 3
# Episode 1138, Score: 285.70939644712473, Epsilon: 0.050, loss: 7.060307502746582 count: 20 version: 3
# Episode 1139, Score: -48.53748594569299, Epsilon: 0.050, loss: 7.046833515167236 count: 20 version: 3
# Episode 1140, Score: -25.21938171151743, Epsilon: 0.050, loss: 6.374741554260254 count: 20 version: 3
# Episode 1141, Score: -15.768347785990954, Epsilon: 0.050, loss: 7.310863018035889 count: 20 version: 3
# Episode 1142, Score: 54.89978616334486, Epsilon: 0.050, loss: 6.9827775955200195 count: 20 version: 3
# Episode 1143, Score: 108.28824166138997, Epsilon: 0.050, loss: 7.180991172790527 count: 20 version: 3
# Episode 1144, Score: -17.351393874833434, Epsilon: 0.050, loss: 7.27944278717041 count: 20 version: 3
# Episode 1145, Score: -13.264398990632287, Epsilon: 0.050, loss: 6.755410194396973 count: 20 version: 3
# Episode 1146, Score: 122.90334933034637, Epsilon: 0.050, loss: 6.791014671325684 count: 20 version: 3
# Episode 1147, Score: 152.29060297852607, Epsilon: 0.050, loss: 7.456940650939941 count: 20 version: 3
# Episode 1148, Score: 96.87834237400511, Epsilon: 0.050, loss: 6.7796406745910645 count: 20 version: 3
# Episode 1149, Score: -39.90149508866409, Epsilon: 0.050, loss: 7.265231132507324 count: 20 version: 3
# Episode 1150, Score: -73.5519927919434, Epsilon: 0.050, loss: 6.740315914154053 count: 20 version: 3
# Episode 1151, Score: 282.04963881068056, Epsilon: 0.050, loss: 6.956607818603516 count: 20 version: 3
# Episode 1152, Score: 2506.3688554692217, Epsilon: 0.050, loss: 6.874220848083496 count: 20 version: 3
# Episode 1153, Score: 41.62097428483571, Epsilon: 0.050, loss: 6.988886833190918 count: 20 version: 3
# Episode 1154, Score: 153.326322333804, Epsilon: 0.050, loss: 7.298282146453857 count: 20 version: 3
# Episode 1155, Score: 19.99073118751255, Epsilon: 0.050, loss: 6.631883144378662 count: 20 version: 3
# Episode 1156, Score: 154.544867328152, Epsilon: 0.050, loss: 6.864121913909912 count: 20 version: 3
# Episode 1157, Score: 104.88331285510242, Epsilon: 0.050, loss: 6.7929205894470215 count: 20 version: 3
# Episode 1158, Score: -71.19608814566436, Epsilon: 0.050, loss: 6.746938705444336 count: 20 version: 3
# Episode 1159, Score: 259.26810570456473, Epsilon: 0.050, loss: 7.0639801025390625 count: 20 version: 3
# Episode 1160, Score: -44.070940680753324, Epsilon: 0.050, loss: 6.6557416915893555 count: 20 version: 3
# Episode 1161, Score: 14.168953515758972, Epsilon: 0.050, loss: 6.900134086608887 count: 20 version: 3
# Episode 1162, Score: 14.57761118361816, Epsilon: 0.050, loss: 6.627696990966797 count: 20 version: 3
# Episode 1163, Score: 2626.822051544058, Epsilon: 0.050, loss: 6.891039848327637 count: 20 version: 3
# Episode 1164, Score: 56.61081362206562, Epsilon: 0.050, loss: 7.385076999664307 count: 20 version: 3
# Episode 1165, Score: 332.2098813936883, Epsilon: 0.050, loss: 7.091217041015625 count: 20 version: 3
# Episode 1166, Score: 108.37175335694133, Epsilon: 0.050, loss: 6.853103160858154 count: 20 version: 3
# Episode 1167, Score: 154.90382692353467, Epsilon: 0.050, loss: 6.852895259857178 count: 20 version: 3
# Episode 1168, Score: 1565.0579825718114, Epsilon: 0.050, loss: 7.062982082366943 count: 20 version: 3
# Episode 1169, Score: 14.702234751763626, Epsilon: 0.050, loss: 6.872280597686768 count: 20 version: 3
# Episode 1170, Score: 140.56867285387193, Epsilon: 0.050, loss: 6.510782718658447 count: 20 version: 3
# Episode 1171, Score: 129.38447247943952, Epsilon: 0.050, loss: 6.756673812866211 count: 20 version: 3
# Episode 1172, Score: 148.81411341073363, Epsilon: 0.050, loss: 6.2459001541137695 count: 20 version: 3
# Episode 1173, Score: 431.22225197026273, Epsilon: 0.050, loss: 6.74561071395874 count: 20 version: 3
# Episode 1174, Score: 155.46833695725127, Epsilon: 0.050, loss: 7.015288352966309 count: 20 version: 3
# Episode 1175, Score: -28.63495706384481, Epsilon: 0.050, loss: 6.8362507820129395 count: 20 version: 3
# Episode 1176, Score: 4.283200602055899, Epsilon: 0.050, loss: 6.9365315437316895 count: 20 version: 3
# Episode 1177, Score: 178.14495823099514, Epsilon: 0.050, loss: 6.880185604095459 count: 20 version: 3
# Episode 1178, Score: 12.249579228644393, Epsilon: 0.050, loss: 6.9009318351745605 count: 20 version: 3
# Episode 1179, Score: 138.43757047605402, Epsilon: 0.050, loss: 6.778656482696533 count: 20 version: 3
# Episode 1180, Score: 186.1017436201255, Epsilon: 0.050, loss: 6.839759349822998 count: 20 version: 3
# Episode 1181, Score: 2563.267390659167, Epsilon: 0.050, loss: 6.694262981414795 count: 20 version: 3
# Episode 1182, Score: -6.890604054601681, Epsilon: 0.050, loss: 6.956579208374023 count: 20 version: 3
# Episode 1183, Score: 130.097714613064, Epsilon: 0.050, loss: 6.867973804473877 count: 20 version: 3
# Episode 1184, Score: 2561.645484816075, Epsilon: 0.050, loss: 7.180994033813477 count: 20 version: 3
# Episode 1185, Score: 69.34162752383838, Epsilon: 0.050, loss: 6.607714653015137 count: 20 version: 3
# Episode 1186, Score: 46.2711044753529, Epsilon: 0.050, loss: 7.024563789367676 count: 20 version: 3
# Episode 1187, Score: 101.12569751714636, Epsilon: 0.050, loss: 6.763310432434082 count: 20 version: 3
# Episode 1188, Score: 47.28773089482263, Epsilon: 0.050, loss: 7.073087215423584 count: 20 version: 3
# Episode 1189, Score: 65.43583773467992, Epsilon: 0.050, loss: 6.656005859375 count: 20 version: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[169], line 117
#     114 state = next_state
#     116 if len(memory) >= BATCH_SIZE:
# --> 117     transitions = memory.sample(BATCH_SIZE)
#     118     batch = Transition(*zip(*transitions))
#     120     states = torch.stack(batch.state).to(device)
#
# Cell In[169], line 41, in ReplayMemory.sample(self, batch_size)
#      40 def sample(self, batch_size):
# ---> 41     return random.sample(self.memory, batch_size)
#
# File /opt/anaconda3/lib/python3.12/random.py:451, in Random.sample(self, population, k, counts)
#     449             j = randbelow(n)
#     450         selected_add(j)
# --> 451         result[i] = population[j]
#     452 return result
#
# KeyboardInterrupt:

# %%
pygame.init()
pygame.font.init()

my_font = pygame.font.SysFont('Comic Sans MS', 30)

policy_dqn = DQN(17, 9).to(device)
policy_dqn.load_state_dict(torch.load("/Users/ard/Desktop/Coding_2/F1_laptime_project/policies/policy_no_20-47.pth"))

angle_list = [angle*30 for angle in range(12)]

newgame = game(inner_points,outer_points,angle_list,(800,150),True)

done = False

while not done:
    state =  newgame.get_state()
    action = select_action(state, 0)
    done = not newgame.update(actions[action])
